# %% [markdown]
# #### 과제0727_2
# 검색 키워드와 총 필요한 뉴스기사 수를 입력하면 요청한 만큼 데이터프레임 형태(컬럼은 title, url)로 출력해주는 크롤링 프로그램을 수행하세요.

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query='

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
news_df = pd.DataFrame(columns=['title','url'])
def search(keyword, num):
    title_list = []
    url_list = []
    news_df = pd.DataFrame(columns=['title','url'])
    for i in range(1, num+1, 10):
        url = 'https://search.naver.com/search.naver?where=news&query='+str(keyword)+'&start='+str(i)
        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        articles = soup.find_all('a',{'class':{'news_tit'}},limit= num)
        for article in articles:
            newslink = article['href']
            url_list.append(newslink)
            title = article.text
            title_list.append(title)
    news_df.title = title_list
    news_df.url = url_list
    return news_df.iloc[:num].drop_duplicates(subset=['title', 'url'])

# %%
search('테슬라', 100)
# Out:
#                                       title  \
# 0               테슬라, 비트코인으로 상반기에만 2200억원 손실
# 1                테슬라, 비트코인으로 1억7000만달러 평가손실
# 2              테슬라 4% 가까이 급락, 다시 ‘칠백슬라’(상보)
# 3             테슬라, 설비투자 1조3000억 증액…공장 증설 영향
# 4       [마켓프로] 초고수들, 하루만에 '칠백슬라' 된 테슬라 저점매수
# ..                                      ...
# 95                        테슬라 호재에 2차전지株 '쑥'
# 96          '가격 인상 효과' 테슬라, 매출 감소했지만 이익 늘었다
# 97       차 값 또 올린 테슬라…물 만난 '아이오닉6' 노 못젓는 이유
# 98  [서학개미 뭐샀나] 테슬라 순매수 금액 압도적 1위…1.4% 하락 마감
# 99       ‘스냅 충격’ 테슬라 제외 美전기차 일제 급락, 루시드 8%↓
#
#                                                   url
# 0   https://biz.chosun.com/international/internati...
# 1       https://www.mk.co.kr/economy/view/2022/659600
# 2              https://www.news1.kr/articles/?4754547
# 3   http://www.newsis.com/view/?id=NISX20220726_00...
# 4   https://www.hankyung.com/finance/article/20220...
# ..                                                ...
# 95  https://www.hankyung.com/finance/article/20220...
# 96  http://www.edaily.co.kr/news/newspath.asp?news...
# 97  http://news.mt.co.kr/mtview.php?no=20220720234...
# 98  https://biz.sbs.co.kr/article_hub/20000073381?...
# 99             https://www.news1.kr/articles/?4751277
#
# [98 rows x 2 columns]
