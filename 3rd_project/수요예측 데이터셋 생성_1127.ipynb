# %%
import re
import numpy as np
import pandas as pd
def yearmonth(x):
    p = re.compile('.{7}')
    return p.findall(x)[0]

pd.options.display.float_format = '{:.2f}'.format
np.set_printoptions(precision=6, suppress=True)

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ## 각 데이터 불러오기

# %%
data20 = pd.read_csv('2020년_증식데이터_편집.csv', index_col=0)
data20['수주월'] = data20['수주일자'].apply(yearmonth)
data21 = pd.read_csv('2021년_증식데이터_편집.csv', index_col=0)
data21['수주월'] = data21['수주일자'].apply(yearmonth)

# 20년도 21년도 데이터 이어붙이기

data20_21 = pd.concat((data20,data21))
data20_21 = data20_21.sort_values(['수주일자','거래처코드','제품명'])

# %%
weather = pd.read_csv('전국평균날씨데이터.csv', index_col=0)
construction = pd.read_csv('연면적별.csv', index_col=0)
rate = pd.read_csv('월별 시장금리추이(202001_202112).csv',encoding='cp949',index_col=0).transpose().reset_index()
shipment = pd.read_csv('시멘트2년 국내출하(월별증감율).csv')

# %% [markdown]
# ## 빈 날짜 DF 생성

# %%
# 빈 날짜 데이터프레임 생성
start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('2021-12-31')
date_all = pd.date_range(start=start,end=end,freq='d')
# test = pd.DataFrame(index=date_all).join(data20_21_detail)
# test[test['거래처코드'].isnull()]

# %%
date_all = pd.date_range(start, end, freq='D').to_frame().rename(columns={0:'Date'}).reset_index(drop=True).set_index('Date')
date_all
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-01 00:00:00, 2020-01-02 00:00:00, 2020-01-03 00:00:00, 2020-01-04 00:00:00, 2020-01-05 00:00:00, 2020-01-06 00:00:00, 2020-01-07 00:00:00, 2020-01-08 00:00:00, 2020-01-09 00:00:00, 2020-01-10 00:00:00, 2020-01-11 00:00:00, 2020-01-12 00:00:00, 2020-01-13 00:00:00, 2020-01-14 00:00:00, 2020-01-15 00:00:00, 2020-01-16 00:00:00, 2020-01-17 00:00:00, 2020-01-18 00:00:00, 2020-01-19 00:00:00, 2020-01-20 00:00:00, 2020-01-21 00:00:00, 2020-01-22 00:00:00, 2020-01-23 00:00:00, 2020-01-24 00:00:00, 2020-01-25 00:00:00, 2020-01-26 00:00:00, 2020-01-27 00:00:00, 2020-01-28 00:00:00, 2020-01-29 00:00:00, 2020-01-30 00:00:00, 2020-01-31 00:00:00, 2020-02-01 00:00:00, 2020-02-02 00:00:00, 2020-02-03 00:00:00, 2020-02-04 00:00:00, 2020-02-05 00:00:00, 2020-02-06 00:00:00, 2020-02-07 00:00:00, 2020-02-08 00:00:00, 2020-02-09 00:00:00, 2020-02-10 00:00:00, 2020-02-11 00:00:00, 2020-02-12 00:00:00, 2020-02-13 00:00:00, 2020-02-14 00:00:00, 2020-02-15 00:00:00, 2020-02-16 00:00:00, 2020-02-17 00:00:00, 2020-02-18 00:00:00, 2020-02-19 00:00:00, 2020-02-20 00:00:00, 2020-02-21 00:00:00, 2020-02-22 00:00:00, 2020-02-23 00:00:00, 2020-02-24 00:00:00, 2020-02-25 00:00:00, 2020-02-26 00:00:00, 2020-02-27 00:00:00, 2020-02-28 00:00:00, 2020-02-29 00:00:00, 2020-03-01 00:00:00, 2020-03-02 00:00:00, 2020-03-03 00:00:00, 2020-03-04 00:00:00, 2020-03-05 00:00:00, 2020-03-06 00:00:00, 2020-03-07 00:00:00, 2020-03-08 00:00:00, 2020-03-09 00:00:00, 2020-03-10 00:00:00, 2020-03-11 00:00:00, 2020-03-12 00:00:00, 2020-03-13 00:00:00, 2020-03-14 00:00:00, 2020-03-15 00:00:00, 2020-03-16 00:00:00, 2020-03-17 00:00:00, 2020-03-18 00:00:00, 2020-03-19 00:00:00, 2020-03-20 00:00:00, 2020-03-21 00:00:00, 2020-03-22 00:00:00, 2020-03-23 00:00:00, 2020-03-24 00:00:00, 2020-03-25 00:00:00, 2020-03-26 00:00:00, 2020-03-27 00:00:00, 2020-03-28 00:00:00, 2020-03-29 00:00:00, 2020-03-30 00:00:00, 2020-03-31 00:00:00, 2020-04-01 00:00:00, 2020-04-02 00:00:00, 2020-04-03 00:00:00, 2020-04-04 00:00:00, 2020-04-05 00:00:00, 2020-04-06 00:00:00, 2020-04-07 00:00:00, 2020-04-08 00:00:00, 2020-04-09 00:00:00, ...]
#
# [731 rows x 0 columns]

# %%
date_m = pd.date_range(start, end, freq='m').to_frame().rename(columns={0:'Date'})
date_m.Date = date_m.Date.astype('str').apply(yearmonth)
date_m = date_m.set_index(np.arange(24))
date_m
# Out:
#        Date
# 0   2020-01
# 1   2020-02
# 2   2020-03
# 3   2020-04
# 4   2020-05
# 5   2020-06
# 6   2020-07
# 7   2020-08
# 8   2020-09
# 9   2020-10
# 10  2020-11
# 11  2020-12
# 12  2021-01
# 13  2021-02
# 14  2021-03
# 15  2021-04
# 16  2021-05
# 17  2021-06
# 18  2021-07
# 19  2021-08
# 20  2021-09
# 21  2021-10
# 22  2021-11
# 23  2021-12

# %% [markdown]
# # 주 단위 데이터셋 생성

# %% [markdown]
# ## 수주량

# %% [markdown]
# ### 주 단위 수주량 합계 : 전체

# %%
# 주 단위 수주량 합계 데이터셋
data20_21_total_week = data20_21.copy()
data20_21_total_week = data20_21_total_week.pivot_table('수주량',index=['수주일자'],aggfunc='sum')
data20_21_total_week = data20_21_total_week.reset_index()
data20_21_total_week['수주일자'] = pd.to_datetime(data20_21_total_week['수주일자'])
data20_21_total_week = data20_21_total_week.set_index('수주일자')

data20_21_total_week = data20_21_total_week.resample('w-tue').sum()
data20_21_total_week
# Out:
#                 수주량
# 수주일자
# 2020-01-07  1158600
# 2020-01-14   757000
# 2020-01-21  1464000
# 2020-01-28  1016800
# 2020-02-04  1392050
# ...             ...
# 2021-12-07  1625070
# 2021-12-14   861000
# 2021-12-21  1405540
# 2021-12-28  1286540
# 2022-01-04   864000
#
# [105 rows x 1 columns]

# %% [markdown]
# ### 주 단위 수주량 합계 : 품목별

# %%
# 주 단위 (품목별) 수주량 합계 데이터셋

data20_21_detail_week = data20_21.copy()
data20_21_detail_week = data20_21_detail_week.pivot_table('수주량',index=['수주일자','제품명'], aggfunc='sum')
data20_21_detail_week = data20_21_detail_week.reset_index()
data20_21_detail_week['수주일자'] = pd.to_datetime(data20_21_detail_week['수주일자'])
data20_21_detail_week = data20_21_detail_week.set_index('수주일자')

# %%
data20_21_detail_week
# Out:
#                       제품명    수주량
# 수주일자
# 2020-01-01    PEMA-HR1000  40000
# 2020-01-01    PEMA-PR1000  20000
# 2020-01-01    PEMA-SR2000  18000
# 2020-01-01   PEMA-SR3000F   9000
# 2020-01-02        CSA4000   5000
# ...                   ...    ...
# 2021-12-31   PEMA-PCM2000   5000
# 2021-12-31  PEMA-PCM2000B   5000
# 2021-12-31    PEMA-PR1000  66000
# 2021-12-31     PEMA-SN400  20000
# 2021-12-31    PEMA-SR2000  45000
#
# [5519 rows x 2 columns]

# %%
li = []
for j in data20_21_detail_week['제품명'].unique():
    data = data20_21_detail_week[data20_21_detail_week['제품명']==j]
    data = date_all.join(data,how='outer')
    data = data.drop(['제품명'],axis=1).resample('w-tue').sum()
    data['제품명'] = j
    data = data[['제품명','수주량']]
    li.append(data)

# %%
data20_21_detail_week = pd.concat(li)
data20_21_detail_week
# Out:
#                      제품명       수주량
# 2020-01-07   PEMA-HR1000 338000.00
# 2020-01-14   PEMA-HR1000 297000.00
# 2020-01-21   PEMA-HR1000 567000.00
# 2020-01-28   PEMA-HR1000 278000.00
# 2020-02-04   PEMA-HR1000 559050.00
# ...                  ...       ...
# 2021-12-07  PEMA-HR1000S      0.00
# 2021-12-14  PEMA-HR1000S  10000.00
# 2021-12-21  PEMA-HR1000S      0.00
# 2021-12-28  PEMA-HR1000S  10000.00
# 2022-01-04  PEMA-HR1000S      0.00
#
# [2835 rows x 2 columns]

# %% [markdown]
# ## 예측중량

# %% [markdown]
# ### 방법1) 30% 오차 예측

# %%
data20_21_detail_week['예상중량'] = 0

for i in range(len(data20_21_detail_week)):
    if data20_21_detail_week['수주량'][i] == 0:
        pass
    else:
        data20_21_detail_week['예상중량'][i] = np.random.randint(data20_21_detail_week['수주량'][i]*0.7, data20_21_detail_week['수주량'][i]*1.3, 1)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_38364\2384203448.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data20_21_detail_week['예상중량'][i] = np.random.randint(data20_21_detail_week['수주량'][i]*0.7, data20_21_detail_week['수주량'][i]*1.3, 1)

# %%
data20_21_detail_week.head(50)
# Out:
#                     제품명       수주량    예상중량
# 2020-01-07  PEMA-HR1000 338000.00  255282
# 2020-01-14  PEMA-HR1000 297000.00  288981
# 2020-01-21  PEMA-HR1000 567000.00  681518
# 2020-01-28  PEMA-HR1000 278000.00  319167
# 2020-02-04  PEMA-HR1000 559050.00  689827
# 2020-02-11  PEMA-HR1000 781500.00  708515
# 2020-02-18  PEMA-HR1000 378000.00  268862
# 2020-02-25  PEMA-HR1000 617000.00  561982
# 2020-03-03  PEMA-HR1000 364000.00  282696
# 2020-03-10  PEMA-HR1000 617000.00  439158
# 2020-03-17  PEMA-HR1000 567000.00  410914
# 2020-03-24  PEMA-HR1000 728000.00  828634
# 2020-03-31  PEMA-HR1000 634550.00  753101
# 2020-04-07  PEMA-HR1000 687000.00  783677
# 2020-04-14  PEMA-HR1000 528000.00  633332
# 2020-04-21  PEMA-HR1000 623000.00  530899
# 2020-04-28  PEMA-HR1000 563000.00  527930
# 2020-05-05  PEMA-HR1000 393000.00  482409
# 2020-05-12  PEMA-HR1000 680000.00  791104
# 2020-05-19  PEMA-HR1000 567000.00  413409
# 2020-05-26  PEMA-HR1000 730550.00  840048
# 2020-06-02  PEMA-HR1000 714000.00  629814
# 2020-06-09  PEMA-HR1000 438000.00  395864
# 2020-06-16  PEMA-HR1000 461000.00  458699
# 2020-06-23  PEMA-HR1000 494000.00  507138
# 2020-06-30  PEMA-HR1000 272000.00  279875
# 2020-07-07  PEMA-HR1000 436000.00  443924
# 2020-07-14  PEMA-HR1000 527000.00  533823
# 2020-07-21  PEMA-HR1000 568000.00  421075
# 2020-07-28  PEMA-HR1000 601550.00  748250
# 2020-08-04  PEMA-HR1000 668000.00  650011
# 2020-08-11  PEMA-HR1000 403000.00  447644
# 2020-08-18  PEMA-HR1000 511000.00  358274
# 2020-08-25  PEMA-HR1000 687000.00  614682
# 2020-09-01  PEMA-HR1000 212000.00  193917
# 2020-09-08  PEMA-HR1000 520000.00  462372
# 2020-09-15  PEMA-HR1000 572000.00  666739
# 2020-09-22  PEMA-HR1000 676000.00  529395
# 2020-09-29  PEMA-HR1000 672550.00  489933
# 2020-10-06  PEMA-HR1000 803000.00  689191
# 2020-10-13  PEMA-HR1000 526000.00  454706
# 2020-10-20  PEMA-HR1000 655000.00  681276
# 2020-10-27  PEMA-HR1000 675000.00  585049
# 2020-11-03  PEMA-HR1000 293000.00  358829
# 2020-11-10  PEMA-HR1000 617000.00  589766
# 2020-11-17  PEMA-HR1000 567000.00  588276
# 2020-11-24  PEMA-HR1000 728000.00  511366
# 2020-12-01  PEMA-HR1000 821550.00  634870
# 2020-12-08  PEMA-HR1000 471000.00  580937
# 2020-12-15  PEMA-HR1000 381000.00  266738

# %% [markdown]
# ### 방법2) 아리마 예측

# %%
len(data20_21_total_week.iloc[:26,:])
# Out:
# 26

# %%
a = data20_21_total_week.iloc[:26,:]

# %%
from pmdarima import auto_arima

auto_arima_model = auto_arima(a, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=4,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 from pmdarima import auto_arima
#       3 auto_arima_model = auto_arima(a, start_p=1,start_q=1,
#       4                              max_p=3, max_q=3,m=4,
#       5                              start_P = 1, start_Q = 1, max_P=3, max_Q=3,
#       6                              seasonal = True, d=1, D=1, trace=True,
#       7                              error_action = 'ignore',
#       8                              suppress_warning=True, stepwise=False)
#       9 auto_arima_model.summary()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pmdarima\__init__.py:52, in <module>
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pmdarima\arima\__init__.py:5, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pmdarima\arima\approx.py:9, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4 #
#       5 # R approx function
#       7 import numpy as np
# ----> 9 from ..utils.array import c, check_endog
#      10 from ..utils import get_callable
#      11 from ..compat.numpy import DTYPE
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pmdarima\utils\__init__.py:5, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .array import *
#       6 from .metaestimators import *
#       7 from .visualization import *
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pmdarima\utils\array.py:7, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4 #
#       5 # Array utilities
# ----> 7 from sklearn.utils import validation as skval
#       9 import numpy as np
#      10 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\__init__.py:80, in <module>
#      78 from . import _distributor_init  # noqa: F401
#      79 from . import __check_build  # noqa: F401
# ---> 80 from .base import clone
#      81 from .utils._show_versions import show_versions
#      83 __all__ = ['calibration', 'cluster', 'covariance', 'cross_decomposition',
#      84            'datasets', 'decomposition', 'dummy', 'ensemble', 'exceptions',
#      85            'experimental', 'externals', 'feature_extraction',
#    (...)
#      94            'clone', 'get_config', 'set_config', 'config_context',
#      95            'show_versions']
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:21, in <module>
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#      23 from .utils.validation import check_array
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\__init__.py:23, in <module>
#      20 from scipy.sparse import issparse
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\class_weight.py:7, in <module>
#       1 # Authors: Andreas Mueller
#       2 #          Manoj Kumar
#       3 # License: BSD 3 clause
#       5 import numpy as np
# ----> 7 from .validation import _deprecate_positional_args
#      10 @_deprecate_positional_args
#      11 def compute_class_weight(class_weight, *, classes, y):
#      12     """Estimate class weights for unbalanced datasets.
#      13
#      14     Parameters
#    (...)
#      38     Logistic Regression in Rare Events Data, King, Zen, 2001.
#      39     """
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:25, in <module>
#      21 import joblib
#      23 from contextlib import suppress
# ---> 25 from .fixes import _object_dtype_isnan, parse_version
#      26 from .. import get_config as _get_config
#      27 from ..exceptions import NonBLASDotWarning, PositiveSpectrumWarning
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\fixes.py:18, in <module>
#      16 import scipy.sparse as sp
#      17 import scipy
# ---> 18 import scipy.stats
#      19 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      20 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 0.25
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\stats\__init__.py:388, in <module>
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     386
#     387 """
# --> 388 from .stats import *
#     389 from .distributions import *
#     390 from .morestats import *
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\stats\stats.py:174, in <module>
#     171 import numpy as np
#     172 from numpy import array, asarray, ma
# --> 174 from scipy.spatial.distance import cdist
#     175 from scipy.ndimage import measurements
#     176 from scipy._lib._util import (_lazywhere, check_random_state, MapWrapper,
#     177                               rng_integers, float_factorial)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\spatial\__init__.py:98, in <module>
#      96 from .kdtree import *
#      97 from .ckdtree import *
# ---> 98 from .qhull import *
#      99 from ._spherical_voronoi import SphericalVoronoi
#     100 from ._plotutils import *
#
# File <frozen importlib._bootstrap>:389, in parent(self)
#
# KeyboardInterrupt:

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings;warnings.filterwarnings('ignore')

# 1개월(4주) 예측

li = []
for i in range(79):

    a = data20_21_total_week.iloc[i:i+26,:]

    weight = SARIMAX(a.수주량, order=(2,1,1), seasonal_order=(1,1,0,4))
    result = weight.fit()
    pred_weight = result.predict(start=len(a),end=(len(a)),
                             typ = 'level').rename('Forecast')
    li.append(pred_weight[0])

# %%
pred_weight = pd.DataFrame(li,columns=['예측중량']).set_index(data20_21_total_week.index[26:])
pred_weight
# Out:
#                  예측중량
# 수주일자
# 2020-07-07 1170712.13
# 2020-07-14 1319201.38
# 2020-07-21 1338214.41
# 2020-07-28 1469693.97
# 2020-08-04 1282272.39
# ...               ...
# 2021-12-07 1251255.59
# 2021-12-14 1766682.93
# 2021-12-21 2250126.45
# 2021-12-28  924752.57
# 2022-01-04  967478.30
#
# [79 rows x 1 columns]

# %%
# 수주량과 비교해보자
data20_21_total_week.iloc[26:]
# Out:
#                 수주량
# 수주일자
# 2020-07-07  1218000
# 2020-07-14  1396000
# 2020-07-21  1544800
# 2020-07-28  1578550
# 2020-08-04  1827500
# ...             ...
# 2021-12-07  1625070
# 2021-12-14   861000
# 2021-12-21  1405540
# 2021-12-28  1286540
# 2022-01-04   864000
#
# [79 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

x = range(len(data20_21_total_week.iloc[26:56]))
y = data20_21_total_week.iloc[26:56]

plt.figure(figsize=(20,10))
plt.plot(x,y)
plt.plot(x,pred_weight[0:30],'r')

# %% [markdown]
# ## 출하량

# %%
shipment_week = shipment.copy()
shipment_week = pd.concat([shipment_week,date_m],axis=1).set_index('Date').drop(['월','월별','월별증감율'],axis=1)

# %%
shipment_week = shipment_week.reset_index()
shipment_week['Date'] = pd.to_datetime(shipment_week['Date'])
shipment_week = shipment_week.set_index('Date')
shipment_week = date_all.join(shipment_week).fillna(method='ffill')
shipment_week
# Out:
#                내수계
# Date
# 2020-01-01 2704.00
# 2020-01-02 2704.00
# 2020-01-03 2704.00
# 2020-01-04 2704.00
# 2020-01-05 2704.00
# ...            ...
# 2021-12-27 4710.00
# 2021-12-28 4710.00
# 2021-12-29 4710.00
# 2021-12-30 4710.00
# 2021-12-31 4710.00
#
# [731 rows x 1 columns]

# %%
def strftime(x):
    return x.strftime('%Y-%m')

# %%
shipment_week = shipment_week.reset_index()
shipment_week['month'] = shipment_week['Date'].apply(strftime)

# %%
li = []
for i in shipment_week['month'].unique():
    li.extend((shipment_week[shipment_week['month']==i].loc[:,'내수계']/len(shipment_week[shipment_week['month']==i])).values)

# %%
shipment_week['내수계'] = pd.Series(li)

# %%
shipment_week = shipment_week.set_index('Date').drop('month',axis=1).resample('w-tue').sum()

# %%
shipment_week.columns = ['출하량']

# %%
shipment_week
# Out:
#                출하량
# Date
# 2020-01-07  610.58
# 2020-01-14  610.58
# 2020-01-21  610.58
# 2020-01-28  610.58
# 2020-02-04  692.99
# ...            ...
# 2021-12-07 1063.55
# 2021-12-14 1063.55
# 2021-12-21 1063.55
# 2021-12-28 1063.55
# 2022-01-04  455.81
#
# [105 rows x 1 columns]

# %% [markdown]
# ## 날씨

# %%
# 주 단위 날씨 데이터셋
weather_week = weather.copy()
weather_week['날짜'] = pd.to_datetime(weather_week['날짜'])
weather_week = weather_week.set_index('날짜')
weather_week = weather_week.resample('w-tue').mean()
weather_week
# Out:
#             평균온도  일강수량  상대습도  최심적설
# 날짜
# 2020-01-07  2.75  7.03 72.22  0.02
# 2020-01-14  1.85  0.73 65.51  0.02
# 2020-01-21  1.09  0.13 58.34  0.03
# 2020-01-28  5.32  3.92 75.36  0.00
# 2020-02-04  2.95  0.30 67.21  0.01
# ...          ...   ...   ...   ...
# 2021-12-07  3.70  0.23 64.27  0.00
# 2021-12-14  4.86  0.10 69.05  0.00
# 2021-12-21  3.08  0.51 66.75  0.19
# 2021-12-28 -1.19  0.48 59.43  0.58
# 2022-01-04 -0.51  0.23 61.19  0.44
#
# [105 rows x 4 columns]

# %% [markdown]
# ## 착공면적

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
construction_week = construction.copy()
construction_week = construction_week.set_index('Month')
construction_week = construction_week.reset_index()
construction_week['Month'] = pd.to_datetime(construction_week['Month'])
construction_week = construction_week.set_index('Month')
construction_week = date_all.join(construction_week).fillna(method='ffill')
construction_week
# Out:
#                   연면적별
# Date
# 2020-01-01  6200509.00
# 2020-01-02  6200509.00
# 2020-01-03  6200509.00
# 2020-01-04  6200509.00
# 2020-01-05  6200509.00
# ...                ...
# 2021-12-27 14132721.00
# 2021-12-28 14132721.00
# 2021-12-29 14132721.00
# 2021-12-30 14132721.00
# 2021-12-31 14132721.00
#
# [731 rows x 1 columns]

# %%
def strftime(x):
    return x.strftime('%Y-%m')

# %%
construction_week = construction_week.reset_index()
construction_week['month'] = construction_week['Date'].apply(strftime)

# %%
li = []
for i in construction_week['month'].unique():
    li.extend((construction_week[construction_week['month']==i].loc[:,'연면적별']/len(construction_week[construction_week['month']==i])).values)

# %%
construction_week['연면적별'] = pd.Series(li)

# %%
construction_week = construction_week.set_index('Date').drop('month',axis=1).resample('w-tue').sum()

# %%
construction_week
# Out:
#                  연면적별
# Date
# 2020-01-07 1400114.94
# 2020-01-14 1400114.94
# 2020-01-21 1400114.94
# 2020-01-28 1400114.94
-24 00:00:00, 2021-08-31 00:00:00, 2021-09-07 00:00:00, 2021-09-14 00:00:00, 2021-09-21 00:00:00, 2021-09-28 00:00:00, 2021-10-05 00:00:00, 2021-10-12 00:00:00, 2021-10-19 00:00:00, 2021-10-26 00:00:00, 2021-11-02 00:00:00, 2021-11-09 00:00:00, 2021-11-16 00:00:00, 2021-11-23 00:00:00, 2021-11-30 00:00:00, ...]
#
# [105 rows x 0 columns]

# %%
import numpy as np

# %%
rate_week = rate.copy().set_index('index')
rate_week = rate_week.reset_index()
rate_week['index'] = pd.to_datetime(rate_week['index'])
rate_week = rate_week.set_index('index')
rate_week = date_all.join(rate_week)
rate_week = rate_week.resample('w-tue').sum()
rate_week = rate_week.replace(0,np.NaN).fillna(method='ffill')
rate_week
# Out:
#             기준금리
# Date
# 2020-01-07  1.25
# 2020-01-14  1.25
# 2020-01-21  1.25
# 2020-01-28  1.25
# 2020-02-04  1.25
# ...          ...
# 2021-12-07  1.00
# 2021-12-14  1.00
# 2021-12-21  1.00
# 2021-12-28  1.00
# 2022-01-04  1.00
#
# [105 rows x 1 columns]

# %% [markdown]
# ## 데이터셋

# %%
# (제품별) 데이터셋 결합
dataset_detail_week = weather_week.join([rate_week,construction_week_scaled_,shipment_week,data20_21_detail_week])

# %%
dataset_detail_week
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량           제품명       수주량  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-HR1000 338000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-PR1000  85000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-SR2000  85000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  PEMA-SR3000F  46000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58       CSA4000  12000.00
# ...          ...   ...   ...   ...   ...   ...    ...           ...       ...
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81   PEMA-SP1000      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81       SRE-200      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      PEMA-SPR      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81     ARE-580FX      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81  PEMA-HR1000S      0.00
#
#               예상중량
# 2020-01-07  255282
# 2020-01-07   63286
# 2020-01-07   81153
# 2020-01-07   40669
# 2020-01-07   14716
# ...            ...
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
#
# [2835 rows x 10 columns]

# %%
dataset_detail_week.to_csv('dataset_detail_week.csv')

# %%
dataset_detail_week= pd.read_csv('dataset_detail_week.csv', index_col=0)
dataset_detail_week
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량           제품명       수주량  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-HR1000 338000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-PR1000  85000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58   PEMA-SR2000  85000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  PEMA-SR3000F  46000.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58       CSA4000  12000.00
# ...          ...   ...   ...   ...   ...   ...    ...           ...       ...
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81   PEMA-SP1000      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81       SRE-200      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      PEMA-SPR      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81     ARE-580FX      0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81  PEMA-HR1000S      0.00
#
#               예상중량
# 2020-01-07  255282
# 2020-01-07   63286
# 2020-01-07   81153
# 2020-01-07   40669
# 2020-01-07   14716
# ...            ...
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
# 2022-01-04       0
#
# [2835 rows x 10 columns]

# %%
len(dataset_detail_week[dataset_detail_week['수주량']!=0])
# Out:
# 1883

# %%
# dataset_detail_week = dataset_detail_week[dataset_detail_week['수주량']!=0]

# %%
dataset_detail_week = pd.concat([dataset_detail_week,pd.get_dummies(dataset_detail_week.제품명)],axis=1).drop('제품명',axis=1)
dataset_detail_week
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량       수주량    예상중량  AE  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58 338000.00  255282   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   63286   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   81153   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  46000.00   40669   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  12000.00   14716   0
# ...          ...   ...   ...   ...   ...   ...    ...       ...     ...  ..
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            1             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# ...         ...         ...          ...       ...          ...           ...
# 2022-01-04  ...           0            1         0            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         1            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             1             0       0        0        0
# 2020-01-07             0             0       0        0        0
# ...                  ...           ...     ...      ...      ...
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        1
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
#
# [2835 rows x 36 columns]

# %%
dataset_detail_week.to_csv('학습용 데이터셋_2년.csv')

# %% [markdown]
# ## 미래 변수 시계열 예측 (3개월)
#  - 날씨 (온도, 습도, 강우량, 적설량)
#  - 착공지수
#  - 기준금리
#  - 출하량
#  - 예상중량

# %%
dataset_detail_week
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량       수주량    예상중량  AE  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58 338000.00  320492   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   71068   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00  100114   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  46000.00   46448   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  12000.00   13639   0
# ...          ...   ...   ...   ...   ...   ...    ...       ...     ...  ..
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            1             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# ...         ...         ...          ...       ...          ...           ...
# 2022-01-04  ...           0            1         0            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         1            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             1             0       0        0        0
# 2020-01-07             0             0       0        0        0
# ...                  ...           ...     ...      ...      ...
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        1
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
#
# [2835 rows x 36 columns]

# %% [markdown]
# ### 온도

# %%
# 온도
a = weather_week.iloc[:,:1]
a
# Out:
#             평균온도
# 날짜
# 2020-01-07  2.75
# 2020-01-14  1.85
# 2020-01-21  1.09
# 2020-01-28  5.32
# 2020-02-04  2.95
# ...          ...
# 2021-12-07  3.70
# 2021-12-14  4.86
# 2021-12-21  3.08
# 2021-12-28 -1.19
# 2022-01-04 -0.51
#
# [105 rows x 1 columns]

# %%
train = a.iloc[:len(a)-29]
test = a.iloc[len(a)-29:]

# %%
from pmdarima import auto_arima

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=125.255, Time=0.22 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=127.255, Time=1.75 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=129.255, Time=3.23 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=131.255, Time=8.54 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=127.255, Time=1.71 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=129.255, Time=2.24 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=131.255, Time=5.83 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=133.255, Time=10.24 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=129.255, Time=4.55 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=131.255, Time=6.79 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=133.255, Time=7.45 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=135.255, Time=12.72 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=131.255, Time=9.79 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=133.255, Time=13.55 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=135.255, Time=15.41 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=119.297, Time=0.24 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=121.297, Time=2.47 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=123.297, Time=4.28 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=125.297, Time=13.01 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=121.297, Time=2.75 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=123.297, Time=3.22 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=125.297, Time=9.28 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=127.297, Time=15.43 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=123.297, Time=8.38 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=125.297, Time=10.02 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=127.297, Time=11.81 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=125.297, Time=16.79 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=127.297, Time=19.10 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=121.261, Time=0.41 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=123.261, Time=3.94 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=125.261, Time=7.10 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=127.261, Time=19.85 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=123.261, Time=4.22 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=125.261, Time=4.91 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=127.261, Time=14.82 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=125.261, Time=11.46 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=127.261, Time=15.43 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=127.261, Time=23.85 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=122.140, Time=0.52 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=124.140, Time=4.96 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=126.140, Time=7.84 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=124.140, Time=4.98 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=126.140, Time=5.96 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=126.140, Time=15.95 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=122.198, Time=0.25 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=124.198, Time=2.19 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=126.198, Time=4.22 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=128.198, Time=11.45 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=124.198, Time=2.50 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=126.198, Time=2.88 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=128.198, Time=8.47 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=130.198, Time=13.39 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=126.198, Time=7.36 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=128.198, Time=9.06 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=130.198, Time=10.31 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=128.198, Time=14.98 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=130.198, Time=16.54 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=121.281, Time=0.40 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=123.281, Time=5.46 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=125.281, Time=7.78 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=127.281, Time=22.57 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=123.281, Time=4.60 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=125.281, Time=5.74 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=127.281, Time=18.50 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=125.281, Time=16.21 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=127.281, Time=19.24 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=127.281, Time=30.43 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=inf, Time=1.11 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=inf, Time=26.38 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=inf, Time=38.12 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=inf, Time=25.49 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=inf, Time=29.16 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=inf, Time=92.79 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=inf, Time=1.59 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=inf, Time=22.80 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=inf, Time=22.51 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=120.598, Time=0.37 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=122.598, Time=3.60 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=124.598, Time=6.53 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=126.598, Time=18.02 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=122.598, Time=3.80 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=124.598, Time=4.97 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=126.598, Time=13.76 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=124.598, Time=12.51 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=126.598, Time=14.78 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=126.598, Time=24.42 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=122.215, Time=0.63 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=124.215, Time=5.37 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=126.215, Time=9.24 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=124.215, Time=5.66 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=126.215, Time=7.43 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=126.215, Time=19.50 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=124.171, Time=0.97 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=126.171, Time=9.16 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=126.171, Time=9.89 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=inf, Time=2.73 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=122.050, Time=0.52 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=124.050, Time=4.57 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=126.050, Time=7.17 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=124.050, Time=5.53 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=126.050, Time=6.44 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=126.050, Time=14.61 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=inf, Time=1.70 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=inf, Time=26.74 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=inf, Time=28.86 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=125.049, Time=2.12 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[52]
# Total fit time: 1135.665 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 1)x(0, 1, [], 52)   Log Likelihood                 -57.648
# Date:                             Fri, 25 Nov 2022   AIC                            119.297
# Time:                                     17:23:53   BIC                            121.568
# Sample:                                 01-07-2020   HQIC                           119.868
#                                       - 06-15-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6330      0.227     -2.784      0.005      -1.079      -0.187
# sigma2         8.6091      2.943      2.925      0.003       2.840      14.378
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 0.39
# Prob(Q):                              0.73   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.91   Skew:                            -0.26
# Prob(H) (two-sided):                  0.90   Kurtosis:                         3.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings;warnings.filterwarnings('ignore')

# 3개월(12주) 예측

model_temp = SARIMAX(a.평균온도, order=(0,1,1), seasonal_order=(0,1,0,52))
result = model_temp.fit()
weather_week_future_temp = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('평균온도')
a.평균온도.plot(figsize=(12,5),legend=True)
weather_week_future_temp.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
weather_week_future_temp = pd.DataFrame(weather_week_future_temp)

# %%
weather_week_future_temp.to_csv('미래변수_온도.csv')

# %% [markdown]
# ### 강수량

# %%
weather_week.iloc[:,1:2]
# Out:
#             일강수량
# 날짜
# 2020-01-07  7.03
# 2020-01-14  0.73
# 2020-01-21  0.13
# 2020-01-28  3.92
# 2020-02-04  0.30
# ...          ...
# 2021-12-07  0.23
# 2021-12-14  0.10
# 2021-12-21  0.51
# 2021-12-28  0.48
# 2022-01-04  0.23
#
# [105 rows x 1 columns]

# %%
# 강수량
b = weather_week.iloc[:,1:2]
train = b.iloc[:len(b)-29]
test = b.iloc[len(b)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=139.672, Time=0.20 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=141.672, Time=0.27 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=143.672, Time=0.62 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=145.672, Time=1.33 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=141.672, Time=0.17 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=143.672, Time=0.25 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=145.672, Time=0.68 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=147.672, Time=1.46 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=143.672, Time=0.42 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=145.672, Time=0.62 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=147.672, Time=0.86 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=149.672, Time=1.78 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=145.672, Time=1.02 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=147.672, Time=1.47 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=149.672, Time=1.89 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=128.796, Time=0.13 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=130.796, Time=0.60 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=132.796, Time=1.38 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=134.796, Time=2.73 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=130.796, Time=0.52 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=132.796, Time=0.65 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=134.796, Time=1.58 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=136.796, Time=3.20 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=132.796, Time=1.41 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=134.796, Time=1.64 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=136.796, Time=1.94 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=134.796, Time=3.56 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=136.796, Time=3.62 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=inf, Time=0.92 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=inf, Time=1.96 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=inf, Time=0.52 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=inf, Time=1.23 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=inf, Time=1.13 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=inf, Time=1.19 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=inf, Time=2.43 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=131.934, Time=0.22 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=133.934, Time=0.88 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=135.934, Time=1.82 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=133.934, Time=0.86 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=135.934, Time=1.11 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=135.934, Time=1.94 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=136.591, Time=0.09 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=138.591, Time=0.41 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=140.591, Time=0.83 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=142.591, Time=1.84 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=138.591, Time=0.41 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=140.591, Time=0.49 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=142.591, Time=1.08 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=144.591, Time=2.24 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=140.591, Time=1.07 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=142.591, Time=1.20 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=144.591, Time=1.42 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=142.591, Time=2.38 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=144.591, Time=2.72 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=130.545, Time=0.14 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=132.545, Time=0.60 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=134.545, Time=1.35 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=136.545, Time=2.81 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=132.545, Time=0.80 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=134.545, Time=0.83 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=136.545, Time=1.68 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=134.545, Time=1.52 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=136.545, Time=1.81 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=136.545, Time=3.51 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=132.531, Time=0.19 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=134.531, Time=0.73 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=136.531, Time=1.51 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=134.531, Time=0.79 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=136.531, Time=0.85 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=136.531, Time=1.80 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=inf, Time=1.02 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=inf, Time=3.91 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=inf, Time=4.46 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=132.963, Time=0.17 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=134.963, Time=0.61 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=136.963, Time=1.48 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=138.963, Time=2.64 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=134.963, Time=0.63 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=136.963, Time=0.74 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=138.963, Time=1.65 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=136.963, Time=1.41 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=138.963, Time=1.75 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=138.963, Time=3.59 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=131.659, Time=0.24 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=133.659, Time=0.76 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=135.659, Time=1.76 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=133.659, Time=0.86 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=135.659, Time=1.02 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=135.659, Time=1.97 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=133.589, Time=0.28 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=135.589, Time=1.29 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=135.589, Time=1.18 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=inf, Time=1.22 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=133.493, Time=0.18 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=135.493, Time=0.69 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=137.493, Time=1.63 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=135.493, Time=0.84 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=137.493, Time=1.00 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=137.493, Time=1.85 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=133.592, Time=0.28 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=135.592, Time=1.13 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=135.592, Time=1.43 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=135.589, Time=0.81 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[52]
# Total fit time: 135.325 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 1)x(0, 1, [], 52)   Log Likelihood                 -62.398
# Date:                             Fri, 25 Nov 2022   AIC                            128.796
# Time:                                     19:48:30   BIC                            131.067
# Sample:                                 01-07-2020   HQIC                           129.367
#                                       - 06-15-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9502      0.234     -4.053      0.000      -1.410      -0.491
# sigma2        12.0690      4.755      2.538      0.011       2.750      21.388
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.43   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.50   Skew:                            -0.20
# Prob(H) (two-sided):                  0.35   Kurtosis:                         3.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings;warnings.filterwarnings('ignore')

# 3개월(12주) 예측

model_rain = SARIMAX(b.일강수량, order=(0,1,1), seasonal_order=(0,1,0,52))
result = model_rain.fit()
weather_week_future_rain = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('일강수량')
b.일강수량.plot(figsize=(12,5),legend=True)
weather_week_future_rain.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
weather_week_future_rain = pd.DataFrame(weather_week_future_rain)
weather_week_future_rain[weather_week_future_rain['일강수량']<0] = 0
weather_week_future_rain
# Out:
#             일강수량
# 2022-01-11  0.00
# 2022-01-18  0.00
# 2022-01-25  1.24
# 2022-02-01  0.77
# 2022-02-08  0.00
# 2022-02-15  0.00
# 2022-02-22  0.00
# 2022-03-01  7.08
# 2022-03-08  0.00
# 2022-03-15  1.44
# 2022-03-22  0.07
# 2022-03-29  3.75

# %%
weather_week_future_rain.to_csv('미래변수_강수량.csv')

# %% [markdown]
# ### 습도

# %%
# 습도
c = weather_week.iloc[:,2:3]
train = c.iloc[:len(b)-29]
test = c.iloc[len(b)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=173.792, Time=0.11 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=175.792, Time=0.62 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=inf, Time=4.89 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=179.792, Time=3.10 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=inf, Time=1.90 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=177.790, Time=2.71 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=179.791, Time=2.60 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=inf, Time=12.35 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=177.791, Time=1.74 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=179.791, Time=1.93 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=inf, Time=8.95 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=183.792, Time=4.42 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=inf, Time=9.22 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=inf, Time=15.99 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=inf, Time=7.82 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=169.329, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=171.328, Time=0.74 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=173.328, Time=1.54 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=175.328, Time=3.06 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=171.326, Time=2.19 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=inf, Time=3.01 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=175.328, Time=1.16 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=177.326, Time=16.06 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=173.328, Time=2.40 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=inf, Time=8.07 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=177.328, Time=1.59 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=175.328, Time=3.99 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=177.325, Time=18.83 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=170.058, Time=0.20 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=inf, Time=3.30 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=174.056, Time=6.88 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=inf, Time=13.34 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=172.055, Time=2.92 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=174.057, Time=1.20 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=176.057, Time=2.47 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=174.055, Time=7.24 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=176.057, Time=2.75 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=176.055, Time=15.95 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=171.758, Time=0.30 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=inf, Time=3.40 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=inf, Time=7.51 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=173.755, Time=4.04 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=175.755, Time=4.82 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=175.755, Time=8.29 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=172.959, Time=0.10 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=inf, Time=2.62 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=176.957, Time=5.51 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=inf, Time=13.09 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=inf, Time=1.87 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=176.957, Time=3.90 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=inf, Time=7.34 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=inf, Time=19.70 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=inf, Time=7.64 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=178.957, Time=7.87 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=inf, Time=9.75 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=inf, Time=15.88 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=180.956, Time=19.78 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=170.290, Time=0.21 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=inf, Time=2.84 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=inf, Time=6.74 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=inf, Time=13.91 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=172.287, Time=2.74 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=174.287, Time=3.41 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=inf, Time=7.21 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=174.287, Time=6.97 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=176.287, Time=7.27 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=176.287, Time=15.82 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=171.503, Time=0.26 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=inf, Time=3.15 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=inf, Time=8.00 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=173.501, Time=3.33 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=175.501, Time=4.34 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=175.501, Time=8.35 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=173.503, Time=0.46 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=inf, Time=4.14 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=175.501, Time=4.40 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=171.027, Time=0.18 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=inf, Time=2.96 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=inf, Time=6.37 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=inf, Time=14.07 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=inf, Time=3.24 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=175.025, Time=4.02 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=177.025, Time=8.11 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=inf, Time=7.96 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=177.025, Time=10.28 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=inf, Time=17.00 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=172.619, Time=0.27 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=inf, Time=3.69 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=inf, Time=7.92 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=174.617, Time=3.84 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=176.617, Time=4.71 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=176.617, Time=9.33 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=174.617, Time=0.36 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=inf, Time=4.14 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=176.615, Time=4.38 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=inf, Time=0.84 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=172.765, Time=0.29 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=inf, Time=4.89 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=inf, Time=9.81 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=inf, Time=4.24 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=176.763, Time=5.27 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=inf, Time=9.62 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=174.619, Time=0.67 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=176.619, Time=2.00 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=176.619, Time=2.05 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=174.630, Time=0.57 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[52]
# Total fit time: 598.340 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 1)x(0, 1, [], 52)   Log Likelihood                 -82.664
# Date:                             Fri, 25 Nov 2022   AIC                            169.329
# Time:                                     20:00:39   BIC                            171.600
# Sample:                                 01-07-2020   HQIC                           169.900
#                                       - 06-15-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8280      0.139     -5.957      0.000      -1.100      -0.556
# sigma2        73.7041     23.539      3.131      0.002      27.568     119.841
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.54   Jarque-Bera (JB):                 0.09
# Prob(Q):                              0.46   Prob(JB):                         0.96
# Heteroskedasticity (H):               0.75   Skew:                            -0.02
# Prob(H) (two-sided):                  0.70   Kurtosis:                         2.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 3개월(12주) 예측

model_humidity = SARIMAX(c.상대습도, order=(2,1,0), seasonal_order=(0,1,0,52))
result = model_humidity.fit()
weather_week_future_humidity = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('상대습도')
c.상대습도.plot(figsize=(12,5),legend=True)
weather_week_future_humidity.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
weather_week_future_humidity = pd.DataFrame(weather_week_future_humidity)
weather_week_future_humidity
# Out:
#             상대습도
# 2022-01-11 63.44
# 2022-01-18 59.60
# 2022-01-25 78.37
# 2022-02-01 60.66
# 2022-02-08 55.15
# 2022-02-15 64.01
# 2022-02-22 55.74
# 2022-03-01 68.48
# 2022-03-08 73.29
# 2022-03-15 69.70
# 2022-03-22 63.85
# 2022-03-29 63.44

# %%
weather_week_future_humidity.to_csv('미래변수_습도.csv')

# %% [markdown]
# ### 적설량

# %%
# 적설량
d = weather_week.iloc[:,3:4]
train = d.iloc[:len(d)-29]
test = d.iloc[len(d)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=12.211, Time=0.20 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=14.211, Time=0.38 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=16.211, Time=0.64 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=18.211, Time=1.46 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=14.211, Time=0.21 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=16.211, Time=0.32 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=18.211, Time=1.54 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=20.211, Time=1.79 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=16.211, Time=0.84 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=18.211, Time=0.91 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=20.211, Time=1.10 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=22.211, Time=2.22 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=18.211, Time=6.34 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=20.211, Time=1.66 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):                 4.62
# Prob(Q):                              0.71   Prob(JB):                         0.10
# Heteroskedasticity (H):               0.01   Skew:                            -0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 3개월(12주) 예측

model_snow = SARIMAX(d.최심적설, order=(3,0,1), seasonal_order=(1,1,0,52))
result = model_snow.fit()
weather_week_future_snow = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('최심적설')
d.최심적설.plot(figsize=(12,5),legend=True)
weather_week_future_snow.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
weather_week_future_snow = pd.DataFrame(weather_week_future_snow)
weather_week_future_snow[weather_week_future_snow['최심적설']<0]= 0
weather_week_future_snow
# Out:
#             최심적설
# 2022-01-11  0.36
# 2022-01-18  0.19
# 2022-01-25  0.11
# 2022-02-01  0.06
# 2022-02-08  0.16
# 2022-02-15  0.39
# 2022-02-22  0.30
# 2022-03-01  0.04
# 2022-03-08  0.04
# 2022-03-15  0.01
# 2022-03-22  0.00
# 2022-03-29  0.00

# %%
weather_week_future_snow.to_csv('미래변수_적설량.csv')

# %% [markdown]
# ### 금리

# %%
# 금리
e = rate_week
train = e.iloc[:len(b)-29]
test = e.iloc[len(b)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=-31.598, Time=0.14 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=-29.598, Time=1.36 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=-27.598, Time=2.58 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=-25.598, Time=1.59 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=-29.598, Time=0.25 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=-27.598, Time=0.36 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=-25.598, Time=1.28 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=-23.598, Time=1.78 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=-27.598, Time=0.70 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=-25.598, Time=1.10 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=-23.598, Time=4.31 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=-21.598, Time=2.14 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=-25.598, Time=1.64 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=-23.598, Time=2.26 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=-21.598, Time=2.55 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=-29.598, Time=0.13 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=-27.598, Time=0.43 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=-25.598, Time=0.80 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=-23.598, Time=1.62 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=-27.598, Time=0.37 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=-25.598, Time=0.48 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=-23.598, Time=1.06 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=-21.598, Time=2.09 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=-25.598, Time=0.84 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=-23.598, Time=1.14 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=-21.598, Time=1.48 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=-23.598, Time=2.20 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=-21.598, Time=2.51 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=-27.598, Time=0.22 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=-25.598, Time=0.76 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=-23.598, Time=1.55 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=-21.598, Time=3.21 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=-25.598, Time=0.61 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=-23.598, Time=0.88 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=-21.598, Time=2.23 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=-23.598, Time=2.87 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=-21.598, Time=1.82 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=-21.598, Time=3.92 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=-25.598, Time=0.17 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=-23.598, Time=0.65 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=-21.598, Time=1.46 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=-23.598, Time=0.65 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=-21.598, Time=0.80 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=-21.598, Time=1.55 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=-29.598, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=-27.598, Time=0.32 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=-25.598, Time=0.98 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=-23.598, Time=2.14 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=-27.598, Time=0.53 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=-25.598, Time=0.56 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=-23.598, Time=0.87 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=-21.598, Time=2.57 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=-25.598, Time=0.89 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=-23.598, Time=1.38 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=-21.598, Time=2.00 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=-23.598, Time=2.41 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=-21.598, Time=3.14 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=-27.598, Time=0.34 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=-25.598, Time=0.45 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=-23.598, Time=1.11 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=-21.598, Time=2.16 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=-25.598, Time=0.46 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=-23.598, Time=0.62 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=-21.598, Time=1.27 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=-23.598, Time=1.13 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=-21.598, Time=1.41 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=-21.598, Time=2.63 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=-25.598, Time=0.26 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=-23.598, Time=0.85 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=-21.598, Time=1.85 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=-23.598, Time=0.98 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=-21.598, Time=1.09 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=-21.598, Time=2.67 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=-23.598, Time=0.24 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=-21.598, Time=0.80 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=-21.598, Time=0.82 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=-27.598, Time=0.11 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=-25.598, Time=0.50 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=-23.598, Time=1.27 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=-21.598, Time=2.74 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=-25.598, Time=0.43 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=-23.598, Time=0.86 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=-21.598, Time=1.28 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=-23.598, Time=1.13 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=-21.598, Time=4.25 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=-21.598, Time=2.34 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=-25.598, Time=0.16 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=-23.598, Time=0.53 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=-21.598, Time=1.19 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=-23.598, Time=0.58 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=-21.598, Time=0.65 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=-21.598, Time=1.63 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=-23.598, Time=0.30 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=-21.598, Time=1.13 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=-21.598, Time=1.46 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=-21.598, Time=0.33 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=-25.598, Time=0.19 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=-23.598, Time=0.90 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=-21.598, Time=2.80 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=-23.598, Time=0.91 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=-21.598, Time=0.78 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=-21.598, Time=4.42 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=-23.598, Time=0.23 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=-21.598, Time=1.08 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=-21.598, Time=0.90 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=-21.598, Time=0.46 sec
#
# Best model:  ARIMA(0,1,0)(0,1,0)[52]
# Total fit time: 137.574 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 52)   Log Likelihood                  16.799
# Date:                            Fri, 25 Nov 2022   AIC                            -31.598
# Time:                                    20:15:31   BIC                            -30.462
# Sample:                                01-07-2020   HQIC                           -31.312
#                                      - 06-15-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0136      0.001      9.175      0.000       0.011       0.016
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):               158.91
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                             3.46
# Prob(H) (two-sided):                  0.07   Kurtosis:                        13.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 3개월(12주) 예측

model_rate = SARIMAX(e.기준금리, order=(0,1,0), seasonal_order=(0,1,0,52))
result = model_rate.fit()
weather_week_future_rate = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('기준금리')
e.기준금리.plot(figsize=(12,5),legend=True)
weather_week_future_rate.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
weather_week_future_rate = pd.DataFrame(weather_week_future_rate)
weather_week_future_rate
# Out:
#             기준금리
# 2022-01-11  1.00
# 2022-01-18  1.00
# 2022-01-25  1.00
# 2022-02-01  1.00
# 2022-02-08  1.00
# 2022-02-15  1.00
# 2022-02-22  1.00
# 2022-03-01  1.00
# 2022-03-08  1.00
# 2022-03-15  1.00
# 2022-03-22  1.00
# 2022-03-29  1.00

# %%
weather_week_future_rate.to_csv('미래변수_금리.csv')

# %% [markdown]
# ### 착공면적

# %%
# 착공면적
f = construction_week_scaled_
train = f.iloc[:len(b)-29]
test = f.iloc[len(b)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=-52.905, Time=0.25 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=-50.905, Time=0.70 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=-48.905, Time=0.79 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=-46.905, Time=2.38 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=-50.905, Time=0.28 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=-48.905, Time=0.57 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=-46.905, Time=2.72 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=-44.905, Time=2.09 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=-48.905, Time=0.69 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=-46.905, Time=1.41 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=-44.905, Time=2.13 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=-42.905, Time=2.75 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=-46.905, Time=2.01 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=-44.905, Time=6.60 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=-42.905, Time=5.18 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=-51.140, Time=0.19 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=-49.140, Time=0.85 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=-47.140, Time=3.36 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=-45.140, Time=3.32 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=-49.140, Time=1.13 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=-47.140, Time=1.87 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=-45.140, Time=2.78 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=-43.140, Time=5.52 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=-47.140, Time=2.62 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC
0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 1.16
# Prob(Q):                              0.52   Prob(JB):                         0.56
# Heteroskedasticity (H):               0.18   Skew:                             0.03
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 3개월(12주) 예측

model_area = SARIMAX(f.착공지수, order=(2,1,3), seasonal_order=(0,1,0,52))
result = model_area.fit()
weather_week_future_area = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('착공지수')
f.착공지수.plot(figsize=(12,5),legend=True)
weather_week_future_area.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
weather_week_future_area = pd.DataFrame(weather_week_future_area)
weather_week_future_area[weather_week_future_area['착공지수']<0] = 0

# %%
weather_week_future_area.to_csv('미래변수_착공면적.csv')

# %% [markdown]
# ### 출하량

# %%
# 출하량
g = shipment_week
train = g.iloc[:len(b)-29]
test = g.iloc[len(b)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=225.173, Time=0.13 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=227.170, Time=0.87 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=229.171, Time=1.10 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=231.171, Time=2.56 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=inf, Time=1.27 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=inf, Time=2.07 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=231.166, Time=6.54 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=233.171, Time=2.54 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=inf, Time=2.15 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=inf, Time=7.54 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=233.166, Time=7.66 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=235.171, Time=3.33 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=inf, Time=5.71 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=inf, Time=17.24 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=235.165, Time=19.21 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=226.409, Time=0.19 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=228.407, Time=0.65 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=230.407, Time=1.57 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=232.407, Time=3.19 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=228.407, Time=0.76 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=230.407, Time=0.80 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=232.407, Time=1.80 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=234.407, Time=3.55 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=230.407, Time=1.86 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=232.407, Time=1.89 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=234.407, Time=2.27 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=232.407, Time=4.15 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=234.407, Time=4.13 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=227.730, Time=0.23 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=229.725, Time=1.07 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=inf, Time=7.66 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=inf, Time=15.11 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=229.717, Time=3.81 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=231.717, Time=3.96 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=inf, Time=9.12 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=231.717, Time=8.54 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=233.717, Time=10.72 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=233.717, Time=19.10 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=inf, Time=0.63 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=inf, Time=4.93 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=inf, Time=7.64 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=230.756, Time=4.95 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=232.766, Time=4.62 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=232.757, Time=9.88 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=226.348, Time=0.15 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=228.345, Time=0.66 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=230.345, Time=3.40 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=inf, Time=12.98 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=228.345, Time=0.79 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=inf, Time=3.75 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=232.345, Time=4.18 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=234.345, Time=7.83 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=230.345, Time=1.81 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=inf, Time=10.06 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=234.345, Time=5.91 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=232.345, Time=4.21 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=234.342, Time=19.70 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=228.330, Time=0.22 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=230.327, Time=0.73 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=inf, Time=7.73 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=inf, Time=15.85 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=230.324, Time=4.35 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=232.326, Time=4.64 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=234.326, Time=9.57 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=232.324, Time=10.33 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=234.328, Time=10.51 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=234.324, Time=20.87 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=229.119, Time=0.51 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=inf, Time=1.82 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=233.115, Time=3.60 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=231.115, Time=1.88 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=233.115, Time=1.89 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=233.115, Time=4.19 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=230.369, Time=1.11 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=inf, Time=3.80 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=232.370, Time=3.56 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=228.279, Time=0.19 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=inf, Time=3.69 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=inf, Time=7.77 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=inf, Time=15.84 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=inf, Time=4.16 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=232.273, Time=4.59 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=inf, Time=8.71 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=inf, Time=9.31 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=234.273, Time=10.63 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=inf, Time=19.77 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=inf, Time=0.67 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=inf, Time=3.77 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=inf, Time=8.46 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=inf, Time=4.56 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=inf, Time=4.98 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=inf, Time=10.58 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=inf, Time=1.20 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=230.295, Time=5.09 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=230.233, Time=5.86 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=inf, Time=0.80 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=228.578, Time=0.37 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=230.575, Time=1.28 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=232.575, Time=2.88 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=230.575, Time=1.38 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=232.574, Time=1.51 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=232.575, Time=3.12 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=230.563, Time=0.47 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=232.560, Time=1.82 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=232.557, Time=5.19 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=inf, Time=1.30 sec
#
# Best model:  ARIMA(0,1,0)(0,1,0)[52]
# Total fit time: 552.023 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 52)   Log Likelihood                -111.586
# Date:                            Fri, 25 Nov 2022   AIC                            225.173
# Time:                                    20:34:21   BIC                            226.308
# Sample:                                01-07-2020   HQIC                           225.458
#                                      - 06-15-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       958.3553    158.153      6.060      0.000     648.382    1268.329
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.55   Jarque-Bera (JB):                18.60
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                            -0.73
# Prob(H) (two-sided):                  0.01   Kurtosis:                         7.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 3개월(12주) 예측

model_out = SARIMAX(g.출하량, order=(2,1,2), seasonal_order=(0,1,0,52))
result = model_out.fit()
weather_week_future_out = result.predict(start=len(a),end=(len(a)-1)+12,
                         typ = 'level').rename('출하량')
g.출하량.plot(figsize=(12,5),legend=True)
weather_week_future_out.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
weather_week_future_out = pd.DataFrame(weather_week_future_out)
weather_week_future_out
# Out:
#                출하량
# 2022-01-11  399.63
# 2022-01-18  470.31
# 2022-01-25  492.97
# 2022-02-01  576.46
# 2022-02-08  683.43
# 2022-02-15  712.01
# 2022-02-22  714.50
# 2022-03-01  819.34
# 2022-03-08 1033.46
# 2022-03-15 1046.22
# 2022-03-22 1043.98
# 2022-03-29 1052.84

# %%
weather_week_future_out.to_csv('미래변수_출하량.csv')

# %% [markdown]
# ### 예상중량

# %%
data20_21_detail_week['제품명'].unique()
# Out:
# array(['PEMA-HR1000', 'PEMA-PR1000', 'PEMA-SR2000', 'PEMA-SR3000F',
#        'CSA4000', 'CSA5000', 'PEMA-500FR', 'PEMA-580FX', 'PEMA-CR1000',
#        'PEMA-CSA5000', 'PEMA-HR1500', 'PEMA-SN400', 'PEMA-SR2000A', 'AE',
#        'PEMA-PCM2000', 'PEMA-PR2000', 'SRE-110', 'PEMA-PCM2000B',
#        'PR1000', 'PEMA-PCR3000E', 'PEMA-SR5000F', 'PEMA-PCR3000N',
#        'PEMA-SP1000', 'SRE-200', 'PEMA-SPR', 'ARE-580FX', 'PEMA-HR1000S'],
#       dtype=object)

# %%
data20_21_detail_week.iloc[:,2:3]
# Out:
#               예상중량
# 2020-01-07  255282
# 2020-01-14  288981
# 2020-01-21  681518
# 2020-01-28  319167
# 2020-02-04  689827
# ...            ...
# 2021-12-07       0
# 2021-12-14   11002
# 2021-12-21       0
# 2021-12-28   12603
# 2022-01-04       0
#
# [2835 rows x 1 columns]

# %%
# 예상중량
h = data20_21_detail_week.iloc[:,2:3]
train = h.iloc[:len(h)-29]
test = h.iloc[len(h)-29:]

# %%
auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=3, max_q=3,m=52,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[52]             : AIC=139.672, Time=0.10 sec
#  ARIMA(0,1,0)(0,1,1)[52]             : AIC=141.672, Time=0.23 sec
#  ARIMA(0,1,0)(0,1,2)[52]             : AIC=143.672, Time=0.58 sec
#  ARIMA(0,1,0)(0,1,3)[52]             : AIC=145.672, Time=1.26 sec
#  ARIMA(0,1,0)(1,1,0)[52]             : AIC=141.672, Time=0.16 sec
#  ARIMA(0,1,0)(1,1,1)[52]             : AIC=143.672, Time=0.24 sec
#  ARIMA(0,1,0)(1,1,2)[52]             : AIC=145.672, Time=0.67 sec
#  ARIMA(0,1,0)(1,1,3)[52]             : AIC=147.672, Time=1.33 sec
#  ARIMA(0,1,0)(2,1,0)[52]             : AIC=143.672, Time=0.46 sec
#  ARIMA(0,1,0)(2,1,1)[52]             : AIC=145.672, Time=0.63 sec
#  ARIMA(0,1,0)(2,1,2)[52]             : AIC=147.672, Time=1.13 sec
#  ARIMA(0,1,0)(2,1,3)[52]             : AIC=149.672, Time=2.40 sec
#  ARIMA(0,1,0)(3,1,0)[52]             : AIC=145.672, Time=1.39 sec
#  ARIMA(0,1,0)(3,1,1)[52]             : AIC=147.672, Time=1.88 sec
#  ARIMA(0,1,0)(3,1,2)[52]             : AIC=149.672, Time=1.86 sec
#  ARIMA(0,1,1)(0,1,0)[52]             : AIC=128.796, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,1)[52]             : AIC=130.796, Time=0.54 sec
#  ARIMA(0,1,1)(0,1,2)[52]             : AIC=132.796, Time=1.36 sec
#  ARIMA(0,1,1)(0,1,3)[52]             : AIC=134.796, Time=2.68 sec
#  ARIMA(0,1,1)(1,1,0)[52]             : AIC=130.796, Time=0.55 sec
#  ARIMA(0,1,1)(1,1,1)[52]             : AIC=132.796, Time=0.67 sec
#  ARIMA(0,1,1)(1,1,2)[52]             : AIC=134.796, Time=1.63 sec
#  ARIMA(0,1,1)(1,1,3)[52]             : AIC=136.796, Time=3.03 sec
#  ARIMA(0,1,1)(2,1,0)[52]             : AIC=132.796, Time=1.37 sec
#  ARIMA(0,1,1)(2,1,1)[52]             : AIC=134.796, Time=1.59 sec
#  ARIMA(0,1,1)(2,1,2)[52]             : AIC=136.796, Time=1.98 sec
#  ARIMA(0,1,1)(3,1,0)[52]             : AIC=134.796, Time=3.27 sec
#  ARIMA(0,1,1)(3,1,1)[52]             : AIC=136.796, Time=3.81 sec
#  ARIMA(0,1,2)(0,1,0)[52]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,2)(0,1,1)[52]             : AIC=inf, Time=0.46 sec
#  ARIMA(0,1,2)(0,1,2)[52]             : AIC=inf, Time=0.96 sec
#  ARIMA(0,1,2)(0,1,3)[52]             : AIC=inf, Time=2.00 sec
#  ARIMA(0,1,2)(1,1,0)[52]             : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,2)(1,1,1)[52]             : AIC=inf, Time=0.67 sec
#  ARIMA(0,1,2)(1,1,2)[52]             : AIC=inf, Time=1.46 sec
#  ARIMA(0,1,2)(2,1,0)[52]             : AIC=inf, Time=1.11 sec
#  ARIMA(0,1,2)(2,1,1)[52]             : AIC=inf, Time=1.40 sec
#  ARIMA(0,1,2)(3,1,0)[52]             : AIC=inf, Time=2.40 sec
#  ARIMA(0,1,3)(0,1,0)[52]             : AIC=131.934, Time=0.27 sec
#  ARIMA(0,1,3)(0,1,1)[52]             : AIC=133.934, Time=0.99 sec
#  ARIMA(0,1,3)(0,1,2)[52]             : AIC=135.934, Time=2.27 sec
#  ARIMA(0,1,3)(1,1,0)[52]             : AIC=133.934, Time=1.24 sec
#  ARIMA(0,1,3)(1,1,1)[52]             : AIC=135.934, Time=0.93 sec
#  ARIMA(0,1,3)(2,1,0)[52]             : AIC=135.934, Time=1.98 sec
#  ARIMA(1,1,0)(0,1,0)[52]             : AIC=136.591, Time=0.08 sec
#  ARIMA(1,1,0)(0,1,1)[52]             : AIC=138.591, Time=0.36 sec
#  ARIMA(1,1,0)(0,1,2)[52]             : AIC=140.591, Time=0.89 sec
#  ARIMA(1,1,0)(0,1,3)[52]             : AIC=142.591, Time=1.79 sec
#  ARIMA(1,1,0)(1,1,0)[52]             : AIC=138.591, Time=0.44 sec
#  ARIMA(1,1,0)(1,1,1)[52]             : AIC=140.591, Time=0.44 sec
#  ARIMA(1,1,0)(1,1,2)[52]             : AIC=142.591, Time=1.03 sec
#  ARIMA(1,1,0)(1,1,3)[52]             : AIC=144.591, Time=2.17 sec
#  ARIMA(1,1,0)(2,1,0)[52]             : AIC=140.591, Time=1.01 sec
#  ARIMA(1,1,0)(2,1,1)[52]             : AIC=142.591, Time=1.13 sec
#  ARIMA(1,1,0)(2,1,2)[52]             : AIC=144.591, Time=1.34 sec
#  ARIMA(1,1,0)(3,1,0)[52]             : AIC=142.591, Time=2.24 sec
#  ARIMA(1,1,0)(3,1,1)[52]             : AIC=144.591, Time=2.67 sec
#  ARIMA(1,1,1)(0,1,0)[52]             : AIC=130.545, Time=0.14 sec
#  ARIMA(1,1,1)(0,1,1)[52]             : AIC=132.545, Time=0.62 sec
#  ARIMA(1,1,1)(0,1,2)[52]             : AIC=134.545, Time=1.30 sec
#  ARIMA(1,1,1)(0,1,3)[52]             : AIC=136.545, Time=2.58 sec
#  ARIMA(1,1,1)(1,1,0)[52]             : AIC=132.545, Time=0.62 sec
#  ARIMA(1,1,1)(1,1,1)[52]             : AIC=134.545, Time=0.73 sec
#  ARIMA(1,1,1)(1,1,2)[52]             : AIC=136.545, Time=1.57 sec
#  ARIMA(1,1,1)(2,1,0)[52]             : AIC=134.545, Time=1.49 sec
#  ARIMA(1,1,1)(2,1,1)[52]             : AIC=136.545, Time=1.92 sec
#  ARIMA(1,1,1)(3,1,0)[52]             : AIC=136.545, Time=3.47 sec
#  ARIMA(1,1,2)(0,1,0)[52]             : AIC=132.531, Time=0.16 sec
#  ARIMA(1,1,2)(0,1,1)[52]             : AIC=134.531, Time=0.69 sec
#  ARIMA(1,1,2)(0,1,2)[52]             : AIC=136.531, Time=1.52 sec
#  ARIMA(1,1,2)(1,1,0)[52]             : AIC=134.531, Time=0.76 sec
#  ARIMA(1,1,2)(1,1,1)[52]             : AIC=136.531, Time=0.88 sec
#  ARIMA(1,1,2)(2,1,0)[52]             : AIC=136.531, Time=1.75 sec
#  ARIMA(1,1,3)(0,1,0)[52]             : AIC=inf, Time=1.06 sec
#  ARIMA(1,1,3)(0,1,1)[52]             : AIC=inf, Time=3.64 sec
#  ARIMA(1,1,3)(1,1,0)[52]             : AIC=inf, Time=4.03 sec
#  ARIMA(2,1,0)(0,1,0)[52]             : AIC=132.963, Time=0.14 sec
#  ARIMA(2,1,0)(0,1,1)[52]             : AIC=134.963, Time=0.55 sec
#  ARIMA(2,1,0)(0,1,2)[52]             : AIC=136.963, Time=1.27 sec
#  ARIMA(2,1,0)(0,1,3)[52]             : AIC=138.963, Time=2.75 sec
#  ARIMA(2,1,0)(1,1,0)[52]             : AIC=134.963, Time=0.57 sec
#  ARIMA(2,1,0)(1,1,1)[52]             : AIC=136.963, Time=0.68 sec
#  ARIMA(2,1,0)(1,1,2)[52]             : AIC=138.963, Time=1.61 sec
#  ARIMA(2,1,0)(2,1,0)[52]             : AIC=136.963, Time=1.74 sec
#  ARIMA(2,1,0)(2,1,1)[52]             : AIC=138.963, Time=1.84 sec
#  ARIMA(2,1,0)(3,1,0)[52]             : AIC=138.963, Time=3.43 sec
#  ARIMA(2,1,1)(0,1,0)[52]             : AIC=131.659, Time=0.21 sec
#  ARIMA(2,1,1)(0,1,1)[52]             : AIC=133.659, Time=0.79 sec
#  ARIMA(2,1,1)(0,1,2)[52]             : AIC=135.659, Time=1.70 sec
#  ARIMA(2,1,1)(1,1,0)[52]             : AIC=133.659, Time=0.88 sec
#  ARIMA(2,1,1)(1,1,1)[52]             : AIC=135.659, Time=1.17 sec
#  ARIMA(2,1,1)(2,1,0)[52]             : AIC=135.659, Time=2.50 sec
#  ARIMA(2,1,2)(0,1,0)[52]             : AIC=133.589, Time=0.34 sec
#  ARIMA(2,1,2)(0,1,1)[52]             : AIC=135.589, Time=1.34 sec
#  ARIMA(2,1,2)(1,1,0)[52]             : AIC=135.589, Time=1.34 sec
#  ARIMA(2,1,3)(0,1,0)[52]             : AIC=inf, Time=1.27 sec
#  ARIMA(3,1,0)(0,1,0)[52]             : AIC=133.493, Time=0.21 sec
#  ARIMA(3,1,0)(0,1,1)[52]             : AIC=135.493, Time=0.79 sec
#  ARIMA(3,1,0)(0,1,2)[52]             : AIC=137.493, Time=1.96 sec
#  ARIMA(3,1,0)(1,1,0)[52]             : AIC=135.493, Time=0.90 sec
#  ARIMA(3,1,0)(1,1,1)[52]             : AIC=137.493, Time=0.97 sec
#  ARIMA(3,1,0)(2,1,0)[52]             : AIC=137.493, Time=2.16 sec
#  ARIMA(3,1,1)(0,1,0)[52]             : AIC=133.592, Time=0.30 sec
#  ARIMA(3,1,1)(0,1,1)[52]             : AIC=135.592, Time=1.18 sec
#  ARIMA(3,1,1)(1,1,0)[52]             : AIC=135.592, Time=1.30 sec
#  ARIMA(3,1,2)(0,1,0)[52]             : AIC=135.589, Time=0.89 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[52]
# Total fit time: 137.421 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   76
# Model:             SARIMAX(0, 1, 1)x(0, 1, [], 52)   Log Likelihood                 -62.398
# Date:                             Sat, 26 Nov 2022   AIC                            128.796
# Time:                                     00:01:50   BIC                            131.067
# Sample:                                 01-07-2020   HQIC                           129.367
#                                       - 06-15-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9502      0.234     -4.053      0.000      -1.410      -0.491
# sigma2        12.0690      4.755      2.538      0.011       2.750      21.388
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.43   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.50   Skew:                            -0.20
# Prob(H) (two-sided):                  0.35   Kurtosis:                         3.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings;warnings.filterwarnings('ignore')

# %%
li = []
for i in data20_21_detail_week['제품명'].unique():
    h = data20_21_detail_week[data20_21_detail_week['제품명']==i]    
    
    
    model_pred_weight = SARIMAX(h.예상중량, order=(2,1,2), seasonal_order=(0,1,0,52))
    result = model_pred_weight.fit()
    weather_week_future_pred_weight = result.predict(start=len(h),end=(len(h)-1)+12,
                             typ = 'level').rename('예상중량')
    weather_week_future_pred_weight = pd.DataFrame(weather_week_future_pred_weight)
    weather_week_future_pred_weight['제품명'] = i
    li.append(weather_week_future_pred_weight)

# %%
weather_week_future_pred_weight = pd.concat(li)
# weather_week_future_pred_weight[weather_week_future_pred_weight['예상중량']<0]['예상중량'] = 0
weather_week_future_pred_weight['예상중량'].loc[weather_week_future_pred_weight['예상중량'] < 0] = 0
weather_week_future_pred_weight
# Out:
#                 예상중량           제품명
# 2022-01-11 147591.41   PEMA-HR1000
# 2022-01-18 356635.87   PEMA-HR1000
# 2022-01-25 331020.94   PEMA-HR1000
# 2022-02-01 415776.29   PEMA-HR1000
# 2022-02-08 880893.14   PEMA-HR1000
# ...              ...           ...
# 2022-03-01    228.19  PEMA-HR1000S
# 2022-03-08    225.13  PEMA-HR1000S
# 2022-03-15    226.37  PEMA-HR1000S
# 2022-03-22    226.34  PEMA-HR1000S
# 2022-03-29    226.09  PEMA-HR1000S
#
# [324 rows x 2 columns]

# %%
weather_week_future_pred_weight[weather_week_future_pred_weight['예상중량']==0]
# Out:
#             예상중량           제품명
# 2022-03-08  0.00   PEMA-SR2000
# 2022-02-01  0.00       CSA4000
# 2022-02-08  0.00       CSA4000
# 2022-01-11  0.00    PEMA-500FR
# 2022-02-22  0.00    PEMA-500FR
# ...          ...           ...
# 2022-03-08  0.00      PEMA-SPR
# 2022-03-15  0.00      PEMA-SPR
# 2022-03-22  0.00      PEMA-SPR
# 2022-03-29  0.00      PEMA-SPR
# 2022-01-11  0.00  PEMA-HR1000S
#
# [61 rows x 2 columns]

# %%
weather_week_future_pred_weight.to_csv('미래변수_예상중량.csv')

# %% [markdown]
# ## 학습 및 평가

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# 모델 생성
# lr_clf = LogisticRegression()
lr_clf = LinearRegression()

# 피쳐, 타겟 지정
x_feature = dataset_detail_week.drop(['수주량'],axis=1)
y_label = dataset_detail_week['수주량'].values

x_train,x_test,y_train,y_test = train_test_split(x_feature,y_label,test_size=0.2, random_state=10)

lr_clf.fit(x_train,y_train)
pred=lr_clf.predict(x_test)

mse = mean_squared_error(y_test,pred)
mae = mean_absolute_error(y_test,pred)
r2 = r2_score(y_test,pred)

print(np.sqrt(mse))
print(mae)
print(r2)
# Out:
# 20961.975493119564
# 9135.652599677838
# 0.9675801881628598

# %%
# 모델 생성
# lr_clf = LogisticRegression()
lr_clf = LinearRegression()

# 피쳐, 타겟 지정
x_feature = dataset_detail_week.drop(['수주량'],axis=1)
y_label = dataset_detail_week['수주량'].values

x_train,x_test,y_train,y_test = train_test_split(x_feature,y_label,test_size=0.2, random_state=10)

lr_clf.fit(x_train,y_train)
pred=lr_clf.predict(x_test)

mse = mean_squared_error(y_test,pred)
mae = mean_absolute_error(y_test,pred)
r2 = r2_score(y_test,pred)

print(np.sqrt(mse))
print(mae)
print(r2)

# %%
y_test
# Out:
# array([     0.,  10000.,   7000.,  35000.,      0.,  44000.,  10000.,
#         46000., 558000., 364000., 120000.,      0.,      0.,   4000.,
#             0.,  15000., 483000.,  45000.,      0.,  30000.,  72570.,
#             0., 115000.,      0., 186000.,      0.,  20000., 491000.,
#             0.,  10000.,  55000.,  60000.,  45000.,      0., 517000.,
#        494000.,  35000.,  10000.,  75000.,  46000.,  90000.,  10000.,
#         10000.,   7000., 100000.,  82000.,  10000.,      0., 821550.,
#         41000.,  13000., 185000.,  12000.,      0.,      0.,  50000.,
#         95000.,  22000.,      0.,  87000., 105000.,  43000.,  86000.,
#         17000.,  20000.,      0.,  10000.,   5000.,  18000.,  70000.,
#             0.,      0.,      0., 224000.,      0.,  28000.,      0.,
#        170000.,   8000., 135000.,      0.,      0.,  48000., 264000.,
#        285000., 461000.,   6000.,  44000.,  35000.,  46000.,  80000.,
#         20000.,      0.,  82000.,  20000.,  20000., 165000.,      0.,
#         20000.,      0.,  28000.,   5000.,   2000.,  15000.,  37000.,
#         10000.,  18000.,  10000.,  27000., 679000.,      0.,  69000.,
#        568000.,  46000.,   7000.,      0.,   3000.,  65000.,      0.,
#             0.,      0., 107570.,  10000.,      0., 178000.,  76000.,
#         30000.,  46000.,  24000.,   5000.,  42000., 395000.,  20000.,
#          4000.,      0.,      0.,  52000.,   5000.,  55000.,  56000.,
#             0.,   5000., 160000.,      0.,  30000.,      0., 193000.,
#             0.,      0.,      0.,   6000., 197000.,  27000.,      0.,
#        212000., 257000.,      0.,  10000.,  55000.,  39600.,  97000.,
#             0.,      0.,   5000.,  70000.,  17000.,   3000.,      0.,
#             0.,      0.,  17000.,  30000.,  31000.,      0.,  36000.,
#          5000.,      0.,  10000.,  15000.,   5000.,      0., 110000.,
#             0.,  10000.,  15000.,  10000.,  20000., 196000.,  60000.,
#         59000.,  10000.,  30000.,      0.,      0.,  46000.,      0.,
#             0.,      0., 463000., 227000.,   6000.,  71000.,      0.,
#         10000.,      0.,      0.,      0.,      0.,      0.,  10000.,
#             0.,   6000.,  17000.,  10000.,      0.,  23000.,  57000.,
#         17000.,      0.,  12000.,  75000.,      0.,  55000.,      0.,
#             0.,      0.,  25000.,  10000.,  43000.,      0.,  10000.,
#        148000., 119000.,  52000.,   4000.,      0., 297000.,      0.,
#             0.,      0.,   5000., 120000.,  69000.,  57000.,  21000.,
#             0.,      0.,   7000.,  10000.,      0.,      0.,      0.,
#        272000.,  10000.,      0.,      0.,  12100.,  39600.,  12000.,

#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2021-03-09  ...           0            0         0            0             0
# 2021-07-20  ...           0            0         0            0             0
# 2021-11-30  ...           0            1         0            0             0
# 2020-10-27  ...           0            0         0            0             0
# 2020-03-10  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2021-03-09             0             0       0        0        0
# 2021-07-20             0             0       0        0        0
# 2021-11-30             0             0       0        0        0
# 2020-10-27             0             0       0        0        0
# 2020-03-10             0             0       0        0        0
#
# [5 rows x 35 columns]

# %%
weather_week_future_temp = pd.read_csv('미래변수_온도.csv',index_col=0)
weather_week_future_rain =  pd.read_csv('미래변수_강수량.csv',index_col=0)
weather_week_future_humidity =  pd.read_csv('미래변수_습도.csv',index_col=0)
weather_week_future_snow =  pd.read_csv('미래변수_적설량.csv',index_col=0)
weather_week_future_rate =  pd.read_csv('미래변수_금리.csv',index_col=0)
weather_week_future_area =  pd.read_csv('미래변수_착공면적.csv',index_col=0)
weather_week_future_out =  pd.read_csv('미래변수_출하량.csv',index_col=0)
weather_week_future_pred_weight =  pd.read_csv('미래변수_예상중량.csv',index_col=0)

# %%
dataset_detail_week_pred = weather_week_future_temp.join([weather_week_future_rain,weather_week_future_humidity,weather_week_future_snow,
                               weather_week_future_rate,weather_week_future_area,weather_week_future_out,weather_week_future_pred_weight])
dataset_detail_week_pred = pd.concat([dataset_detail_week_pred, pd.get_dummies(dataset_detail_week_pred['제품명'])],axis=1).drop(columns='제품명',axis=1)
dataset_detail_week_pred
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수     출하량      예상중량  AE  \
# 2022-01-11 -5.90  0.00 63.44  0.36  1.00  0.00  399.63 147591.41   0
# 2022-01-11 -5.90  0.00 63.44  0.36  1.00  0.00  399.63  98599.56   0
# 2022-01-11 -5.90  0.00 63.44  0.36  1.00  0.00  399.63  18170.07   0
# 2022-01-11 -5.90  0.00 63.44  0.36  1.00  0.00  399.63   6828.78   0
# 2022-01-11 -5.90  0.00 63.44  0.36  1.00  0.00  399.63   7014.14   0
# ...          ...   ...   ...   ...   ...   ...     ...       ...  ..
# 2022-03-29 13.01  3.75 63.44  0.00  1.00  0.81 1052.84   7749.54   0
# 2022-03-29 13.01  3.75 63.44  0.00  1.00  0.81 1052.84     22.51   0
# 2022-03-29 13.01  3.75 63.44  0.00  1.00  0.81 1052.84      0.00   0
# 2022-03-29 13.01  3.75 63.44  0.00  1.00  0.81 1052.84    183.90   0
# 2022-03-29 13.01  3.75 63.44  0.00  1.00  0.81 1052.84    226.09   0
#
#             ARE-580FX  ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  \
# 2022-01-11          0  ...           0            0         0            0
# 2022-01-11          0  ...           0            0         0            0
# 2022-01-11          0  ...           0            0         0            1
# 2022-01-11          0  ...           0            0         0            0
# 2022-01-11          0  ...           0            0         0            0
# ...               ...  ...         ...          ...       ...          ...
# 2022-03-29          0  ...           0            1         0            0
# 2022-03-29          0  ...           0            0         0            0
# 2022-03-29          0  ...           0            0         1            0
# 2022-03-29          1  ...           0            0         0            0
# 2022-03-29          0  ...           0            0         0            0
#
#             PEMA-SR2000A  PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2022-01-11             0             0             0       0        0        0
# 2022-01-11             0             0             0       0        0        0
# 2022-01-11             0             0             0       0        0        0
# 2022-01-11             0             1             0       0        0        0
# 2022-01-11             0             0             0       0        0        0
# ...                  ...           ...           ...     ...      ...      ...
# 2022-03-29             0             0             0       0        0        0
# 2022-03-29             0             0             0       0        0        1
# 2022-03-29             0             0             0       0        0        0
# 2022-03-29             0             0             0       0        0        0
# 2022-03-29             0             0             0       0        0        0
#
# [324 rows x 35 columns]

# %%
dataset_detail_week_pred.columns[8:]
# Out:
# Index(['AE', 'ARE-580FX', 'CSA4000', 'CSA5000', 'PEMA-500FR', 'PEMA-580FX',
#        'PEMA-CR1000', 'PEMA-CSA5000', 'PEMA-HR1000', 'PEMA-HR1000S',
#        'PEMA-HR1500', 'PEMA-PCM2000', 'PEMA-PCM2000B', 'PEMA-PCR3000E',
#        'PEMA-PCR3000N', 'PEMA-PR1000', 'PEMA-PR2000', 'PEMA-SN400',
#        'PEMA-SP1000', 'PEMA-SPR', 'PEMA-SR2000', 'PEMA-SR2000A',
#        'PEMA-SR3000F', 'PEMA-SR5000F', 'PR1000', 'SRE-110', 'SRE-200'],
#       dtype='object')

# %%
dataset_detail_week.columns[9:]
# Out:
# Index(['AE', 'ARE-580FX', 'CSA4000', 'CSA5000', 'PEMA-500FR', 'PEMA-580FX',
#        'PEMA-CR1000', 'PEMA-CSA5000', 'PEMA-HR1000', 'PEMA-HR1000S',
#        'PEMA-HR1500', 'PEMA-PCM2000', 'PEMA-PCM2000B', 'PEMA-PCR3000E',
#        'PEMA-PCR3000N', 'PEMA-PR1000', 'PEMA-PR2000', 'PEMA-SN400',
#        'PEMA-SP1000', 'PEMA-SPR', 'PEMA-SR2000', 'PEMA-SR2000A',
#        'PEMA-SR3000F', 'PEMA-SR5000F', 'PR1000', 'SRE-110', 'SRE-200'],
#       dtype='object')

# %%
real_pred=lr_clf.predict(dataset_detail_week_pred)
real_pred = pd.DataFrame(real_pred,columns=['수주량']).set_index(dataset_detail_week_pred.index)
real_pred[real_pred['수주량']<0] = 0
real_pred = pd.concat([real_pred,dataset_detail_week_pred],axis=1)
real_pred.head(50)
# Out:
#                  수주량  평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량      예상중량  AE  \
# 2022-01-11 261667.75 -5.90  0.00 63.44  0.36  1.00  0.00 399.63 147591.41   0
# 2022-01-11  98651.46 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  98599.56   0
# 2022-01-11  32454.40 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  18170.07   0
# 2022-01-11  15250.85 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   6828.78   0
# 2022-01-11   4240.03 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   7014.14   0
# 2022-01-11  84973.21 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  26581.05   0
# 2022-01-11   6362.63 -5.90  0.00 63.44  0.36  1.00  0.00 399.63      0.00   0
# 2022-01-11  19230.81 -5.90  0.00 63.44  0.36  1.00  0.00 399.63      0.00   0
# 2022-01-11   1062.95 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   6869.96   0
# 2022-01-11      0.00 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   1768.01   0
# 2022-01-11  74725.26 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  22566.18   0
# 2022-01-11   6299.66 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   4396.07   0
# 2022-01-11    531.98 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   4491.08   0
# 2022-01-11   8595.24 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  14488.49   1
# 2022-01-11   6873.04 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  11244.87   0
# 2022-01-11   9326.69 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   6879.13   0
# 2022-01-11      0.00 -5.90  0.00 63.44  0.36  1.00  0.00 399.63      0.00   0
# 2022-01-11      0.00 -5.90  0.00 63.44  0.36  1.00  0.00 399.63   1608.08   0
# 2022-01-11   3457.94 -5.90  0.00 63.44  0.36  1.00  0.00 399.63  11318.63   0
# 2022-01-11      0.00 -5.90  0.00 63.44  0.36  1.00  0.00 399.
# 2022-03-01 33692.46  6.95  7.08 68.48  0.04  1.00  0.61  819.34 35644.62   0
# 2022-03-08 44351.26  7.40  0.00 73.29  0.04  1.00  0.76 1033.46 49251.75   0
# 2022-03-15 17765.79 10.36  1.44 69.70  0.01  1.00  0.78 1046.22 10084.82   0
# 2022-03-22 43118.51 10.02  0.07 63.85  0.00  1.00  0.80 1043.98 44971.74   0
# 2022-03-29 16581.40 13.01  3.75 63.44  0.00  1.00  0.81 1052.84  6866.40   0
#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2022-01-11  ...           0            0         0            0             0
# 2022-01-18  ...           0            0         0            0             0
# 2022-01-25  ...           0            0         0            0             0
# 2022-02-01  ...           0            0         0            0             0
# 2022-02-08  ...           0            0         0            0             0
# 2022-02-15  ...           0            0         0            0             0
# 2022-02-22  ...           0            0         0            0             0
# 2022-03-01  ...           0            0         0            0             0
# 2022-03-08  ...           0            0         0            0             0
# 2022-03-15  ...           0            0         0            0             0
# 2022-03-22  ...           0            0         0            0             0
# 2022-03-29  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2022-01-11             0             0       0        0        0
# 2022-01-18             0             0       0        0        0
# 2022-01-25             0             0       0        0        0
# 2022-02-01             0             0       0        0        0
# 2022-02-08             0             0       0        0        0
# 2022-02-15             0             0       0        0        0
# 2022-02-22             0             0       0        0        0
# 2022-03-01             0             0       0        0        0
# 2022-03-08             0             0       0        0        0
# 2022-03-15             0             0       0        0        0
# 2022-03-22             0             0       0        0        0
# 2022-03-29             0             0       0        0        0
#
# [12 rows x 36 columns]

# %%
real_pred = pd.read_csv('3개월 예측 데이터셋.csv',index_col=0)

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(real_pred)),real_pred['수주량'],'r')

# %%
plt.plot(range(len(real_pred)),real_pred['예상중량'],'r')

# %%
mse = mean_squared_error(real_pred['수주량'],real_pred['예상중량'])
mae = mean_absolute_error(real_pred['수주량'],real_pred['예상중량'])
r2 = r2_score(real_pred['수주량'],real_pred['예상중량'])

print(np.sqrt(mse))
print(mae)
print(r2)
# Out:
# 15736.794813533797
# 7022.696660452908
# 0.9768052926555864

# %% [markdown]
# # 월 단위 데이터셋 생성 (사용하지 않음)

# %% [markdown]
# ## 수주량

# %%
# 월 단위 수주량 합계 데이터셋
data20_21_total_month = data20_21.copy()
data20_21_total_month = data20_21_total_month.pivot_table('수주량',index=['수주월'], aggfunc='sum')
data20_21_total_month
# Out:
#              수주량
# 수주월
# 2020-01  4808400
# 2020-02  6317320
# 2020-03  7712350
# 2020-04  7157310
# 2020-05  7712350
# 2020-06  5784210
# 2020-07  6645350
# 2020-08  6182310
# 2020-09  7566350
# 2020-10  7057310
# 2020-11  7567350
# 2020-12  6274150
# 2021-01  4630400
# 2021-02  6145320
# 2021-03  7712350
# 2021-04  7157310
# 2021-05  7712350
# 2021-06  6191210
# 2021-07  7007350
# 2021-08  6449310
# 2021-09  6952350
# 2021-10  6579310
# 2021-11  7032350
# 2021-12  6042150

# %%
# 월 단위 (거래처별, 품목별) 수주량  합계 데이터셋
data20_21_detail_month = data20_21.copy()
data20_21_detail_month = data20_21_detail_month.pivot_table('수주량',index=['수주월','거래처코드','제품명'], aggfunc='sum')
data20_21_detail_month = data20_21_detail_month.reset_index()
data20_21_detail_month = data20_21_detail_month.set_index('수주월')
data20_21_detail_month
# Out:
#            거래처코드           제품명    수주량
# 수주월
# 2020-01  2001102            AE   3000
# 2020-01  2001102       CSA5000  23000
# 2020-01  2001102   PEMA-HR1000   7000
# 2020-01  2001102   PEMA-HR1500   4000
# 2020-01  2001102   PEMA-PR1000  20000
# ...          ...           ...    ...
# 2021-12  2007800   PEMA-HR1000  10000
# 2021-12  2007800   PEMA-HR1500  30000
# 2021-12  2007800  PEMA-PCM2000   5000
# 2021-12  2007800   PEMA-SR2000  36000
# 2021-12  2007800  PEMA-SR3000F  10000
#
# [10084 rows x 3 columns]

# %% [markdown]
# ## 날씨

# %%
# 월 단위 날씨
weather_month = weather.copy()
weather_month['년월'] = weather_month['날짜'].apply(yearmonth)
# weather['날짜'] = pd.to_datetime(weather['날짜'])

weather_month = weather_month.pivot_table(['평균온도','일강수량','상대습도','최심적설'],index='년월',aggfunc='mean')
weather_month.head(3)
# Out:
#          상대습도  일강수량  최심적설  평균온도
# 년월
# 2020-01    68     3     0     3
# 2020-02    67     2     0     4
# 2020-03    61     1     0     8

# %% [markdown]
# ## 착공면적

# %%
construction_month = construction.copy()
construction_month = construction_month.set_index('Month')
construction_month.head(3)
# Out:
#              연면적별
# Month
# 2020-01   6200509
# 2020-02   7743793
# 2020-03  11972937

# %% [markdown]
# ## 금리

# %%
rate_month = rate.copy().set_index('index')
rate_month.head(3)
# Out:
#          기준금리
# index
# 2020-01     1
# 2020-02     1
# 2020-03     1

# %% [markdown]
# ## 데이터셋

# %%
dataset_total_month = weather_month.join([rate_month,construction_month,data20_21_total_month])
dataset_total_month
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별      수주량
# 년월
# 2020-01    68     3     0     3     1   6200509  4808400
# 2020-02    67     2     0     4     1   7743793  6317320
# 2020-03    61     1     0     8     1  11972937  7712350
# 2020-04    56     1     0    11     1  10481354  7157310
# 2020-05    73     4     0    18     0  10999316  7712350
# 2020-06    76     6     0    23     0  10255271  5784210
# 2020-07    86    13     0    22     0  10658885  6645350
# 2020-08    85    13     0    27     0   8595586  6182310
# 2020-09    80     8     0    20     0  10775873  7566350
# 2020-10    69     0     0    14     0   9195394  7057310
# 2020-11    66     1     0     9     0  12312253  7567350
# 2020-12    60     0     0     1     0  12855085  6274150
# 2021-01    64     1     1    -1     0   7570978  4630400
# 2021-02    58     1     0     4     0  10178609  6145320
# 2021-03    68     4     0     9     0  12996528  7712350
# 2021-04    59     3     0    13     0  11765306  7157310
# 2021-05    71     4     0    17     0  12417941  7712350
# 2021-06    77     3     0    22     0  10857729  6191210
# 2021-07    81     8     0    26     0  10510350  7007350
# 2021-08    83     9     0    25     1   8974011  6449310
# 2021-09    81     5     0    22     1  11398360  6952350
# 2021-10    76     2     0    15     1  11618046  6579310
# 2021-11    70     2     0     9     1  11415255  7032350
# 2021-12    65     0     0     2     1  14132721  6042150

# %% [markdown]
# ## 상세 데이터셋

# %%
dataset_detail_month = weather_month.join([rate_month,construction_month,data20_21_detail_month])
dataset_detail_month
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별    거래처코드           제품명    수주량
# 2020-01    68     3     0     3     1   6200509  2001102            AE   3000
# 2020-01    68     3     0     3     1   6200509  2001102       CSA5000  23000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-HR1000   7000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-HR1500   4000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-PR1000  20000
# ...       ...   ...   ...   ...   ...       ...      ...           ...    ...
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-HR1000  10000
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-HR1500  30000
# 2021-12    65     0     0     2     1  14132721  2007800  PEMA-PCM2000   5000
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-SR2000  36000
# 2021-12    65     0     0     2     1  14132721  2007800  PEMA-SR3000F  10000
#
# [10084 rows x 9 columns]

# %%
dataset_detail_month[(dataset_detail_month['거래처코드']==2001102)&(dataset_detail_month['제품명']=='AE')]
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별    거래처코드 제품명   수주량
# 2020-01    68     3     0     3     1   6200509  2001102  AE  3000
# 2020-03    61     1     0     8     1  11972937  2001102  AE  3000
# 2020-05    73     4     0    18     0  10999316  2001102  AE  3000
# 2020-07    86    13     0    22     0  10658885  2001102  AE  3000
# 2020-09    80     8     0    20     0  10775873  2001102  AE  3000
# 2020-11    66     1     0     9     0  12312253  2001102  AE  3000
# 2021-01    64     1     1    -1     0   7570978  2001102  AE  3000
# 2021-03    68     4     0     9     0  12996528  2001102  AE  3000
# 2021-05    71     4     0    17     0  12417941  2001102  AE  3000
# 2021-07    81     8     0    26     0  10510350  2001102  AE  3000
# 2021-09    81     5     0    22     1  11398360  2001102  AE  3000
# 2021-11    70     2     0     9     1  11415255  2001102  AE  3000

# %%
for i in dataset_detail['거래처코드'].unique():
    for j in dataset_detail[dataset_detail['거래처코드']==i]['제품명'].unique():
        data = dataset_detail[(dataset_detail['거래처코드']==i)&(dataset_detail['제품명']==j)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '거래처코드'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [486], in <cell line: 1>()
# ----> 1 for i in dataset_detail['거래처코드'].unique():
#       2     for j in dataset_detail[dataset_detail['거래처코드']==i]['제품명'].unique():
#       3         data = dataset_detail[(dataset_detail['거래처코드']==i)&(dataset_detail['제품명']==j)]
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: '거래처코드'

# %%
from pmdarima import auto_arima

auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=5, max_q=3,m=12,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()
