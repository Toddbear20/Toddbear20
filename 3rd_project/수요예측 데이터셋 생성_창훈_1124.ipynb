# %%
import re
import pandas as pd
def yearmonth(x):
    p = re.compile('.{7}')
    return p.findall(x)[0]

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ## 각 데이터 불러오기

# %%
data20 = pd.read_csv('2020년_증식데이터_편집.csv', index_col=0)
data20['수주월'] = data20['수주일자'].apply(yearmonth)
data21 = pd.read_csv('2021년_증식데이터_편집.csv', index_col=0)
data21['수주월'] = data21['수주일자'].apply(yearmonth)

# 20년도 21년도 데이터 이어붙이기

data20_21 = pd.concat((data20,data21))
data20_21 = data20_21.sort_values(['수주일자','거래처코드','제품명'])

# %%
weather = pd.read_csv('전국평균날씨데이터.csv', index_col=0)
construction = pd.read_csv('연면적별.csv', index_col=0)
rate = pd.read_csv('월별 시장금리추이(202001_202112).csv',encoding='cp949',index_col=0).transpose().reset_index()

# %% [markdown]
# ## 빈 날짜 DF 생성

# %%
# 빈 날짜 데이터프레임 생성
start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('2021-12-31')
date_all = pd.date_range(start=start,end=end,freq='d')
# test = pd.DataFrame(index=date_all).join(data20_21_detail)
# test[test['거래처코드'].isnull()]

# %%
date_all = pd.date_range(start, end, freq='D').to_frame().rename(columns={0:'Date'}).reset_index(drop=True).set_index('Date')
date_all
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-01 00:00:00, 2020-01-02 00:00:00, 2020-01-03 00:00:00, 2020-01-04 00:00:00, 2020-01-05 00:00:00, 2020-01-06 00:00:00, 2020-01-07 00:00:00, 2020-01-08 00:00:00, 2020-01-09 00:00:00, 2020-01-10 00:00:00, 2020-01-11 00:00:00, 2020-01-12 00:00:00, 2020-01-13 00:00:00, 2020-01-14 00:00:00, 2020-01-15 00:00:00, 2020-01-16 00:00:00, 2020-01-17 00:00:00, 2020-01-18 00:00:00, 2020-01-19 00:00:00, 2020-01-20 00:00:00, 2020-01-21 00:00:00, 2020-01-22 00:00:00, 2020-01-23 00:00:00, 2020-01-24 00:00:00, 2020-01-25 00:00:00, 2020-01-26 00:00:00, 2020-01-27 00:00:00, 2020-01-28 00:00:00, 2020-01-29 00:00:00, 2020-01-30 00:00:00, 2020-01-31 00:00:00, 2020-02-01 00:00:00, 2020-02-02 00:00:00, 2020-02-03 00:00:00, 2020-02-04 00:00:00, 2020-02-05 00:00:00, 2020-02-06 00:00:00, 2020-02-07 00:00:00, 2020-02-08 00:00:00, 2020-02-09 00:00:00, 2020-02-10 00:00:00, 2020-02-11 00:00:00, 2020-02-12 00:00:00, 2020-02-13 00:00:00, 2020-02-14 00:00:00, 2020-02-15 00:00:00, 2020-02-16 00:00:00, 2020-02-17 00:00:00, 2020-02-18 00:00:00, 2020-02-19 00:00:00, 2020-02-20 00:00:00, 2020-02-21 00:00:00, 2020-02-22 00:00:00, 2020-02-23 00:00:00, 2020-02-24 00:00:00, 2020-02-25 00:00:00, 2020-02-26 00:00:00, 2020-02-27 00:00:00, 2020-02-28 00:00:00, 2020-02-29 00:00:00, 2020-03-01 00:00:00, 2020-03-02 00:00:00, 2020-03-03 00:00:00, 2020-03-04 00:00:00, 2020-03-05 00:00:00, 2020-03-06 00:00:00, 2020-03-07 00:00:00, 2020-03-08 00:00:00, 2020-03-09 00:00:00, 2020-03-10 00:00:00, 2020-03-11 00:00:00, 2020-03-12 00:00:00, 2020-03-13 00:00:00, 2020-03-14 00:00:00, 2020-03-15 00:00:00, 2020-03-16 00:00:00, 2020-03-17 00:00:00, 2020-03-18 00:00:00, 2020-03-19 00:00:00, 2020-03-20 00:00:00, 2020-03-21 00:00:00, 2020-03-22 00:00:00, 2020-03-23 00:00:00, 2020-03-24 00:00:00, 2020-03-25 00:00:00, 2020-03-26 00:00:00, 2020-03-27 00:00:00, 2020-03-28 00:00:00, 2020-03-29 00:00:00, 2020-03-30 00:00:00, 2020-03-31 00:00:00, 2020-04-01 00:00:00, 2020-04-02 00:00:00, 2020-04-03 00:00:00, 2020-04-04 00:00:00, 2020-04-05 00:00:00, 2020-04-06 00:00:00, 2020-04-07 00:00:00, 2020-04-08 00:00:00, 2020-04-09 00:00:00, ...]
#
# [731 rows x 0 columns]

# %% [markdown]
# # 주 단위 데이터셋 생성

# %% [markdown]
# ## 수주량

# %%
# 주 단위 수주량 합계 데이터셋
data20_21_total_week = data20_21.copy()
data20_21_total_week = data20_21_total_week.pivot_table('수주량',index=['수주일자'],aggfunc='sum')
data20_21_total_week = data20_21_total_week.reset_index()
data20_21_total_week['수주일자'] = pd.to_datetime(data20_21_total_week['수주일자'])
data20_21_total_week = data20_21_total_week.set_index('수주일자')

data20_21_total_week = data20_21_total_week.resample('w-tue').sum()
data20_21_total_week
# Out:
#                 수주량
# 수주일자
# 2020-01-07  1158600
# 2020-01-14   757000
# 2020-01-21  1464000
# 2020-01-28  1016800
# 2020-02-04  1392050
# ...             ...
# 2021-12-07  1625070
# 2021-12-14   861000
# 2021-12-21  1405540
# 2021-12-28  1286540
# 2022-01-04   864000
#
# [105 rows x 1 columns]

# %%
# 주 단위 (고객별,품목별) 수주량 합계 데이터셋

data20_21_detail_week = data20_21.copy()
data20_21_detail_week = data20_21_detail_week.pivot_table('수주량',index=['수주일자','거래처코드','제품명'], aggfunc='sum')
data20_21_detail_week = data20_21_detail_week.reset_index()
data20_21_detail_week['수주일자'] = pd.to_datetime(data20_21_detail_week['수주일자'])
data20_21_detail_week = data20_21_detail_week.set_index('수주일자')

# data20_21_detail_week = data20_21_detail_week.resample('w-tue').sum()
data20_21_detail_week[(data20_21_detail_week['거래처코드']==2004000)&(data20_21_detail_week['제품명']=="PEMA-PR1000")]
# Out:
#               거래처코드          제품명    수주량
# 수주일자
# 2020-01-01  2004000  PEMA-PR1000  20000
# 2020-02-22  2004000  PEMA-PR1000  20000
# 2020-03-17  2004000  PEMA-PR1000  10000
# 2020-04-22  2004000  PEMA-PR1000  20000
# 2020-05-17  2004000  PEMA-PR1000  10000
# 2020-06-22  2004000  PEMA-PR1000  20000
# 2020-07-17  2004000  PEMA-PR1000  10000
# 2020-08-22  2004000  PEMA-PR1000  20000
# 2020-09-17  2004000  PEMA-PR1000  10000
# 2020-10-22  2004000  PEMA-PR1000  20000
# 2020-11-17  2004000  PEMA-PR1000  10000
# 2021-03-17  2004000  PEMA-PR1000  10000
# 2021-04-22  2004000  PEMA-PR1000  20000
# 2021-05-17  2004000  PEMA-PR1000  10000
# 2021-06-22  2004000  PEMA-PR1000  20000
# 2021-07-17  2004000  PEMA-PR1000  10000
# 2021-08-22  2004000  PEMA-PR1000  20000
# 2021-09-17  2004000  PEMA-PR1000  10000
# 2021-10-22  2004000  PEMA-PR1000  20000
# 2021-11-17  2004000  PEMA-PR1000  10000

# %%
li = []
for i in data20_21_detail_week['거래처코드'].unique():
    for j in data20_21_detail_week[data20_21_detail_week['거래처코드']==i]['제품명'].unique():
        data = data20_21_detail_week[(data20_21_detail_week['거래처코드']==i)&(data20_21_detail_week['제품명']==j)]
        data = date_all.join(data,how='outer')
        data = data.drop(['거래처코드','제품명'],axis=1).resample('w-tue').sum()
        data['거래처코드'] = i
        data['제품명'] = j
        data = data[['거래처코드','제품명','수주량']]
        li.append(data)

# %%
data20_21_detail_week = pd.concat(li)
data20_21_detail_week
# Out:
#               거래처코드          제품명      수주량
# 2020-01-07  2004000  PEMA-PR1000  20000.0
# 2020-01-14  2004000  PEMA-PR1000      0.0
# 2020-01-21  2004000  PEMA-PR1000      0.0
# 2020-01-28  2004000  PEMA-PR1000      0.0
# 2020-02-04  2004000  PEMA-PR1000      0.0
# ...             ...          ...      ...
# 2021-12-07  2003900  PEMA-PR1000      0.0
# 2021-12-14  2003900  PEMA-PR1000      0.0
# 2021-12-21  2003900  PEMA-PR1000      0.0
# 2021-12-28  2003900  PEMA-PR1000      0.0
# 2022-01-04  2003900  PEMA-PR1000      0.0
#
# [66675 rows x 3 columns]

# %% [markdown]
# ## 날씨

# %%
# 주 단위 날씨 데이터셋
weather_week = weather.copy()
weather_week['날짜'] = pd.to_datetime(weather_week['날짜'])
weather_week = weather_week.set_index('날짜')
weather_week = weather_week.resample('w-tue').mean()
weather_week
# Out:
#                 평균온도      일강수량       상대습도      최심적설
# 날짜
# 2020-01-07  2.750075  7.034737  72.215940  0.024361
# 2020-01-14  1.852782  0.730226  65.505564  0.015038
# 2020-01-21  1.088120  0.128722  58.339699  0.032180
# 2020-01-28  5.323008  3.924361  75.362707  0.000000
# 2020-02-04  2.950827  0.304060  67.209474  0.009474
# ...              ...       ...        ...       ...
# 2021-12-07  3.703459  0.230526  64.266165  0.004662
# 2021-12-14  4.859850  0.099850  69.050677  0.000000
# 2021-12-21  3.082105  0.511128  66.748722  0.193985
# 2021-12-28 -1.188120  0.477594  59.434586  0.578195
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404
#
# [105 rows x 4 columns]

# %% [markdown]
# ## 착공면적

# %%
construction_week = construction.copy()
construction_week = construction_week.set_index('Month')
construction_week = construction_week.reset_index()
construction_week['Month'] = pd.to_datetime(construction_week['Month'])
construction_week = construction_week.set_index('Month')
construction_week = date_all.join(construction_week).fillna(method='ffill')
construction_week
# Out:
#                   연면적별
# Date
# 2020-01-01   6200509.0
# 2020-01-02   6200509.0
# 2020-01-03   6200509.0
# 2020-01-04   6200509.0
# 2020-01-05   6200509.0
# ...                ...
# 2021-12-27  14132721.0
# 2021-12-28  14132721.0
# 2021-12-29  14132721.0
# 2021-12-30  14132721.0
# 2021-12-31  14132721.0
#
# [731 rows x 1 columns]

# %%
def strftime(x):
    return x.strftime('%Y-%m')

# %%
construction_week = construction_week.reset_index()
construction_week['month'] = construction_week['Date'].apply(strftime)

# %%
li = []
for i in construction_week['month'].unique():
    li.extend((construction_week[construction_week['month']==i].loc[:,'연면적별']/len(construction_week[construction_week['month']==i])).values)

# %%
construction_week['연면적별'] = pd.Series(li)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
construction_week = construction_week.set_index('Date').drop('month',axis=1).resample('w-tue').sum()

# %%
construction_week
# Out:
#                  연면적별
# Date
# 2020-01-07 1400114.94
# 2020-01-14 1400114.94
# 2020-01-21 1400114.94
# 2020-01-28 1400114.94
# 2020-02-04 1668158.64
# ...               ...
# 2021-12-07 3191259.58
# 2021-12-14 3191259.58
# 2021-12-21 3191259.58
# 2021-12-28 3191259.58
# 2022-01-04 1367682.68
#
# [105 rows x 1 columns]

# %% [markdown]
# ## 금리

# %%
start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('2022-01-04')
date_gold = pd.date_range(start, end, freq='w-tue').to_frame().rename(columns={0:'Date'}).reset_index(drop=True).set_index('Date')
date_gold
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-07 00:00:00, 2020-01-14 00:00:00, 2020-01-21 00:00:00, 2020-01-28 00:00:00, 2020-02-04 00:00:00, 2020-02-11 00:00:00, 2020-02-18 00:00:00, 2020-02-25 00:00:00, 2020-03-03 00:00:00, 2020-03-10 00:00:00, 2020-03-17 00:00:00, 2020-03-24 00:00:00, 2020-03-31 00:00:00, 2020-04-07 00:00:00, 2020-04-14 00:00:00, 2020-04-21 00:00:00, 2020-04-28 00:00:00, 2020-05-05 00:00:00, 2020-05-12 00:00:00, 2020-05-19 00:00:00, 2020-05-26 00:00:00, 2020-06-02 00:00:00, 2020-06-09 00:00:00, 2020-06-16 00:00:00, 2020-06-23 00:00:00, 2020-06-30 00:00:00, 2020-07-07 00:00:00, 2020-07-14 00:00:00, 2020-07-21 00:00:00, 2020-07-28 00:00:00, 2020-08-04 00:00:00, 2020-08-11 00:00:00, 2020-08-18 00:00:00, 2020-08-25 00:00:00, 2020-09-01 00:00:00, 2020-09-08 00:00:00, 2020-09-15 00:00:00, 2020-09-22 00:00:00, 2020-09-29 00:00:00, 2020-10-06 00:00:00, 2020-10-13 00:00:00, 2020-10-20 00:00:00, 2020-10-27 00:00:00, 2020-11-03 00:00:00, 2020-11-10 00:00:00, 2020-11-17 00:00:00, 2020-11-24 00:00:00, 2020-12-01 00:00:00, 2020-12-08 00:00:00, 2020-12-15 00:00:00, 2020-12-22 00:00:00, 2020-12-29 00:00:00, 2021-01-05 00:00:00, 2021-01-12 00:00:00, 2021-01-19 00:00:00, 2021-01-26 00:00:00, 2021-02-02 00:00:00, 2021-02-09 00:00:00, 2021-02-16 00:00:00, 2021-02-23 00:00:00, 2021-03-02 00:00:00, 2021-03-09 00:00:00, 2021-03-16 00:00:00, 2021-03-23 00:00:00, 2021-03-30 00:00:00, 2021-04-06 00:00:00, 2021-04-13 00:00:00, 2021-04-20 00:00:00, 2021-04-27 00:00:00, 2021-05-04 00:00:00, 2021-05-11 00:00:00, 2021-05-18 00:00:00, 2021-05-25 00:00:00, 2021-06-01 00:00:00, 2021-06-08 00:00:00, 2021-06-15 00:00:00, 2021-06-22 00:00:00, 2021-06-29 00:00:00, 2021-07-06 00:00:00, 2021-07-13 00:00:00, 2021-07-20 00:00:00, 2021-07-27 00:00:00, 2021-08-03 00:00:00, 2021-08-10 00:00:00, 2021-08-17 00:00:00, 2021-08-24 00:00:00, 2021-08-31 00:00:00, 2021-09-07 00:00:00, 2021-09-14 00:00:00, 2021-09-21 00:00:00, 2021-09-28 00:00:00, 2021-10-05 00:00:00, 2021-10-12 00:00:00, 2021-10-19 00:00:00, 2021-10-26 00:00:00, 2021-11-02 00:00:00, 2021-11-09 00:00:00, 2021-11-16 00:00:00, 2021-11-23 00:00:00, 2021-11-30 00:00:00, ...]
#
# [105 rows x 0 columns]

# %%
import numpy as np

# %%
rate_week = rate.copy().set_index('index')
rate_week = rate_week.reset_index()
rate_week['index'] = pd.to_datetime(rate_week['index'])
rate_week = rate_week.set_index('index')
rate_week = date_all.join(rate_week)
rate_week = rate_week.resample('w-tue').sum()
rate_week = rate_week.replace(0,np.NaN).fillna(method='ffill')
rate_week
# Out:
#             기준금리
# Date
# 2020-01-07  1.25
# 2020-01-14  1.25
# 2020-01-21  1.25
# 2020-01-28  1.25
# 2020-02-04  1.25
# ...          ...
# 2021-12-07  1.00
# 2021-12-14  1.00
# 2021-12-21  1.00
# 2021-12-28  1.00
# 2022-01-04  1.00
#
# [105 rows x 1 columns]

# %%
# 데이터셋 결합
dataset_detail_week = weather_week.join([rate_week,construction_week,data20_21_detail_week])

# %%
dataset_detail_week.to_csv('dataset_detail_week.csv')

# %%
import pandas as pd
import numpy as np
import random


dataset_detail_week= pd.read_csv('dataset_detail_week.csv', index_col=0)
dataset_detail_week
# Out:
#                 평균온도      일강수량       상대습도      최심적설  기준금리          연면적별  \
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# ...              ...       ...        ...       ...   ...           ...
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
#
#               거래처코드            제품명      수주량
# 2020-01-07  2004000    PEMA-PR1000  20000.0
# 2020-01-07  2004000    PEMA-HR1000  15000.0
# 2020-01-07  2004000    PEMA-SR2000      0.0
# 2020-01-07  2004000    PEMA-HR1500      0.0
# 2020-01-07  2004000   PEMA-SR2000A      0.0
# ...             ...            ...      ...
# 2022-01-04  2003900  PEMA-PCR3000N      0.0
# 2022-01-04  2003900   PEMA-SR3000F      0.0
# 2022-01-04  2003900             AE      0.0
# 2022-01-04  2003900     PEMA-580FX  15000.0
# 2022-01-04  2003900    PEMA-PR1000      0.0
#
# [66675 rows x 9 columns]

# %% [markdown]
# ## 예상중량

# %%
np.random.seed(2)
np.random.randint(dataset_detail_week['수주량'][0]*0.7, dataset_detail_week['수주량'][0]*1.3, 1)
# Out:
# array([21336])

# %%
dataset_detail_week['예상중량'] = 0

# %%
for i in range(len(dataset_detail_week)):
    if dataset_detail_week['수주량'][i] == 0:
        pass
    else:
        dataset_detail_week['예상중량'][i] = np.random.randint(dataset_detail_week['수주량'][i]*0.7, dataset_detail_week['수주량'][i]*1.3, 1)
# Out:
# C:\Users\sch01\AppData\Local\Temp\ipykernel_17428\463576023.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_detail_week['예상중량'][i] = np.random.randint(dataset_detail_week['수주량'][i]*0.7, dataset_detail_week['수주량'][i]*1.3, 1)

# %%
dataset_detail_week
# Out:
#                 평균온도      일강수량       상대습도      최심적설  기준금리          연면적별  \
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# ...              ...       ...        ...       ...   ...           ...
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
#
#               거래처코드            제품명      수주량   예상중량
# 2020-01-07  2004000    PEMA-PR1000  20000.0  16575
# 2020-01-07  2004000    PEMA-HR1000  15000.0  17137
# 2020-01-07  2004000    PEMA-SR2000      0.0      0
# 2020-01-07  2004000    PEMA-HR1500      0.0      0
# 2020-01-07  2004000   PEMA-SR2000A      0.0      0
# ...             ...            ...      ...    ...
# 2022-01-04  2003900  PEMA-PCR3000N      0.0      0
# 2022-01-04  2003900   PEMA-SR3000F      0.0      0
# 2022-01-04  2003900             AE      0.0      0
# 2022-01-04  2003900     PEMA-580FX  15000.0  17928
# 2022-01-04  2003900    PEMA-PR1000      0.0      0
#
# [66675 rows x 10 columns]

# %%
data20_21['예상중량'] = 0

# %%
data20_21[data20_21['수주량']==0]
# Out:
# Empty DataFrame
# Columns: [거래처코드, 제품코드, 수주량, 수주단가, 수주금액, 수주일자, 납기일자, 제품명, 수주월, 예상중량]
# Index: []

# %%
data20_21.reset_index(drop=True, inplace=True)

# %%
data20_21
# Out:
#          거래처코드           제품코드    수주량  수주단가      수주금액        수주일자        납기일자  \
# 0      2004000  PEMA013901520  20000  1028  20560000  2020-01-01  2020-01-04
# 1      2004100  PEMA033078017   5000  1029   5145000  2020-01-01  2020-01-04
# 2      2004104  PEMA043080500   5000  1030   5150000  2020-01-01  2020-01-04
# 3      2004200  PEMA043080500   2000  1031   2062000  2020-01-01  2020-01-04
# 4      2004300  PEMA043062000   6000  1032   6192000  2020-01-01  2020-01-04
# ...        ...            ...    ...   ...       ...         ...         ...
# 18792  2007600  PEMA053046500   4000  2701  10804000  2021-12-31  2022-01-03
# 18793  2007700  PEMA033014200  10000  2702  27020000  2021-12-31  2022-01-03
# 18794  2007700  TSN4012011125  10000  2717  27170000  2021-12-31  2022-01-03
# 18795  2007800  PEMA063061300   5000  2703  13515000  2021-12-31  2022-01-03
# 18796  2007800  PEMA013123000  10000  2718  27180000  2021-12-31  2022-01-03
#
#                 제품명      수주월  예상중량
# 0       PEMA-PR1000  2020-01     0
# 1       PEMA-SR2000  2020-01     0
# 2       PEMA-SR2000  2020-01     0
# 3       PEMA-SR2000  2020-01     0
# 4       PEMA-SR2000  2020-01     0
# ...             ...      ...   ...
# 18792   PEMA-HR1500  2021-12     0
# 18793   PEMA-HR1500  2021-12     0
# 18794    PEMA-SN400  2021-12     0
# 18795  PEMA-PCM2000  2021-12     0
# 18796   PEMA-SR2000  2021-12     0
#
# [18797 rows x 10 columns]

# %% [markdown]
# ### 원 데이터 예측 중량

# %%
data20_21

    
for i in range(len(data20_21)):
    data20_21['예상중량'][i] = np.random.randint(data20_21['수주량'][i]*0.7, data20_21['수주량'][i]*1.3, 1)
# Out:
# C:\Users\sch01\AppData\Local\Temp\ipykernel_17428\2974647725.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data20_21['예상중량'][i] = np.random.randint(data20_21['수주량'][i]*0.7, data20_21['수주량'][i]*1.3, 1)

# %%
data20_21
# Out:
#          거래처코드           제품코드    수주량  수주단가      수주금액        수주일자        납기일자  \
# 0      2004000  PEMA013901520  20000  1028  20560000  2020-01-01  2020-01-04
# 1      2004100  PEMA033078017   5000  1029   5145000  2020-01-01  2020-01-04
# 2      2004104  PEMA043080500   5000  1030   5150000  2020-01-01  2020-01-04
# 3      2004200  PEMA043080500   2000  1031   2062000  2020-01-01  2020-01-04
# 4      2004300  PEMA043062000   6000  1032   6192000  2020-01-01  2020-01-04
# ...        ...            ...    ...   ...       ...         ...         ...
# 18792  2007600  PEMA053046500   4000  2701  10804000  2021-12-31  2022-01-03
# 18793  2007700  PEMA033014200  10000  2702  27020000  2021-12-31  2022-01-03
# 18794  2007700  TSN4012011125  10000  2717  27170000  2021-12-31  2022-01-03
# 18795  2007800  PEMA063061300   5000  2703  13515000  2021-12-31  2022-01-03
# 18796  2007800  PEMA013123000  10000  2718  27180000  2021-12-31  2022-01-03
#
#                 제품명      수주월   예상중량
# 0       PEMA-PR1000  2020-01  21390
# 1       PEMA-SR2000  2020-01   6479
# 2       PEMA-SR2000  2020-01   3825
# 3       PEMA-SR2000  2020-01   2172
# 4       PEMA-SR2000  2020-01   6075
# ...             ...      ...    ...
# 18792   PEMA-HR1500  2021-12   2862
# 18793   PEMA-HR1500  2021-12   8721
# 18794    PEMA-SN400  2021-12  12025
# 18795  PEMA-PCM2000  2021-12   5962
# 18796   PEMA-SR2000  2021-12  12188
#
# [18797 rows x 10 columns]

# %% [markdown]
# ## 시멘트

# %%
# 빈 날짜 데이터프레임 생성
start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('2021-12-31')
date_all = pd.date_range(start=start,end=end,freq='d')
# test = pd.DataFrame(index=date_all).join(data20_21_detail)
# test[test['거래처코드'].isnull()]

# %%
def strftime(x):
    return x.strftime('%Y-%m')

# %%
date_all = pd.date_range(start, end, freq='D').to_frame().rename(columns={0:'Date'}).reset_index(drop=True).set_index('Date')
date_all = date_all.reset_index()

# %%
date_all['Month']=date_all['Date'].apply(strftime)

# %%
month_in=date_all['Month'].unique()

# %%
add_mi = pd.read_csv('./시멘트2년 국내출하(월별증감율).csv')

# %%
add_mi.index = month_in

# %%
add_mi.reset_index(inplace=True)

# %%
add_mi=add_mi[['index','내수계']]

# %%
add_mi.rename({'index':'month'}, axis=1, inplace=True)

# %%
add_mi = add_mi.append({'month' : '2022-01', '내수계':2704}, ignore_index=True)
# Out:
# C:\Users\sch01\AppData\Local\Temp\ipykernel_17428\4289067202.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   add_mi = add_mi.append({'month' : '2022-01', '내수계':2704}, ignore_index=True)

# %%
add_mi
# Out:
#       month   내수계
# 0   2020-01  2704
# 1   2020-02  3127
# 2   2020-03  4419
# 3   2020-04  4625
# 4   2020-05  4065
# 5   2020-06  4289
# 6   2020-07  3541
# 7   2020-08  3026
# 8   2020-09  4069
# 9   2020-10  4347
# 10  2020-11  4594
# 11  2020-12  4356
# 12  2021-01  2746
# 13  2021-02  3027
# 14  2021-03  4684
# 15  2021-04  4902
# 16  2021-05  4335
# 17  2021-06  4388
# 18  2021-07  4223
# 19  2021-08  3493
# 20  2021-09  3601
# 21  2021-10  4461
# 22  2021-11  4794
# 23  2021-12  4710
# 24  2022-01  2704

# %%
dataset_detail_week.reset_index(inplace=True)

# %%
dataset_detail_week['index'] = pd.to_datetime(dataset_detail_week['index'])

# %%
dataset_detail_week['month']=dataset_detail_week['index'].apply(strftime)

# %%
dataset_detail_week
# Out:
#            index      평균온도      일강수량       상대습도      최심적설  기준금리          연면적별  \
# 0     2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 1     2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 2     2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 3     2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# 4     2020-01-07  2.750075  7.034737  72.215940  0.024361  1.25  1.400115e+06
# ...          ...       ...       ...        ...       ...   ...           ...
# 66670 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 66671 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 66672 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 66673 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
# 66674 2022-01-04 -0.505965  0.232632  61.186667  0.441404  1.00  1.367683e+06
#
#          거래처코드            제품명      수주량   예상중량    month
# 0      2004000    PEMA-PR1000  20000.0  16575  2020-01
# 1      2004000    PEMA-HR1000  15000.0  17137  2020-01
# 2      2004000    PEMA-SR2000      0.0      0  2020-01
# 3      2004000    PEMA-HR1500      0.0      0  2020-01
# 4      2004000   PEMA-SR2000A      0.0      0  2020-01
# ...        ...            ...      ...    ...      ...
# 66670  2003900  PEMA-PCR3000N      0.0      0  2022-01
# 66671  2003900   PEMA-SR3000F      0.0      0  2022-01
# 66672  2003900             AE      0.0      0  2022-01
# 66673  2003900     PEMA-580FX  15000.0  17928  2022-01
# 66674  2003900    PEMA-PR1000      0.0      0  2022-01
#
# [66675 rows x 12 columns]

# %%
dataset_detail_week = pd.merge(dataset_detail_week, add_mi, on='month', how='outer')

# %%
dataset_detail_week.drop('month',axis=1, inplace=True)

# %%
dataset_detail_week.rename({'내수계':'시멘트'}, axis=1, inplace=True)

# %%
ind=dataset_detail_week.index.unique()

# %%
pro=dataset_detail_week['제품명'].unique()

# %%
part_li = []
for i,j in enumerate(ind):
    dataset_detail_week.replace({j:i}, inplace=True)

# %%
dataset_detail_week
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리       연면적별    거래처코드            제품명  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000    PEMA-PR1000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000    PEMA-HR1000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000    PEMA-SR2000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000    PEMA-HR1500
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000   PEMA-SR2000A
# ...          ...   ...   ...   ...   ...        ...      ...            ...
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900  PEMA-PCR3000N
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900   PEMA-SR3000F
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900             AE
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900     PEMA-580FX
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900    PEMA-PR1000
#
#                 수주량
# 2020-01-07 20000.00
# 2020-01-07 15000.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# ...             ...
# 2022-01-04     0.00
# 2022-01-04     0.00
# 2022-01-04     0.00
# 2022-01-04 15000.00
# 2022-01-04     0.00
#
# [66675 rows x 9 columns]

# %%
part_li2[10]
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리       연면적별    거래처코드      제품명  수주량
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004100  CSA4000 0.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004500  CSA4000 0.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005900  CSA4000 0.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2006000  CSA4000 0.00
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2006300  CSA4000 0.00
# ...          ...   ...   ...   ...   ...        ...      ...      ...  ...
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003000  CSA4000 0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003400  CSA4000 0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003500  CSA4000 0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003600  CSA4000 0.00
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003700  CSA4000 0.00
#
# [2310 rows x 9 columns]

# %%
cus=dataset_detail_week['거래처코드'].unique()

# %%
part_li3 = []
for i in cus:
    part =dataset_detail_week[dataset_detail_week['거래처코드']==i]
    part_li3.append(part)

# %%
part_li3[7].head(10)
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리       연면적별    거래처코드          제품명  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800  PEMA-HR1000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800           AE
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800      CSA5000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800  PEMA-HR1500
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800  PEMA-SR2000
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800   PEMA-580FX
# 2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2005800  PEMA-PR1000
# 2020-01-14  1.85  0.73 65.51  0.02  1.25 1400114.94  2005800  PEMA-HR1000
# 2020-01-14  1.85  0.73 65.51  0.02  1.25 1400114.94  2005800           AE
# 2020-01-14  1.85  0.73 65.51  0.02  1.25 1400114.94  2005800      CSA5000
#
#                 수주량
# 2020-01-07 10000.00
# 2020-01-07 10000.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# 2020-01-07     0.00
# 2020-01-14     0.00
# 2020-01-14  4000.00
# 2020-01-14     0.00

# %% [markdown]
# # 월 단위 데이터셋 생성

# %% [markdown]
# ## 수주량

# %%
# 월 단위 수주량 합계 데이터셋
data20_21_total_month = data20_21.copy()
data20_21_total_month = data20_21_total_month.pivot_table('수주량',index=['수주월'], aggfunc='sum')
data20_21_total_month
# Out:
#              수주량
# 수주월
# 2020-01  4808400
# 2020-02  6317320
# 2020-03  7712350
# 2020-04  7157310
# 2020-05  7712350
# 2020-06  5784210
# 2020-07  6645350
# 2020-08  6182310
# 2020-09  7566350
# 2020-10  7057310
# 2020-11  7567350
# 2020-12  6274150
# 2021-01  4630400
# 2021-02  6145320
# 2021-03  7712350
# 2021-04  7157310
# 2021-05  7712350
# 2021-06  6191210
# 2021-07  7007350
# 2021-08  6449310
# 2021-09  6952350
# 2021-10  6579310
# 2021-11  7032350
# 2021-12  6042150

# %%
# 월 단위 (거래처별, 품목별) 수주량  합계 데이터셋
data20_21_detail_month = data20_21.copy()
data20_21_detail_month = data20_21_detail_month.pivot_table('수주량',index=['수주월','거래처코드','제품명'], aggfunc='sum')
data20_21_detail_month = data20_21_detail_month.reset_index()
data20_21_detail_month = data20_21_detail_month.set_index('수주월')
data20_21_detail_month
# Out:
#            거래처코드           제품명    수주량
# 수주월
# 2020-01  2001102            AE   3000
# 2020-01  2001102       CSA5000  23000
# 2020-01  2001102   PEMA-HR1000   7000
# 2020-01  2001102   PEMA-HR1500   4000
# 2020-01  2001102   PEMA-PR1000  20000
# ...          ...           ...    ...
# 2021-12  2007800   PEMA-HR1000  10000
# 2021-12  2007800   PEMA-HR1500  30000
# 2021-12  2007800  PEMA-PCM2000   5000
# 2021-12  2007800   PEMA-SR2000  36000
# 2021-12  2007800  PEMA-SR3000F  10000
#
# [10084 rows x 3 columns]

# %% [markdown]
# ## 날씨

# %%
# 월 단위 날씨
weather_month = weather.copy()
weather_month['년월'] = weather_month['날짜'].apply(yearmonth)
# weather['날짜'] = pd.to_datetime(weather['날짜'])

weather_month = weather_month.pivot_table(['평균온도','일강수량','상대습도','최심적설'],index='년월',aggfunc='mean')
weather_month.head(3)
# Out:
#          상대습도  일강수량  최심적설  평균온도
# 년월
# 2020-01    68     3     0     3
# 2020-02    67     2     0     4
# 2020-03    61     1     0     8

# %% [markdown]
# ## 착공면적

# %%
construction_month = construction.copy()
construction_month = construction_month.set_index('Month')
construction_month.head(3)
# Out:
#              연면적별
# Month
# 2020-01   6200509
# 2020-02   7743793
# 2020-03  11972937

# %% [markdown]
# ## 금리

# %%
rate_month = rate.copy().set_index('index')
rate_month.head(3)
# Out:
#          기준금리
# index
# 2020-01     1
# 2020-02     1
# 2020-03     1

# %% [markdown]
# ## 데이터셋

# %%
dataset_total_month = weather_month.join([rate_month,construction_month,data20_21_total_month])
dataset_total_month
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별      수주량
# 년월
# 2020-01    68     3     0     3     1   6200509  4808400
# 2020-02    67     2     0     4     1   7743793  6317320
# 2020-03    61     1     0     8     1  11972937  7712350
# 2020-04    56     1     0    11     1  10481354  7157310
# 2020-05    73     4     0    18     0  10999316  7712350
# 2020-06    76     6     0    23     0  10255271  5784210
# 2020-07    86    13     0    22     0  10658885  6645350
# 2020-08    85    13     0    27     0   8595586  6182310
# 2020-09    80     8     0    20     0  10775873  7566350
# 2020-10    69     0     0    14     0   9195394  7057310
# 2020-11    66     1     0     9     0  12312253  7567350
# 2020-12    60     0     0     1     0  12855085  6274150
# 2021-01    64     1     1    -1     0   7570978  4630400
# 2021-02    58     1     0     4     0  10178609  6145320
# 2021-03    68     4     0     9     0  12996528  7712350
# 2021-04    59     3     0    13     0  11765306  7157310
# 2021-05    71     4     0    17     0  12417941  7712350
# 2021-06    77     3     0    22     0  10857729  6191210
# 2021-07    81     8     0    26     0  10510350  7007350
# 2021-08    83     9     0    25     1   8974011  6449310
# 2021-09    81     5     0    22     1  11398360  6952350
# 2021-10    76     2     0    15     1  11618046  6579310
# 2021-11    70     2     0     9     1  11415255  7032350
# 2021-12    65     0     0     2     1  14132721  6042150

# %% [markdown]
# ## 상세 데이터셋

# %%
dataset_detail_month = weather_month.join([rate_month,construction_month,data20_21_detail_month])
dataset_detail_month
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별    거래처코드           제품명    수주량
# 2020-01    68     3     0     3     1   6200509  2001102            AE   3000
# 2020-01    68     3     0     3     1   6200509  2001102       CSA5000  23000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-HR1000   7000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-HR1500   4000
# 2020-01    68     3     0     3     1   6200509  2001102   PEMA-PR1000  20000
# ...       ...   ...   ...   ...   ...       ...      ...           ...    ...
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-HR1000  10000
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-HR1500  30000
# 2021-12    65     0     0     2     1  14132721  2007800  PEMA-PCM2000   5000
# 2021-12    65     0     0     2     1  14132721  2007800   PEMA-SR2000  36000
# 2021-12    65     0     0     2     1  14132721  2007800  PEMA-SR3000F  10000
#
# [10084 rows x 9 columns]

# %%
dataset_detail_month[(dataset_detail_month['거래처코드']==2001102)&(dataset_detail_month['제품명']=='AE')]
# Out:
#          상대습도  일강수량  최심적설  평균온도  기준금리      연면적별    거래처코드 제품명   수주량
# 2020-01    68     3     0     3     1   6200509  2001102  AE  3000
# 2020-03    61     1     0     8     1  11972937  2001102  AE  3000
# 2020-05    73     4     0    18     0  10999316  2001102  AE  3000
# 2020-07    86    13     0    22     0  10658885  2001102  AE  3000
# 2020-09    80     8     0    20     0  10775873  2001102  AE  3000
# 2020-11    66     1     0     9     0  12312253  2001102  AE  3000
# 2021-01    64     1     1    -1     0   7570978  2001102  AE  3000
# 2021-03    68     4     0     9     0  12996528  2001102  AE  3000
# 2021-05    71     4     0    17     0  12417941  2001102  AE  3000
# 2021-07    81     8     0    26     0  10510350  2001102  AE  3000
# 2021-09    81     5     0    22     1  11398360  2001102  AE  3000
# 2021-11    70     2     0     9     1  11415255  2001102  AE  3000

# %%
for i in dataset_detail['거래처코드'].unique():
    for j in dataset_detail[dataset_detail['거래처코드']==i]['제품명'].unique():
        data = dataset_detail[(dataset_detail['거래처코드']==i)&(dataset_detail['제품명']==j)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '거래처코드'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [486], in <cell line: 1>()
# ----> 1 for i in dataset_detail['거래처코드'].unique():
#       2     for j in dataset_detail[dataset_detail['거래처코드']==i]['제품명'].unique():
#       3         data = dataset_detail[(dataset_detail['거래처코드']==i)&(dataset_detail['제품명']==j)]
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: '거래처코드'

# %%
from pmdarima import auto_arima

auto_arima_model = auto_arima(train, start_p=1,start_q=1,
                             max_p=5, max_q=3,m=12,
                             start_P = 1, start_Q = 1, max_P=3, max_Q=3,
                             seasonal = True, d=1, D=1, trace=True,
                             error_action = 'ignore',
                             suppress_warning=True, stepwise=False)
auto_arima_model.summary()

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: xgboost in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (1.6.2)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: lightgbm in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (3.3.2)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: click in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\roaming\python\python38\site-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from click->lazypredict) (0.4.4)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lightgbm->lazypredict) (1.22.3)
# Requirement already satisfied: wheel in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from pandas->lazypredict) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

df3 = pd.read_csv('./학습용 데이터셋_2년.csv', index_col=0)
df3
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량       수주량    예상중량  AE  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58 338000.00  343884   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   63342   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   96888   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  46000.00   40072   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  12000.00    9542   0
# ...          ...   ...   ...   ...   ...   ...    ...       ...     ...  ..
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            1             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# ...         ...         ...          ...       ...          ...           ...
# 2022-01-04  ...           0            1         0            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         1            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             1             0       0        0        0
# 2020-01-07             0             0       0        0        0
# ...                  ...           ...     ...      ...      ...
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        1
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
#
# [2835 rows x 36 columns]

# %%
# df3['수주량'] = np.log1p(df3['수주량'])
# df3['13수주량'] = np.log1p(df3['13수주량'])

# %%
df3
# Out:
#      수주량  평균온도  일강수량  상대습도  최심적설  기준금리       연면적별  13수주량
# 1  13.96 10.30  2.20 65.20  0.00  0.75 2703566.42  14.38
# 2  13.54  9.62  0.12 49.08  0.00  0.75 2445649.27  14.47
# 3  14.20  9.47  1.05 56.94  0.00  0.75 2445649.27  14.31
# 4  13.83 11.43  4.95 67.63  0.00  0.75 2445649.27  14.50
# 5  14.15 10.85  0.06 50.09  0.00  0.75 2445649.27  14.29
# ..   ...   ...   ...   ...   ...   ...        ...    ...
# 89 14.25  3.70  0.23 64.27  0.00  1.00 3191259.58  14.30
# 90 14.30  4.86  0.10 69.05  0.00  1.00 3191259.58  13.67
# 91 14.26  3.08  0.51 66.75  0.19  1.00 3191259.58  14.16
# 92 14.61 -1.19  0.48 59.43  0.58  1.00 3191259.58  14.07
# 93 14.04 -0.51  0.23 61.19  0.44  1.00 1367682.68  13.67
#
# [93 rows x 8 columns]

# %%
df3.columns
# Out:
# Index(['수주량', '평균온도', '일강수량', '상대습도', '최심적설', '기준금리', '연면적별', '13수주량'], dtype='object')

# %%
# df = pd.DataFrame(df3['연면적별'])

# obj = MinMaxScaler()
# df3['연면적별']=obj.fit_transform(df)

# %%
# obj2 = StandardScaler()
# df3[['평균온도', '일강수량', '상대습도', '최심적설']]= obj2.fit_transform(df3.drop(['13수주량','수주량','기준금리', '연면적별'], axis=1, inplace = False))

# %%
df3
# Out:
#             평균온도  일강수량  상대습도  최심적설  기준금리  착공지수    출하량       수주량    예상중량  AE  \
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58 338000.00  343884   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   63342   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  85000.00   96888   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  46000.00   40072   0
# 2020-01-07  2.75  7.03 72.22  0.02  1.25  0.02 610.58  12000.00    9542   0
# ...          ...   ...   ...   ...   ...   ...    ...       ...     ...  ..
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
# 2022-01-04 -0.51  0.23 61.19  0.44  1.00  0.00 455.81      0.00       0   0
#
#             ...  PEMA-SN400  PEMA-SP1000  PEMA-SPR  PEMA-SR2000  PEMA-SR2000A  \
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            1             0
# 2020-01-07  ...           0            0         0            0             0
# 2020-01-07  ...           0            0         0            0             0
# ...         ...         ...          ...       ...          ...           ...
# 2022-01-04  ...           0            1         0            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         1            0             0
# 2022-01-04  ...           0            0         0            0             0
# 2022-01-04  ...           0            0         0            0             0
#
#             PEMA-SR3000F  PEMA-SR5000F  PR1000  SRE-110  SRE-200
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             0             0       0        0        0
# 2020-01-07             1             0       0        0        0
# 2020-01-07             0             0       0        0        0
# ...                  ...           ...     ...      ...      ...
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        1
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
# 2022-01-04             0             0       0        0        0
#
# [2835 rows x 36 columns]

# %%
x_features = df3.drop(['수주량','예상중량'], axis=1, inplace=False)
y_target = df3['수주량']

# %%
np.set_printoptions(precision=4, suppress=True)

# %%
# x_train = x_features[:-12]
# y_train = y_target[:-12]
# x_test=x_features[-12:]
# y_test=y_target[-12:]

# %%
lr_model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x_features, y_target, test_size = 0.2, random_state=156)

lr_model.fit(x_train,y_train)
pred = lr_model.predict(x_test)

print(lr_model.coef_)

mse = mean_squared_error(y_test, pred)
mae = mean_absolute_error(y_test, pred)
r2 = r2_score(y_test,pred)
rmse = np.sqrt(mse)

print(rmse)
print(mae)
print(r2)
# Out:
# [ 4.4302e+02  7.9895e+01 -5.3110e+02 -1.1473e+04 -2.3862e+03 -1.9951e+03
#   1.9090e+01  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14
#   2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14
#   2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14
#   2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14
#   2.1527e+14  2.1527e+14  2.1527e+14  2.1527e+14]
# 39550.19598369779
# 18743.43149250441
# 0.8873592227024233

# %%
len(x_test)
# Out:
# 567

# %%
pred
# Out:
# array([  4983.875 , -12202.25  , 211501.7812,      3.1562,  -1316.    ,
#         15231.3438,   1745.6562,  -1307.5   , 205367.7188,  15195.5938,
#         14333.9688,  12321.1562, 247222.1562,  17081.3438, 538918.375 ,
#        121694.0625,  10703.0938, 119944.75  ,  27384.5625, 542678.0938,
#         17426.875 ,  96220.9062,  21592.5625,  17615.3438, 242984.0625,
#        115424.9688,   7231.0625,  22222.75  ,  17588.8125,   8772.8125,
#          5370.3438,  14513.2812,   4217.375 ,  85719.2812, 547450.4375,
#         -4150.5938,    607.0938,  10607.4062,  -9435.7812,  21128.0312,
#          5214.3125,   5065.9688,  -5402.0938,  10232.7812,  14179.0938,
#         65338.1562,  -7354.5   ,   6573.1562,  13832.625 , 114149.4062,
#          6049.9062,  78309.3438,  21534.5625,  76581.625 ,  13340.875 ,
#          2754.2188, 110483.3438,  -2576.9375, 235372.875 ,  37961.5   ,
#         25180.4688,  74566.125 ,   7289.    , 118481.8125,  -2498.0938,
#         56510.2188,  -5771.6875,   5566.625 ,  45457.    ,  36615.7188,
#         -5988.9688, -10044.3125,  20472.5   , 542955.9688,  76441.1562,
#        541744.4688,  19247.5   ,  18947.    ,  14154.3438,  41713.6562,
#         -5883.0938,   1819.5312,   7869.2188, 205224.2812, 103102.9688,
#         33450.0312,  22572.5   ,  10832.9688,  41704.3438,  -3463.2188,
#         35548.2812,   8111.7188,  44652.25  ,  77731.1562, 129818.5   ,
#         15873.375 , 184792.3438,   -725.2812,   5213.5625,   1805.125 ,
#        100040.7188,  12222.5938, 239705.2812,  11252.8438,  65048.625 ,
#         12815.3125,   7946.4375,  -2335.6562,  12266.875 ,    787.9375,
#        -10205.5312,   1728.0625,  -7113.2188,   1708.9688,  24007.25  ,
#        239977.125 , 207155.9062,   2342.3438,   -290.1875,  19289.3125,
#           277.5625,   7906.8125,    497.0625, -13118.2812,  27103.6562,
#        116918.8125,  -2991.4062,   4309.1875,  18255.7812,  17318.6875,
#          7203.2188,  -1805.2812, 235854.4375,  -4094.1562,   5074.9688,
#         17231.2812, 120869.3125,  48617.4688,  10283.125 ,  13299.0625,
#         -4619.0938,  46983.3438,   4427.4062,  76525.7188,  47779.4062,
#         11868.5938,    515.125 ,    849.4688, 207911.4375,  33846.0938,
#         16824.625 ,  18054.3438, 223749.3438,  24887.3125,  43923.4375,
#         27447.1875,  12066.3125,  47947.7188,  35941.125 ,  88975.875 ,
#          6851.9062,  10795.8125,   2301.    , 241424.5625,   3346.6562,
#         46467.1562,  14966.0938, -11473.0312,   9756.9688, 241166.    ,
#        244814.0625,   6443.625 ,  18228.5312,    738.    , 117841.375 ,
#          8376.7188,  16828.0312, 528282.25  , 234066.25  ,  84092.375 ,
#        541452.3125,  21844.7188,  18087.8438,   8156.75  ,   2585.875 ,
#        -23618.0312,  38333.0938, 125898.375 ,   4688.5   , 238746.6875,
#         -3647.7188, 537305.0938,  -4433.0938, 111211.0625,   7578.25  ,
#         13487.4062,  -1496.4688,   5750.1562,  39295.8438,  19926.875 ,
#          6267.2188,  15234.5938,  -1024.7812,  35677.9688,   6994.3438,
#         10287.5625,  18144.875 ,  16037.375 ,   6624.7812,  16486.875 ,
#         69286.5   ,  57044.8438,    776.5938, 232434.5312,  24909.9062,
#          8504.5625, -12779.3438, 119643.    ,   1528.875 ,  49514.75  ,
#          5633.9062,  29778.9062,   -978.1875,  37719.6875,    896.75  ,
#          6872.6875,   5825.5312,  23285.9688,  -1188.1562,  -1858.7812,
#         11921.3125,   -834.75  , 111753.2188,  94032.25  ,  21224.0625,
#          6739.0312,    699.5   ,  -2037.2188, 209926.3438,   8008.7812,
#         45916.25  , 211006.75  ,  19975.0625,  29507.8438,  50964.5625,
#        536092.6562,  78237.25  ,   5600.0312,  52685.625 ,   5564.8438,
#        118336.9062,  29979.4688, 224695.4688,   1245.4688,  10231.5   ,
#         -5746.9688, 241168.2188,  10782.125 ,  10388.375 ,  15737.4375,
#         14948.    , -12541.1875,   1596.    , 234936.9062,   8624.2188,
#        105260.9062, -12708.8125,  36361.9688,   4315.6562,  10789.5938,
#         14678.4375,   1220.5938,   5688.6562, -12172.1562,   3279.2812,
#        238876.375 ,  37001.9062,   4423.9688,  13682.6562,  46000.8438,
#        212139.3438,   2496.9375,  13406.9688,  -9181.5312,  74565.5   ,
#         45713.4688,  18794.2812,  -1065.5   ,  18150.125 ,  10450.9375,
#          1776.125 ,  40743.375 ,  28163.5312,   2275.9062,  53727.1875,
#        213490.875 ,   9370.625 , 110686.125 ,   4928.875 ,  21712.5625,
#        541502.6562,  -9388.4375,  78753.1562,  10693.4688,   1718.9688,
#          8044.    ,   -894.125 ,  -5494.6875,   4020.2812,  24096.6562,
#         43509.75  ,  28277.0625,   9523.0312,   -584.8125, 536906.7188,
#         82696.25  ,  22948.4062,  83609.5625,   4704.8438,   1663.125 ,
#        129810.0938,   -683.75  ,   1029.9375,  12632.625 ,  13446.4062,
#         35426.4688,  82921.5625,  23364.5625,  23192.25  , 209945.2188,
#          3448.4375,   8753.9375,  91502.3125, 535374.9375,  49845.375 ,
#         88810.9688,  -4444.6875,  14943.125 ,  48538.625 , 242917.5312,
#          9279.0625,   7118.5625,   5624.3438,  45737.6875,  73295.625 ,
#          3516.8438,  23808.0312,  17327.0938,  56378.0625, 236720.5312,
#        215404.7188, 114578.6562,  10247.5   ,  87134.9688, 205833.4375,
#         32603.7188,  16689.3438,  49364.875 ,  -5172.4062,   4556.9375,
#         15675.2188,  -3389.125 ,   3290.875 ,  29468.1562,  10533.25  ,
#        117372.2188, 234992.8125,  45540.2812,  -2801.375 ,  16675.1875,
#          1538.25  , 204278.7812,  15698.9688,  -2821.6562,  13082.4688,
#         18694.8438,  -2780.0312,  20295.75  ,  16587.1875,   -751.875 ,
#         17966.0312,   3954.3438,  34943.875 ,  17713.875 ,  -2859.4375,
#          6547.6562, 524333.9062,  -2944.8125,  25416.375 ,   8932.7812,
#        246631.9375,  -2212.5   ,   1263.0625,   4337.7812,  12915.0938,
#         37639.4688,   6027.5938, 535631.6562,  -9966.875 ,  16319.8125,
#          8925.4062, -10624.5312, 547214.5312,   2837.6562,  12828.5312,
#        116642.5625,  48954.0938,   4445.25  ,  31738.5   , 195627.9062,
#        205242.5312,   6693.1875,   9837.4688,  -2818.9375,  13637.6875,
#         -2886.1562,   2139.5625,   9225.6875,  -3931.0312,  20352.1875,
#          5712.2812,  20207.625 ,   5547.375 ,  32697.8438,  18425.7812,
#        210386.0938,   1680.3438,  45003.5938,  17732.75  , -10419.5   ,
#        113092.7188,  15997.625 ,  48027.3125, 231706.8125,  38894.375 ,
#         36724.0938,  17910.625 ,  12558.    ,  -1306.7812,   9734.5938,
#          1137.4688,  19066.125 ,   5609.9688,   2796.7188,  11457.8125,
#         64173.3438,  29584.0625,   5219.4688, 116901.2188, 537942.5938,
#         32045.3438, 121280.0938, 204278.1562,  56990.7188,    351.375 ,
#          4331.5625,  85562.875 ,  -1463.9688,   6777.5   , 102525.875 ,
#        252443.4375,   6704.5938, 239064.8438,   6339.625 ,   7463.1562,
#          1292.8438,  53929.1562, 535957.4375,  78152.9375,   6544.5625,
#         13468.2812, 210177.8438,   4510.4062,  13629.2812,   5262.5   ,
#          7449.2188, -10866.5312,   6572.4375,   7349.7812,   9764.3125,
#         11979.4062,  79281.1875,  29218.0312,  71914.5625,   9734.9062,
#          5205.375 ,  -5271.2812, 117523.2188,  80213.6875,   -315.0938,
#         -6758.6875,   9986.75  ,  16447.0312, -16380.0625,   2457.0312,
#         12038.5938,  -2621.0938,   -110.625 ,   8451.375 , 206809.5625,
#          1694.8125, 238643.75  ,   -674.25  ,  12141.8438,  17767.9688,
#          1559.0625,    471.875 ,   3223.6875, -12413.4375, 532291.375 ,
#        238624.875 ,   8724.75  ,  37187.0625,  33846.0938,   1879.0625,
#          3393.8125,   1735.25  ,  51259.2188,  11553.625 ,  21054.0625,
#        122879.7812, 115340.6562, 238678.9688, 113713.4375,   1849.0312,
#         23543.6875,  10728.    ,  10312.0312, 131219.9688,  -1228.0938,
#         10450.5312,  -7078.5312,  -9882.8438, 198999.1562, 212461.375 ,
#         16644.4688,   9342.1562,   -545.4688,    135.9688,   7574.5625,
#          7721.0625, -11103.5   ,  61228.8125,  10104.5938, 195996.9375,
#        -23860.0312,  12626.375 ,  17943.8125, 113347.4062,  24635.1562,
#         93396.6562,  -2357.1875,     82.5938,   6620.3125,  -2303.8125,
#        205443.2188,   4357.8438,   3399.0625, -10124.125 ,   9834.3438,
#          6388.8438,  79324.5   ,  94062.3438,   9982.9062, 242093.5312,
#          4051.    ,  12519.5312])

# %%
def correlation(X, y):
    res = [np.abs(np.corrcoef(X[:,i], y)[1,0]) for i in range(5)]
    return res
 
def LRC(X, y):
    std = np.std(X, axis=0)
    std_X = X/std
    
    reg = LinearRegression().fit(X, y)
    coef_sum = np.sum(np.abs(reg.coef_))
    res = np.abs(reg.coef_)/coef_sum
    return res
 
def plot_importance(X, y, importance):
    temp1 = X.columns
    temp2 = importance(X, y)
    result = sorted(zip(temp1, temp2), key=lambda x:x[1])
    label = [x[0] for x in result]
    value = [x[1] for x in result]
    fig = plt.figure(figsize=(6,7))
    fig.set_facecolor('white')
    plt.barh(label, value, height=0.5)
    plt.show()
    print(temp2)

# %%
lr_model = RandomForestRegressor()
x_train, x_test, y_train, y_test = train_test_split(x_features, y_target, test_size = 0.2, random_state=156)

lr_model.fit(x_train,y_train)
pred = lr_model.predict(x_test)

print(lr_model.feature_importances_)

mse = mean_squared_error(y_test, pred)
mae = mean_absolute_error(y_test, pred)
r2 = r2_score(y_test,pred)
rmse = np.sqrt(mse)

print(rmse)
print(mae)
print(r2)
# Out:
# [0.016  0.0179 0.0169 0.0048 0.0031 0.013  0.0203 0.0003 0.     0.0004
#  0.1015 0.0033 0.0146 0.     0.     0.6572 0.     0.089  0.0004 0.0001
#  0.     0.     0.0215 0.0019 0.0011 0.     0.     0.0117 0.0002 0.0046
#  0.     0.     0.     0.    ]
# 41821.61817161338
# 18218.567019400354
# 0.874049462798911

# %%
def correlation(X, y):
    res = [np.abs(np.corrcoef(X[:,i], y)[1,0]) for i in range(5)]
    return res
 
def LRC(X, y):
    std = np.std(X, axis=0)
    std_X = X/std
    reg = RandomForestRegressor().fit(X, y)
    coef_sum = np.sum(np.abs(reg.feature_importances_))
    res = np.abs(reg.feature_importances_)/coef_sum
    return res
 
def plot_importance(X, y, importance):
    temp1 = X.columns
    temp2 = importance(X, y)
    result = sorted(zip(temp1, temp2), key=lambda x:x[1])
    label = [x[0] for x in result]
    value = [x[1] for x in result]
    fig = plt.figure(figsize=(6,7))
    fig.set_facecolor('white')
    plt.barh(label, value, height=0.5)
    plt.show()
    print(temp2)

# %%
LRC(x_features,y_target)
# Out:
# array([0.0181, 0.0188, 0.0171, 0.005 , 0.0039, 0.0126, 0.0204, 0.0003,
#        0.    , 0.0004, 0.1101, 0.0033, 0.013 , 0.    , 0.    , 0.6498,
#        0.    , 0.0842, 0.0003, 0.0001, 0.    , 0.    , 0.0236, 0.002 ,
#        0.0012, 0.    , 0.    , 0.0112, 0.0002, 0.0044, 0.    , 0.    ,
#        0.    , 0.    ])

# %%
from matplotlib import font_manager, rc # 한글넣기

font_path = './malgun.ttf' # 해당파일 visualization > dataset에 있음
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력하게 해주는것

plot_importance(x_features,y_target,LRC)
# Out:
# [0.0192 0.0188 0.0173 0.0046 0.0038 0.0138 0.0196 0.0003 0.     0.0004
#  0.1143 0.0035 0.0134 0.     0.     0.6421 0.     0.0843 0.0004 0.0001
#  0.     0.     0.0245 0.002  0.0012 0.     0.     0.0113 0.0002 0.0047
#  0.     0.     0.     0.    ]

# %%
clf = LazyRegressor(verbose=0, predictions=True)
# clf2 = LazyRegressor(verbose=0, predictions=True)

# models, predictions = clf2.fit(x_train, x_test, y_train, y_test)
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:08<00:00,  5.05it/s]
#                                      Adjusted R-Squared  \
# Model
# LGBMRegressor                                      0.89
# HistGradientBoostingRegressor                      0.89
# SGDRegressor                                       0.88
# LassoCV                                            0.88
# LassoLarsCV                                        0.88
# LarsCV                                             0.88
# LassoLars                                          0.88
# Lasso                                              0.88
# Lars                                               0.88
# TransformedTargetRegressor                         0.88
# LinearRegression                                   0.88
# Ridge                                              0.88
# BayesianRidge                                      0.88
# RidgeCV                                            0.88
# GradientBoostingRegressor                          0.88
# HuberRegressor                                     0.88
# PassiveAggressiveRegressor                         0.87
# LassoLarsIC                                        0.87
# RandomForestRegressor                              0.86
# BaggingRegressor                                   0.86
# ExtraTreesRegressor                                0.86
# KNeighborsRegressor                                0.86
# XGBRegressor                                       0.85
# OrthogonalMatchingPursuitCV                        0.85
# ExtraTreeRegressor                                 0.83
# OrthogonalMatchingPursuit                          0.80
# DecisionTreeRegressor                              0.78
# ElasticNet                                         0.77
# AdaBoostRegressor                                  0.74
# GaussianProcessRegressor                           0.72
# TweedieRegressor                                   0.64
# KernelRidge                                        0.64
# ElasticNetCV                                      -0.04
# DummyRegressor                                    -0.06
# NuSVR                                             -0.15
# SVR                                               -0.24
# MLPRegressor                                      -0.26
# LinearSVR                                         -0.30
# RANSACRegressor               -323309052477544333312.00
#
#                                               R-Squared                RMSE  \
# Model
# LGBMRegressor                                      0.90            37838.64
# HistGradientBoostingRegressor                      0.89            38244.33
# SGDRegressor                                       0.89            39419.30
# LassoCV                                            0.89            39540.92
# LassoLarsCV                                        0.89            39542.94
# LarsCV                                             0.89            39542.94
# LassoLars                                          0.89            39543.54
# Lasso                                              0.89            39550.02
# Lars                                               0.89            39550.19
# TransformedTargetRegressor                         0.89            39550.19
# LinearRegression                                   0.89            39550.19
# Ridge                                              0.89            39552.48
# BayesianRidge                                      0.89            39558.31
# RidgeCV                                            0.89            39575.42
# GradientBoostingRegressor                          0.88            40271.29
# HuberRegressor                                     0.88            40370.35
# PassiveAggressiveRegressor                         0.88            40931.75
# LassoLarsIC                                        0.88            41614.61
# RandomForestRegressor                              0.87            42049.47
# BaggingRegressor                                   0.87            42123.63
# ExtraTreesRegressor                                0.87            42837.36
# KNeighborsRegressor                                0.87            42933.46
# XGBRegressor                                       0.86            44089.18
# OrthogonalMatchingPursuitCV                        0.86            44153.93
# ExtraTreeRegressor                                 0.84            47146.84
# OrthogonalMatchingPursuit                          0.82            50461.56
# DecisionTreeRegressor                              0.80            53335.20
# ElasticNet                                         0.79            54444.15
# AdaBoostRegressor                                  0.75            58647.73
# GaussianProcessRegressor                           0.73            60931.58
# TweedieRegressor                                   0.67            68138.89
# KernelRidge                                        0.66            68674.48
# ElasticNetCV                                       0.02           116765.01
# DummyRegressor                                    -0.00           117857.26
# NuSVR                                             -0.08           122379.54
# SVR                                               -0.17           127243.03
# MLPRegressor                                      -0.18           128232.33
# LinearSVR                                         -0.22           130400.00
# RANSACRegressor               -303887660632603557888.00 2054269194025806.75
#
#                                Time Taken
# Model
# LGBMRegressor                        0.10
# HistGradientBoostingRegressor        1.80
# SGDRegressor                         0.02
# LassoCV                              0.09
# LassoLarsCV                          0.05
# LarsCV                               0.05
# LassoLars                            0.01
# Lasso                                0.06
# Lars                                 0.01
# TransformedTargetRegressor           0.01
# LinearRegression                     0.01
# Ridge                                0.01
# BayesianRidge                        0.01
# RidgeCV                              0.02
# GradientBoostingRegressor            0.24
# HuberRegressor                       0.05
# PassiveAggressiveRegressor           0.11
# LassoLarsIC                          0.01
# RandomForestRegressor                0.94
# BaggingRegressor                     0.10
# ExtraTreesRegressor                  0.69
# KNeighborsRegressor                  0.09
# XGBRegressor                         0.19
# OrthogonalMatchingPursuitCV          0.02
# ExtraTreeRegressor                   0.02
# OrthogonalMatchingPursuit            0.01
# DecisionTreeRegressor                0.02
# ElasticNet                           0.01
# AdaBoostRegressor                    0.09
# GaussianProcessRegressor             0.58
# TweedieRegressor                     0.01
# KernelRidge                          0.18
# ElasticNetCV                         0.07
# DummyRegressor                       0.01
# NuSVR                                0.26
# SVR                                  0.32
# MLPRegressor                         1.72
# LinearSVR                            0.01
# RANSACRegressor                      0.07

# %%
import lightgbm as lgb
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import accuracy_score,confusion_matrix
import numpy as np
def lgb_evaluate(numLeaves, maxDepth, scaleWeight, minChildWeight, subsample, colSam):
    reg=lgb.LGBMRegressor(num_leaves=31, max_depth= 2,scale_pos_weight= scaleWeight, min_child_weight= minChildWeight, subsample= 0.4, colsample_bytree= 0.4, learning_rate=0.05,   n_estimators=20)
#   scores = cross_val_score(reg, train_x, train_y, cv=5, scoring='roc_auc')
    scores = cross_val_score(reg, train_x, train_y, cv=5, scoring='neg_mean_squared_error')
    return np.mean(scores)
def bayesOpt(train_x, train_y):
    lgbBO = BayesianOptimization(lgb_evaluate, {  'numLeaves':  (5, 90),  'maxDepth': (2, 90),   'scaleWeight': (1, 10000),  'minChildWeight': (0.01, 70), 'subsample': (0.4, 1), 'colSam': (0.4, 1) })
    lgbBO.maximize(init_points=5, n_iter=50)
    print(lgbBO.res)
boston = load_boston()
X, y = boston.data, boston.target
train_x, X_test, train_y, y_test = train_test_split(X, y, test_size=0.2)
bayesOpt(train_x, train_y)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
dic = {}
for i in dataset_detail_week['제품명'].unique():
    count=len(dataset_detail_week[dataset_detail_week['제품명']==i])
    dic.setdefault(i,count)

# %%
li=sorted(dic.items(), key=lambda x: x[1], reverse=True)

# %%
top_10=li[:10]

# %%
top_li = []
for i in top_10:
    top_li.append(i[0])

# %%
top_li
# Out:
# ['PEMA-HR1000',
#  'CSA5000',
#  'PEMA-HR1500',
#  'PEMA-SR2000',
#  'PEMA-PR1000',
#  'PEMA-SR3000F',
#  'PEMA-580FX',
#  'AE',
#  'PEMA-SN400',
#  'PEMA-PR2000']

# %%
pro1=dataset_detail_week[dataset_detail_week['제품명'] == 'PEMA-HR1000']

# %%
pro1.index.unique()
# Out:
# Index(['2020-01-07', '2020-01-14', '2020-01-21', '2020-01-28', '2020-02-04',
#        '2020-02-11', '2020-02-18', '2020-02-25', '2020-03-03', '2020-03-10',
#        ...
#        '2021-11-02', '2021-11-09', '2021-11-16', '2021-11-23', '2021-11-30',
#        '2021-12-07', '2021-12-14', '2021-12-21', '2021-12-28', '2022-01-04'],
#       dtype='object', length=105)

# %%
pro1=pro1.reset_index()

# %%
pro1
# Out:
#            index  평균온도  일강수량  상대습도  최심적설  기준금리       연면적별    거래처코드  \
# 0     2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004000
# 1     2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004100
# 2     2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004104
# 3     2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004200
# 4     2020-01-07  2.75  7.03 72.22  0.02  1.25 1400114.94  2004300
# ...          ...   ...   ...   ...   ...   ...        ...      ...
# 7450  2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003500
# 7451  2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003600
# 7452  2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003700
# 7453  2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003800
# 7454  2022-01-04 -0.51  0.23 61.19  0.44  1.00 1367682.68  2003900
#
#               제품명      수주량
# 0     PEMA-HR1000 15000.00
# 1     PEMA-HR1000 15000.00
# 2     PEMA-HR1000 10000.00
# 3     PEMA-HR1000     0.00
# 4     PEMA-HR1000     0.00
# ...           ...      ...
# 7450  PEMA-HR1000     0.00
# 7451  PEMA-HR1000     0.00
# 7452  PEMA-HR1000  6000.00
# 7453  PEMA-HR1000     0.00
# 7454  PEMA-HR1000     0.00
#
# [7455 rows x 10 columns]

# %%
t=pro1.pivot_table(index='index',
                values = '수주량',
                aggfunc='sum')

# %%
features=pro1.pivot_table(index='index',
                values = ['평균온도','일강수량','상대습도','최심적설','기준금리','연면적별'],
                aggfunc='mean')

# %%
pro1_train_df = features.join(t)

# %%
pro1_train_df=pro1_train_df[12:].reset_index(drop=True)

# %%
pro1_train_df.index=pro1_train_df.index+1

# %%
pro1_train_df.rename({'수주량' : '13수주량'}, axis=1, inplace=True)

# %%
t.reset_index(drop=True, inplace=True)

# %%
t.index = t.index +1

# %%
t=t[:93]

# %%
PEMA_HR1000_df=pro1_train_df.join(t)

# %%
def top_list(pro_df):
    dic = {}
    for i in pro_df['제품명'].unique():
        count=len(pro_df[pro_df['제품명']==i])
        dic.setdefault(i,count)
    li=sorted(dic.items(), key=lambda x: x[1], reverse=True)
    top_li = []
    for i in li:
        top_li.append(i[0])
    return top_li

# %%
top_li = top_list(dataset_detail_week)
top_li
# Out:
# ['PEMA-HR1000',
#  'CSA5000',
#  'PEMA-HR1500',
#  'PEMA-SR2000',
#  'PEMA-PR1000',
#  'PEMA-SR3000F',
#  'PEMA-580FX',
#  'AE',
#  'PEMA-SN400',
#  'PEMA-PR2000',
#  'PEMA-500FR',
#  'CSA4000',
#  'PEMA-PCM2000',
#  'PEMA-PCM2000B',
#  'PEMA-SR2000A',
#  'PEMA-CR1000',
#  'PEMA-PCR3000E',
#  'PR1000',
#  'PEMA-SR5000F',
#  'PEMA-SP1000',
#  'PEMA-CSA5000',
#  'SRE-110',
#  'PEMA-PCR3000N',
#  'SRE-200',
#  'PEMA-SPR',
#  'PEMA-HR1000S',
#  'ARE-580FX']

# %%
def make_product_df(pro_df):
    top_li = top_list(pro_df)
    
    df_li = []
    for i in top_li:
        df = pro_df[pro_df['제품명']==i]
        df=df.reset_index()
        t=df.pivot_table(index='index',
                    values = '수주량',
                    aggfunc='sum')
        features=df.pivot_table(index='index',
                    values = ['평균온도','일강수량','상대습도','최심적설','기준금리','연면적별'],
                    aggfunc='mean')
        new_df = features.join(t)
        new_df=new_df[12:].reset_index(drop=True)
        new_df.index=new_df.index+1
        new_df=new_df.rename({'수주량' : '13수주량'}, axis=1)
        t.reset_index(drop=True, inplace=True)
        t.index = t.index +1
        t=t[:93]
        product_df=new_df.join(t)
        df_li.append(product_df)
    return df_li, top_li

# %%
df_li,top_li=make_product_df(dataset_detail_week)

# %%
for i in top_li:
    print(f'{i}')
    print(df_dic[i])
# Out:
# PEMA-HR1000
#     기준금리  상대습도  연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75  0.73  0.73  2.20  0.00 10.30 634550.00 338000.00
# 2   0.75  0.59  0.59  0.12  0.00  9.62 687000.00 297000.00
# 3   0.75  0.59  0.59  1.05  0.00  9.47 528000.00 567000.00
# 4   0.75  0.59  0.59  4.95  0.00 11.43 623000.00 278000.00
# 5   0.75  0.59  0.59  0.06  0.00 10.85 563000.00 559050.00
# ..   ...   ...   ...   ...   ...   ...       ...       ...
# 89  1.00  1.00  1.00  0.23  0.00  3.70 578000.00 574000.00
# 90  1.00  1.00  1.00  0.10  0.00  4.86 294000.00 600000.00
# 91  1.00  1.00  1.00  0.51  0.19  3.08 466000.00 615550.00
# 92  1.00  1.00  1.00  0.48  0.58 -1.19 461000.00 778000.00
# 93  1.00  0.00  0.00  0.23  0.44 -0.51 252000.00 463000.00
#
# [93 rows x 8 columns]
# CSA5000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 285000.00 133000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 266000.00 131000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 253000.00 219000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 352000.00 193000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 170000.00 181000.00
# ..   ...   ...        ...   ...   ...   ...       ...       ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 227000.00 270000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 155000.00 237000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 257000.00 285000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 212000.00 316000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 161000.00 237000.00
#
# [93 rows x 8 columns]
# PEMA-HR1500
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 213000.00 168000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 247000.00  50000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 238000.00 148000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 260540.00 192000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 258000.00 226000.00
# ..   ...   ...        ...   ...   ...   ...       ...       ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 217000.00 139000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 178000.00 279000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 196540.00 199000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 216540.00 267000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 101000.00 247000.00
#
# [93 rows x 8 columns]
# PEMA-SR2000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30  75000.00  85000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 107570.00  45000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47  90000.00  49000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 108000.00  74000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85  85000.00  97000.00
# ..   ...   ...        ...   ...   ...   ...       ...       ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70  97570.00  67000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  43000.00  79000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  76000.00  89000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  46000.00 115000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51  63000.00  73570.00
#
# [93 rows x 8 columns]
# PEMA-PR1000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30  84000.00  85000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 210000.00  70000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 110000.00 107000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 156000.00 100000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 110000.00  75000.00
# ..   ...   ...        ...   ...   ...   ...       ...       ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 185000.00 117000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  15000.00 140000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  65000.00  89000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  80000.00 205000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51  66000.00  15000.00
#
# [93 rows x 8 columns]
# PEMA-SR3000F
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 79000.00 46000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 58000.00 43000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 31000.00 36000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 96000.00 46000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 46000.00 43000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 48000.00 26000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 28000.00 47000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 96000.00 59000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 81000.00 77000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 25000.00 46000.00
#
# [93 rows x 8 columns]
# PEMA-580FX
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 125000.00  65000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 160000.00  15000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 170000.00  95000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 120000.00  10000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 120000.00  15000.00
# ..   ...   ...        ...   ...   ...   ...       ...       ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 100000.00 105000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  40000.00  35000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  70000.00  45000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  40000.00 135000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51  90000.00  75000.00
#
# [93 rows x 8 columns]
# AE
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30  8000.00 17000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62  9000.00  6000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 17000.00 29000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 21000.00 11000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 20000.00 10000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70  8000.00 45000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  7000.00 19000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 20000.00  2000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 17000.00  7000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51  6000.00 15000.00
#
# [93 rows x 8 columns]
# PEMA-SN400
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 50000.00 35000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 45000.00 18000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 32000.00  5000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 40000.00 12800.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 35000.00 20000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 45000.00  5000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 22000.00 12800.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 35000.00 30000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 27000.00 60000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 30000.00 10000.00
#
# [93 rows x 8 columns]
# PEMA-PR2000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 59000.00 35000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 11000.00 10000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 51000.00 55000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 55000.00  5000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 35000.00 45000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 11000.00 55000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 16000.00 40000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 30000.00 20000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  6000.00 60000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 30000.00 25000.00
#
# [93 rows x 8 columns]
# PEMA-500FR
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 72000.00 55000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 60000.00 25000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 33000.00 44000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 78000.00 13000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 55000.00 60000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 43000.00 36000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86     0.00 43000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 58000.00 40000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 38000.00 95000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 20000.00     0.00
#
# [93 rows x 8 columns]
# CSA4000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 10000.00 12000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 23000.00 20000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 27000.00     0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 15000.00 20000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 12000.00  2000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 23000.00     0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 17000.00 29000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  5000.00 10000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 15000.00 33000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00  7000.00
#
# [93 rows x 8 columns]
# PEMA-PCM2000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 10000.00  8000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 27000.00 10000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 13000.00 10000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 10000.00 20000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 20000.00 14000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 27000.00 18000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  8000.00 25000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  5000.00 21000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  3000.00 22000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 10000.00 18000.00
#
# [93 rows x 8 columns]
# PEMA-PCM2000B
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 10000.00     0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62  4000.00  3000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 13000.00 10000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 10000.00  7000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85  5000.00  5000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70  4000.00 10000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  8000.00 12000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  5000.00  5000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  3000.00  9000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51 10000.00  8000.00
#
# [93 rows x 8 columns]
# PEMA-SR2000A
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 17000.00 17000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62  7000.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 12000.00 27000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 12000.00  7000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 17000.00  7000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70  7000.00 17000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 12000.00 12000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08  5000.00  7000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 12000.00 17000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00 12000.00
#
# [93 rows x 8 columns]
# PEMA-CR1000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 20000.00 10000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62     0.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47     0.00 20000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43     0.00 10000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 10000.00 10000.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70     0.00 10000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86     0.00 10000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08     0.00 10000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19     0.00 10000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00     0.00
#
# [93 rows x 8 columns]
# PEMA-PCR3000E
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도   13수주량     수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 5000.00    0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62    0.00    0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 5000.00 5000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 6000.00    0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85    0.00    0.00
# ..   ...   ...        ...   ...   ...   ...     ...     ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70    0.00 5000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 5000.00    0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 6000.00 5000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 6000.00 5000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51    0.00 5000.00
#
# [93 rows x 8 columns]
# PR1000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도  13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30   0.00     0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62   0.00 14000.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47   0.00 28000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43   0.00     0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85   0.00     0.00
# ..   ...   ...        ...   ...   ...   ...    ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70   0.00 28000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86   0.00     0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08   0.00     0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19   0.00     0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51   0.00     0.00
#
# [93 rows x 8 columns]
# PEMA-SR5000F
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도   13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30    0.00     0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 2000.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47    0.00 10000.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43    0.00     0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85    0.00  5000.00
# ..   ...   ...        ...   ...   ...   ...     ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 2000.00 10000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86    0.00     0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08    0.00  5000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19    0.00  2000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51    0.00     0.00
#
# [93 rows x 8 columns]
# PEMA-SP1000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도   13수주량     수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30 7000.00    0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62    0.00    0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47    0.00    0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43    0.00 4000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85    0.00    0.00
# ..   ...   ...        ...   ...   ...   ...     ...     ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70    0.00 4000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86    0.00    0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08    0.00 2000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19    0.00 5000.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51    0.00    0.00
#
# [93 rows x 8 columns]
# PEMA-CSA5000
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30     0.00 10000.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62     0.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47     0.00     0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 10000.00 10000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 10000.00     0.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70     0.00     0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86     0.00 10000.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08 10000.00     0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 10000.00     0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00     0.00
#
# [93 rows x 8 columns]
# SRE-110
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30     0.00 39600.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62     0.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47  3000.00     0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43     0.00     0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85 39600.00     0.00
# ..   ...   ...        ...   ...   ...   ...      ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70     0.00     0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86  3000.00     0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08     0.00     0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19  3000.00     0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00     0.00
#
# [93 rows x 8 columns]
# PEMA-PCR3000N
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도  13수주량     수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30   0.00    0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62   0.00    0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47   0.00    0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43   0.00 4000.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85   0.00 3000.00
# ..   ...   ...        ...   ...   ...   ...    ...     ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70   0.00 4000.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86   0.00    0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08   0.00 3000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19   0.00    0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51   0.00    0.00
#
# [93 rows x 8 columns]
# SRE-200
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도  13수주량      수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30   0.00     0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62   0.00     0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47   0.00     0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43   0.00     0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85   0.00 15000.00
# ..   ...   ...        ...   ...   ...   ...    ...      ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70   0.00     0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86   0.00     0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08   0.00 15000.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19   0.00     0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51   0.00     0.00
#
# [93 rows x 8 columns]
# PEMA-SPR
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도   13수주량     수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30    0.00    0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62 2500.00    0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47    0.00    0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43    0.00    0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85    0.00    0.00
# ..   ...   ...        ...   ...   ...   ...     ...     ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70 2500.00    0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86    0.00    0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08    0.00    0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19    0.00 2500.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51    0.00    0.00
#
# [93 rows x 8 columns]
# PEMA-HR1000S
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량  수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30     0.00 0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62     0.00 0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47 10000.00 0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43     0.00 0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85     0.00 0.00
# ..   ...   ...        ...   ...   ...   ...      ...  ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70     0.00 0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86 10000.00 0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08     0.00 0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19 10000.00 0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00 0.00
#
# [93 rows x 8 columns]
# ARE-580FX
#     기준금리  상대습도       연면적별  일강수량  최심적설  평균온도    13수주량  수주량
# 1   0.75 65.20 2703566.42  2.20  0.00 10.30     0.00 0.00
# 2   0.75 49.08 2445649.27  0.12  0.00  9.62     0.00 0.00
# 3   0.75 56.94 2445649.27  1.05  0.00  9.47     0.00 0.00
# 4   0.75 67.63 2445649.27  4.95  0.00 11.43 12100.00 0.00
# 5   0.75 50.09 2445649.27  0.06  0.00 10.85     0.00 0.00
# ..   ...   ...        ...   ...   ...   ...      ...  ...
# 89  1.00 64.27 3191259.58  0.23  0.00  3.70     0.00 0.00
# 90  1.00 69.05 3191259.58  0.10  0.00  4.86     0.00 0.00
# 91  1.00 66.75 3191259.58  0.51  0.19  3.08     0.00 0.00
# 92  1.00 59.43 3191259.58  0.48  0.58 -1.19     0.00 0.00
# 93  1.00 61.19 1367682.68  0.23  0.44 -0.51     0.00 0.00
#
# [93 rows x 8 columns]

# %%
df_dic = {}
for i,j in zip(top_li, df_li):
    df_dic.setdefault(i,j)

# %%
df_dic.keys()
# Out:
# dict_keys(['PEMA-HR1000', 'CSA5000', 'PEMA-HR1500', 'PEMA-SR2000', 'PEMA-PR1000', 'PEMA-SR3000F', 'PEMA-580FX', 'AE', 'PEMA-SN400', 'PEMA-PR2000', 'PEMA-500FR', 'CSA4000', 'PEMA-PCM2000', 'PEMA-PCM2000B', 'PEMA-SR2000A', 'PEMA-CR1000', 'PEMA-PCR3000E', 'PR1000', 'PEMA-SR5000F', 'PEMA-SP1000', 'PEMA-CSA5000', 'SRE-110', 'PEMA-PCR3000N', 'SRE-200', 'PEMA-SPR', 'PEMA-HR1000S', 'ARE-580FX'])

# %%
PEMA_HR1000_df = df_li[0]

# %%
df = pd.DataFrame(PEMA_HR1000_df['연면적별'])

obj = MinMaxScaler()
PEMA_HR1000_df['연면적별']=obj.fit_transform(df)

obj2 = MinMaxScaler()
PEMA_HR1000_df['상대습도']=obj2.fit_transform(df)

x_features = PEMA_HR1000_df.drop(['13수주량'], axis=1, inplace=False)
y_target = PEMA_HR1000_df['13수주량']

# %%
PEMA_HR1000_df
# Out:
#     기준금리  상대습도  연면적별  일강수량  최심적설  평균온도     13수주량       수주량
# 1   0.75  0.73  0.73  2.20  0.00 10.30 634550.00 338000.00
# 2   0.75  0.59  0.59  0.12  0.00  9.62 687000.00 297000.00
# 3   0.75  0.59  0.59  1.05  0.00  9.47 528000.00 567000.00
# 4   0.75  0.59  0.59  4.95  0.00 11.43 623000.00 278000.00
# 5   0.75  0.59  0.59  0.06  0.00 10.85 563000.00 559050.00
# ..   ...   ...   ...   ...   ...   ...       ...       ...
# 89  1.00  1.00  1.00  0.23  0.00  3.70 578000.00 574000.00
# 90  1.00  1.00  1.00  0.10  0.00  4.86 294000.00 600000.00
# 91  1.00  1.00  1.00  0.51  0.19  3.08 466000.00 615550.00
# 92  1.00  1.00  1.00  0.48  0.58 -1.19 461000.00 778000.00
# 93  1.00  0.00  0.00  0.23  0.44 -0.51 252000.00 463000.00
#
# [93 rows x 8 columns]

# %%
lr_model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x_features, y_target, test_size = 0.12, random_state=156)

lr_model.fit(x_train,y_train)
pred = lr_model.predict(x_test)

print(lr_model.coef_)

mse = mean_squared_error(y_test, pred)
mae = mean_absolute_error(y_test, pred)
r2 = r2_score(y_test,pred)
rmse = np.sqrt(mse)

print(f'RMSE : {rmse}')
print(f'MAE : {mae}')
print(f'R2_score : {r2}')
# Out:
# [-9.33730816e+04  3.12519576e+03  3.12519576e+03 -3.82450495e+03
#  -2.09566895e+05  3.93678432e+02 -2.45466263e-01]
# RMSE : 174741.16645900815
# MAE : 128919.41345357924
# R2_score : 0.06968334663959475

# %%
len(y_test)
# Out:
# 12

# %%
import matplotlib.pyplot as plt

x= range(len(pred))
y = pred



plt.plot(x,y_test, 'b')

plt.plot(x,y, 'y')

plt.show()

# %%
def correlation(X, y):
    res = [np.abs(np.corrcoef(X[:,i], y)[1,0]) for i in range(5)]
    return res
 
def LRC(X, y):
    std = np.std(X, axis=0)
    std_X = X/std
    
    reg = LinearRegression().fit(X, y)
    coef_sum = np.sum(np.abs(reg.coef_))
    res = np.abs(reg.coef_)/coef_sum
    return res
 
def plot_importance(X, y, importance):
    temp1 = X.columns
    temp2 = importance(X, y)
    result = sorted(zip(temp1, temp2), key=lambda x:x[1])
    label = [x[0] for x in result]
    value = [x[1] for x in result]
    fig = plt.figure(figsize=(6,7))
    fig.set_facecolor('white')
    plt.barh(label, value, height=0.5)
    plt.show()
    print(temp2)

# %%
from matplotlib import font_manager, rc # 한글넣기

font_path = './malgun.ttf' # 해당파일 visualization > dataset에 있음
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력하게 해주는것

plot_importance(x_features,y_target,LRC)
# Out:
# [2.13123743e-01 1.23685063e-01 1.23685062e-01 4.19719453e-03
#  5.34837453e-01 4.71035773e-04 4.48819694e-07]

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features, y_target, test_size = 0.3, random_state=0)

clf = LazyRegressor(verbose=0, predictions=True)
# clf2 = LazyRegressor(verbose=0, predictions=True)

# models, predictions = clf2.fit(x_train, x_test, y_train, y_test)
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:01<00:00, 38.43it/s]
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# GradientBoostingRegressor                    0.12       0.35 136972.74
# AdaBoostRegressor                            0.09       0.33 139338.26
# SGDRegressor                                -0.04       0.23 149111.12
# Ridge                                       -0.04       0.23 149191.79
# Lars                                        -0.04       0.23 149198.60
# TransformedTargetRegressor                  -0.04       0.23 149198.60
# LinearRegression                            -0.04       0.23 149198.60
# Lasso                                       -0.04       0.23 149199.81
# LassoLars                                   -0.04       0.23 149208.43
# PoissonRegressor                            -0.04       0.23 149381.64
# RidgeCV                                     -0.05       0.23 149689.41
# BaggingRegressor                            -0.06       0.22 150672.63
# ElasticNet                                  -0.08       0.20 151977.56
# RandomForestRegressor                       -0.10       0.18 153704.46
# ExtraTreesRegressor                         -0.12       0.17 154601.62
# TweedieRegressor                            -0.12       0.17 154987.77
# HuberRegressor                              -0.14       0.16 156105.25
# GammaRegressor                              -0.14       0.16 156123.64
# LassoLarsIC                                 -0.18       0.12 159259.00
# DecisionTreeRegressor                       -0.19       0.12 159963.80
# KNeighborsRegressor                         -0.26       0.07 164391.11
# LGBMRegressor                               -0.28       0.05 165489.26
# RANSACRegressor                             -0.29       0.05 165996.19
# HistGradientBoostingRegressor               -0.30       0.04 166972.74
# OrthogonalMatchingPursuitCV                 -0.32       0.02 168224.16
# OrthogonalMatchingPursuit                   -0.32       0.02 168224.16
# LassoCV                                     -0.33       0.02 168711.89
# LarsCV                                      -0.33       0.02 168713.74
# LassoLarsCV                                 -0.33       0.02 168713.74
# NuSVR                                       -0.35      -0.00 170131.81
# ElasticNetCV                                -0.36      -0.01 170816.81
# BayesianRidge                               -0.36      -0.01 170820.96
# DummyRegressor                              -0.36      -0.01 170820.96
# SVR                                         -0.39      -0.03 172724.89
# XGBRegressor                                -0.58      -0.17 183816.19
# ExtraTreeRegressor                          -0.66      -0.23 188892.45
# GaussianProcessRegressor                    -3.81      -2.56 321010.35
# PassiveAggressiveRegressor                 -11.64      -8.36 520535.39
# KernelRidge                                -14.28     -10.32 572265.15
# LinearSVR                                  -14.82     -10.72 582291.93
# MLPRegressor                               -14.82     -10.72 582342.91
#
#                                Time Taken
# Model
# GradientBoostingRegressor            0.03
# AdaBoostRegressor                    0.06
# SGDRegressor                         0.01
# Ridge                                0.01
# Lars                                 0.01
# TransformedTargetRegressor           0.01
# LinearRegression                     0.01
# Lasso                                0.01
# LassoLars                            0.01
# PoissonRegressor                     0.01
# RidgeCV                              0.01
# BaggingRegressor                     0.02
# ElasticNet                           0.01
# RandomForestRegressor                0.11
# ExtraTreesRegressor                  0.08
# TweedieRegressor                     0.01
# HuberRegressor                       0.02
# GammaRegressor                       0.01
# LassoLarsIC                          0.01
# DecisionTreeRegressor                0.01
# KNeighborsRegressor                  0.01
# LGBMRegressor                        0.03
# RANSACRegressor                      0.05
# HistGradientBoostingRegressor        0.08
# OrthogonalMatchingPursuitCV          0.01
# OrthogonalMatchingPursuit            0.01
# LassoCV                              0.05
# LarsCV                               0.03
# LassoLarsCV                          0.02
# NuSVR                                0.01
# ElasticNetCV                         0.06
# BayesianRidge                        0.01
# DummyRegressor                       0.00
# SVR                                  0.01
# XGBRegressor                         0.12
# ExtraTreeRegressor                   0.01
# GaussianProcessRegressor             0.01
# PassiveAggressiveRegressor           0.01
# KernelRidge                          0.01
# LinearSVR                            0.01
# MLPRegressor                         0.10
