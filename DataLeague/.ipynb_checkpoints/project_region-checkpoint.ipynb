# %%
# 사각형 내 상가분석
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = '2WKhofO%2FP%2Fzyhb%2FYYUq6fVtO08ZFBBiJ%2B7abwe9sV7Y%2BP9sWIADFvAVKjMJc6qln2Kabc6cgEs4anTIddxB7Tg%3D%3D'
res_id = 'store'

def baro_api(skey, res_id, encode):
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + encode   
    query = url + params
    
    response = Request(query)
    response.get_method = lambda: 'GET'
    response_body = urlopen(response).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']

    df = pd.DataFrame(items)
    return df

# %%
# 역 주변 350m반경 내의 상가정보
# 역 좌표에 경도, 위도 대비 350m만큼의 사각좌표 구하기
def xy(x,y):
    max_x = x + 0.00350
    max_y = y + 0.00350
    min_x = x - 0.00350    
    min_y = y - 0.00350        
    return (min_x, min_y, max_x, max_y)
# xy좌표 값 : 이대역 좌표
min_x, min_y, max_x, max_y = xy(126.945857, 37.556761)

import numpy as np
#좌표로 계산된 지역, 구역 나누기
print(min_x, min_y, max_x, max_y )
li_x = np.linspace(min_x,max_x,20)
li_y = np.linspace(min_y,max_y,20)
#좌표 API 내에 넣고 데이터 프레임 만들기
df_s = np.NaN
for i in range(len(li_x)-1):
    x0 = li_x[i]
    x1 = li_x[i+1]
    for j in range(len(li_y)-1):
        y0 = li_y[j]
        y1 = li_y[j+1]
        
        # #이대역 37.556761, 126.945857
        encode = urlencode({quote_plus('catId'):'rectangle'
                            , quote_plus('minx'):x0, quote_plus('miny'):y0
                            , quote_plus('maxx'):x1, quote_plus('maxy'):y1})

        df_t = baro_api(skey, res_id, encode)
        #print(i, j, type(df_t), len(df_t))

        if type(df_t) == type(pd.DataFrame()) and len(df_t) > 0:        
            if type(df_s) == type(pd.DataFrame()) and len(df_s) > 0:
                #df_s = pd.concat(df_s,df_t, ignore_index=True)
                df_s = pd.concat([df_s, df_t], axis = 0, ignore_index=True)
            else:
                df_s = df_t    

df_s
# Out:
# 126.942357 37.553261 126.949357 37.560261000000004

# %%
# 데이터프레임 내에 중복값 확인 및 처리
print(df_s.duplicated().sum())
# Out:
# 0

# %%
df_s.drop_duplicates(inplace = True)
# 중복값 재확인
df_s.duplicated().sum()
df_s.to_json('df_region.json', orient='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df_s.drop_duplicates(inplace = True)
#       2 # 중복값 재확인
#       3 df_s.duplicated().sum()
#
# NameError: name 'df_s' is not defined

# %%
import warnings
warnings.filterwarnings('ignore')
df_s[df_s.indsLclsCd == 'Q'][df_s.bizesNm == '']
# Out:
# Empty DataFrame
# Columns: [bizesId, bizesNm, brchNm, indsLclsCd, indsLclsNm, indsMclsCd, indsMclsNm, indsSclsCd, indsSclsNm, ksicCd, ksicNm, ctprvnCd, ctprvnNm, signguCd, signguNm, adongCd, adongNm, ldongCd, ldongNm, lnoCd, plotSctCd, plotSctNm, lnoMnno, lnoSlno, lnoAdr, rdnmCd, rdnm, bldMnno, bldSlno, bldMngNo, bldNm, rdnmAdr, oldZipcd, newZipcd, dongNo, flrNo, hoNo, lon, lat]
# Index: []
#
# [0 rows x 39 columns]

# %%
df_d = pd.read_json('df_region2.json')
df_d
# Out:
#       bizesId      bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0    22414172         브레드칸                 N   관광/여가/오락        N03
# 1    12098251         머리쟁이                 F      생활서비스        F01
# 2    12620998  에이치에비뉴호텔이대점    이대점          O         숙박        O01
# 3    21954392      로뎀원룸리빙텔                 R      학문/교육        R10
# 4    11980901           팔색                 Q         음식        Q01
# ..        ...          ...    ...        ...        ...        ...
# 952  11755132       파파존스피자  이대아현점          Q         음식        Q06
# 953  12452641    파파존스이대아현점  이대아현점          Q         음식        Q07
# 954  21946384          로신이                 D         소매        D06
# 955  26159771         뮤즈웨딩                 F      생활서비스        F17
# 956  26288178          아네스                 D         소매        D05
#
#      indsMclsNm indsSclsCd    indsSclsNm  ksicCd  ...      bldMngNo     bldNm  \
# 0      연극/영화/극장     N03A06  연극/음악/예술관련기타          ...  1.144011e+24
# 1       이/미용/건강     F01A01         여성미용실  S96112  ...  1.144011e+24
# 2         호텔/콘도     O01A01         호텔/콘도          ...  1.144011e+24      대성목재
# 3       도서관/독서실     R10A02           고시원  R90212  ...  1.144011e+24
# 4            한식     Q01A01     한식/백반/한정식  I56111  ...  1.141011e+24    신촌자이엘라
# ..          ...        ...           ...     ...  ...           ...       ...
# 952          양식     Q06A01      정통양식/경양식  I56114  ...  1.141011e+24
# 953       패스트푸드     Q07A01          피자전문  I56192  ...  1.141011e+24
# 954  가방/신발/액세서리     D06A02     구두제화/캐주얼화  G47420  ...  1.141011e+24
# 955  예식/의례/관혼상제     F17A01     예식장/예식서비스  S96991  ...  1.141011e+24
# 956        의복의류     D05A01          일반의류  G47416  ...  1.141011e+24  링크(LINK)
#
#                     rdnmAdr  oldZipcd newZipcd  dongNo flrNo  hoNo  \
# 0    서울특별시 마포구 신촌로24안길 16-3    121806     4103
# 1         서울특별시 마포구 신촌로 154    121806     4104             2
# 2         서울특별시 마포구 신촌로 152    121806     4104             1
# 3         서울특별시 마포구 신촌로 154    121806     4104
# 4        서울특별시 서대문구 신촌로 149    120809     3780             1
# ..                      ...       ...      ...     ...   ...   ...
# 952      서울특별시 서대문구 신촌로 207    120822     3767             2
# 953      서울특별시 서대문구 신촌로 207    120822     3767             1
# 954      서울특별시 서대문구 신촌로 207    120822     3767             1
# 955      서울특별시 서대문구 신촌로 207    120822     3767             1
# 956      서울특별시 서대문구 신촌로 209    120822     3767             1
#
#             lon        lat
# 0    126.942434  37.555489
# 1    126.942637  37.556347
# 2    126.942560  37.556238
# 3    126.942637  37.556347
# 4    126.942483  37.556859
# ..          ...        ...
# 952  126.949133  37.557207
# 953  126.949133  37.557207
# 954  126.949133  37.557207
# 955  126.949133  37.557207
# 956  126.949258  37.557190
#
# [944 rows x 39 columns]

# %%
df_food = df_d[df_d.indsLclsCd == 'Q']
df_food.rename(columns={'bizesNm':'place'}, inplace = True) 
df_food
# Out:
#       bizesId      place brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 4    11980901         팔색                 Q         음식        Q01         한식
# 5    12033685    포원제로410                 Q         음식        Q06         양식
# 11   16553616     밥이꿀바비꿀                 Q         음식        Q01         한식
# 12   16701604        투다리    이대점          Q         음식        Q09       유흥주점
# 13   16860055         벨르                 Q         음식        Q12     커피점/카페
# ..        ...        ...    ...        ...        ...        ...        ...
# 943  12482161    플러스알파카페                 Q         음식        Q01         한식
# 944  15958983    마이헬싱키까페                 Q         음식        Q01         한식
# 947  26031006    고향순대감자탕                 Q         음식        Q01         한식
# 952  11755132     파파존스피자  이대아현점          Q         음식        Q06         양식
# 953  12452641  파파존스이대아현점  이대아현점          Q         음식        Q07      패스트푸드
#
#     indsSclsCd   indsSclsNm  ksicCd  ...      bldMngNo   bldNm  \
# 4       Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24  신촌자이엘라
# 5       Q06A01     정통양식/경양식  I56114  ...  1.141011e+24  신촌자이엘라
# 11      Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24  신촌자이엘라
# 12      Q09A07     기타일반유흥주점  I56211  ...  1.141011e+24  신촌자이엘라
# 13      Q12A01  커피전문점/카페/다방  I56220  ...  1.141011e+24  신촌자이엘라
# ..         ...          ...     ...  ...           ...     ...
# 943     Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24   핀란드타워
# 944     Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24   핀란드타워
# 947     Q01A01    한식/백반/한정식  I56111  ...  1.144011e+24
# 952     Q06A01     정통양식/경양식  I56114  ...  1.141011e+24
# 953     Q07A01         피자전문  I56192  ...  1.141011e+24
#
#                  rdnmAdr  oldZipcd newZipcd  dongNo flrNo  hoNo         lon  \
# 4     서울특별시 서대문구 신촌로 149    120809     3780             1        126.942483
# 5     서울특별시 서대문구 신촌로 149    120809     3780             1        126.942483
# 11    서울특별시 서대문구 신촌로 149    120809     3780     101              126.942483
# 12    서울특별시 서대문구 신촌로 149    120809     3780                      126.942483
# 13    서울특별시 서대문구 신촌로 149    120809     3780     101              126.942483
# ..                   ...       ...      ...     ...   ...   ...         ...
# 943   서울특별시 서대문구 신촌로 203    120808     3767             2        126.948488
# 944   서울특별시 서대문구 신촌로 203    120808     3767            -2        126.948488
# 947  서울특별시 마포구 대흥로24길 50    121870     4123             1        126.948656
# 952   서울특별시 서대문구 신촌로 207    120822     3767             2        126.949133
# 953   서울특별시 서대문구 신촌로 207    120822     3767             1        126.949133
#
#            lat
# 4    37.556859
# 5    37.556859
# 11   37.556859
# 12   37.556859
# 13   37.556859
# ..         ...
# 943  37.557201
# 944  37.557201
# 947  37.554905
# 952  37.557207
# 953  37.557207
#
# [357 rows x 39 columns]

# %%
df_ter = pd.merge(df_food, df_best, on = 'place', how = 'inner')
df_ter
# Out:
#      bizesId    place brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0   17533468     진돈부리                 Q         음식        Q03     일식/수산물
# 1   18143901     수퍼파인                 Q         음식        Q07      패스트푸드
# 2   20630100      훈카츠                 Q         음식        Q05     닭/오리요리
# 3   16325619     영미김밥                 Q         음식        Q04         분식
# 4   23382559  미스터서왕만두                 Q         음식        Q04         분식
# 5   20673833       아건                 Q         음식        Q06         양식
# 6   16603185       아건                 Q         음식        Q10    별식/퓨전요리
# 7   17010845    심플리키친                 Q         음식        Q01         한식
# 8   17079357   원앤온리커피                 Q         음식        Q12     커피점/카페
# 9   16638629      치즈문                 Q         음식        Q09       유흥주점
# 10  21980103     플로루스                 Q         음식        Q08    제과제빵떡케익
# 11  17933395     로컬식당                 Q         음식        Q01         한식
# 12  16294026     비아37                 Q         음식        Q06         양식
# 13  17838146      신화장                 Q         음식        Q02         중식
# 14  23434871   파파노다이닝                 Q         음식        Q06         양식
# 15  17533548       리카   스시카야          Q         음식        Q03     일식/수산물
# 16  18107441  굿바이슈가베어                 Q         음식        Q01         한식
# 17  16584804     청키파이                 Q         음식        Q12     커피점/카페
# 18  17009491      노란집                 Q         음식        Q06         양식
# 19  17011505     카페코지                 Q         음식        Q12     커피점/카페
# 20  19968901     파가니니                 Q         음식        Q01         한식
# 21  17038461     한끼마끼                 Q         음식        Q04         분식
# 22  12106104       다다                 Q         음식        Q06         양식
# 23  16993798     천진분식    이대점          Q         음식        Q04         분식
# 24  17137238    모미지식당                 Q         음식        Q03     일식/수산물
# 25  17156695     포케포케                 Q         음식        Q15         부페
# 26  25730957     가야가야                 Q         음식        Q04         분식
# 27  12568888    타이스토리                 Q         음식        Q01         한식
# 28  19967677  빵사이에낀과일                 Q         음식        Q07      패스트푸드
# 29  17092421    세아마라탕                 Q         음식        Q02         중식
# 30  18352531    방그레커피                 Q         음식        Q12     커피점/카페
# 31  18030884      유소바                 Q         음식        Q03     일식/수산물
# 32  17496872     원즈오운                 Q         음식        Q06         양식
# 33  17476457     하늘초밥                 Q         음식        Q03     일식/수산물
# 34  17083541      폴어반                 Q         음식        Q06         양식
# 35  20280676    종금양꼬치                 Q         음식        Q09       유흥주점
# 36  14084683    종금양꼬치                 Q         음식        Q09       유흥주점
# 37  16729867      내사랑                 Q         음식        Q12     커피점/카페
# 38  12328064     만나김밥                 Q         음식        Q04         분식
#
#    indsSclsCd   indsSclsNm  ksicCd  ...                 rdnmAdr  oldZipcd  \
# 0      Q03A02       음식점-일식  I56113  ...      서울특별시 서대문구 신촌로 149    120809
# 1      Q07A05      샌드위치전문점  I56192  ...      서울특별시 서대문구 신촌역로 17    120809
# 2      Q05A08    후라이드/양념치킨  I56193  ...      서울특별시 서대문구 신촌역로 15    120809
# 3      Q04A01       라면김밥분식  I56194  ...      서울특별시 서대문구 신촌역로 21    120809
# 4      Q04A01       라면김밥분식  I56194  ...      서울특별시 서대문구 신촌역로 16    120808
# [1 rows x 39 columns]

# %%
df_best = pd.read_json('./df_best2.json')
df_best
# Out:
#           place  rate visit
# 0          인생식당          14
# 1      디저트바 이브흐  4.91   258
# 2          공복식당  4.48   275
# 3         유야케도쿄  4.59   220
# 4          하늘초밥  4.66   190
# ..          ...   ...   ...
# 199  하루엔소쿠 이대역점           8
# 200     불밥 이대본점  4.46    96
# 201   쉬즈베이글 이대점  4.56   277
# 202       나이스샤워  4.46   204
# 203   박가네 찌개&볶음  4.42   145
#
# [204 rows x 3 columns]

# %%
df_food
# Out:
#       bizesId      place brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 4    11980901         팔색                 Q         음식        Q01         한식
# 5    12033685    포원제로410                 Q         음식        Q06         양식
# 11   16553616     밥이꿀바비꿀                 Q         음식        Q01         한식
# 12   16701604        투다리    이대점          Q         음식        Q09       유흥주점
# 13   16860055         벨르                 Q         음식        Q12     커피점/카페
# ..        ...        ...    ...        ...        ...        ...        ...
# 943  12482161    플러스알파카페                 Q         음식        Q01         한식
# 944  15958983    마이헬싱키까페                 Q         음식        Q01         한식
# 947  26031006    고향순대감자탕                 Q         음식        Q01         한식
# 952  11755132     파파존스피자  이대아현점          Q         음식        Q06         양식
# 953  12452641  파파존스이대아현점  이대아현점          Q         음식        Q07      패스트푸드
#
#     indsSclsCd   indsSclsNm  ksicCd  ...      bldMngNo   bldNm  \
# 4       Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24  신촌자이엘라
# 5       Q06A01     정통양식/경양식  I56114  ...  1.141011e+24  신촌자이엘라
# 11      Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24  신촌자이엘라
# 12      Q09A07     기타일반유흥주점  I56211  ...  1.141011e+24  신촌자이엘라
# 13      Q12A01  커피전문점/카페/다방  I56220  ...  1.141011e+24  신촌자이엘라
# ..         ...          ...     ...  ...           ...     ...
# 943     Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24   핀란드타워
# 944     Q01A01    한식/백반/한정식  I56111  ...  1.141011e+24   핀란드타워
# 947     Q01A01    한식/백반/한정식  I56111  ...  1.144011e+24
# 952     Q06A01     정통양식/경양식  I56114  ...  1.141011e+24
# 953     Q07A01         피자전문  I56192  ...  1.141011e+24
#
#                  rdnmAdr  oldZipcd newZipcd  dongNo flrNo  hoNo         lon  \
# 4     서울특별시 서대문구 신촌로 149    120809     3780             1        126.942483
# 5     서울특별시 서대문구 신촌로 149    120809     3780             1        126.942483
# 11    서울특별시 서대문구 신촌로 149    120809     3780     101              126.942483
# 12    서울특별시 서대문구 신촌로 149    120809     3780                      126.942483
# 13    서울특별시 서대문구 신촌로 149    120809     3780     101              126.942483
# ..                   ...       ...      ...     ...   ...   ...         ...
# 943   서울특별시 서대문구 신촌로 203    120808     3767             2        126.948488
# 944   서울특별시 서대문구 신촌로 203    120808     3767            -2        126.948488
# 947  서울특별시 마포구 대흥로24길 50    121870     4123             1        126.948656
# 952   서울특별시 서대문구 신촌로 207    120822     3767             2        126.949133
# 953   서울특별시 서대문구 신촌로 207    120822     3767             1        126.949133
#
#            lat
# 4    37.556859
# 5    37.556859
# 11   37.556859
# 12   37.556859
# 13   37.556859
# ..         ...
# 943  37.557201
# 944  37.557201
# 947  37.554905
# 952  37.557207
# 953  37.557207
#
# [357 rows x 39 columns]

# %%
pd.merge('df_food','df_best', left_on = 'bizesNm',
    right_on='place', how = 'outer')

# %%
df_food.join(df_best, how = 'inner')
# Out:
#       bizesId  bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 4    11980901       팔색                 Q         음식        Q01         한식
# 5    12033685  포원제로410                 Q         음식        Q06         양식
# 11   16553616   밥이꿀바비꿀                 Q         음식        Q01         한식
# 12   16701604      투다리    이대점          Q         음식        Q09       유흥주점
# 13   16860055       벨르                 Q         음식        Q12     커피점/카페
# ..        ...      ...    ...        ...        ...        ...        ...
# 191  17465035   주앙곰컴퍼니                 Q         음식        Q04         분식
# 193  19967963    인생이야기                 Q         음식        Q12     커피점/카페
# 194  21980103     플로루스                 Q         음식        Q08    제과제빵떡케익
# 196  23417732    솔리드웍스                 Q         음식        Q09       유흥주점
# 201  16984313     미혜식당                 Q         음식        Q02         중식
#
#     indsSclsCd   indsSclsNm  ksicCd  ... oldZipcd  newZipcd dongNo  flrNo  \
# 4       Q01A01    한식/백반/한정식  I56111  ...   120809      3780             1
# 5       Q06A01     정통양식/경양식  I56114  ...   120809      3780             1
# 11      Q01A01    한식/백반/한정식  I56111  ...   120809      3780    101
# 12      Q09A07     기타일반유흥주점  I56211  ...   120809      3780
# 13      Q12A01  커피전문점/카페/다방  I56220  ...   120809      3780    101
# ..         ...          ...     ...  ...      ...       ...    ...    ...
# 191     Q04A01       라면김밥분식  I56194  ...   120809      3765             1
# 193     Q12A01  커피전문점/카페/다방  I56220  ...   120809      3765             3
# 194     Q08A01          제과점  I56191  ...   120809      3765
# 196     Q09A08    빠/카페/스탠드빠  I56211  ...   120809      3765             1
# 201     Q02A00     중국음식/중국집  I56112  ...   120809      3765
#
#     hoNo         lon        lat       place  rate  visit
# 4         126.942483  37.556859        하늘초밥  4.66    190
# 5         126.942483  37.556859    마더린러 베이글          714
# 11        126.942483  37.556859         유소바          249
# 12        126.942483  37.556859      공릉닭한마리  4.45    433
# 13        126.942483  37.556859   그릭데이 이대본점  4.71  3,098
# ..   ...         ...        ...         ...   ...    ...
# 191       126.943580  37.559328   모도크로플 이대점           22
# 193       126.943661  37.559212  고스트요거트 이대점   4.8    906
# 194       126.943693  37.559347  아리랑노점 이대본점           19
# 196       126.943479  37.559273          다다  4.45    250
# 201       126.943769  37.559528   쉬즈베이글 이대점  4.56    277
#
# [68 rows x 42 columns]

# %%
df_ter.sort_values('rate', ascending = False).head()
# Out:
#      bizesId    place brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 9   16638629      치즈문                 Q         음식        Q09       유흥주점
# 34  17083541      폴어반                 Q         음식        Q06         양식
# 0   17533468     진돈부리                 Q         음식        Q03     일식/수산물
# 16  18107441  굿바이슈가베어                 Q         음식        Q01         한식
# 5   20673833       아건                 Q         음식        Q06         양식
#
#    indsSclsCd indsSclsNm  ksicCd  ...                 rdnmAdr  oldZipcd  \
# 9      Q09A08  빠/카페/스탠드빠  I56211  ...  서울특별시 서대문구 이화여대길 88-13    120808
# 34     Q06A01   정통양식/경양식  I56114  ...    서울특별시 서대문구 이화여대2길 11    120808
# 0      Q03A02     음식점-일식  I56113  ...      서울특별시 서대문구 신촌로 149    120809
# 16     Q01A01  한식/백반/한정식  I56111  ...   서울특별시 서대문구 이화여대길 72-6    120808
# 5      Q06A01   정통양식/경양식  I56114  ...    서울특별시 서대문구 이화여대3길 35    120809
#
#    newZipcd  dongNo flrNo  hoNo         lon        lat  rate  visit
# 9      3765                      126.943805  37.559385  4.91     94
# 34     3767                      126.946492  37.557516  4.89    185
# 0      3780             1        126.942483  37.556859  4.83    179
# 16     3765             1        126.944552  37.559427  4.83    180
# 5      3766             2        126.943669  37.557834  4.82  1,351
#
# [5 rows x 41 columns]

# %%
df_ter['visit'] = pd.to_numeric(df_ter["visit"].str.replace(',', ''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 df_ter['visit'] = pd.to_numeric(df_ter["visit"].str.replace(',', ''))
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\strings\accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\strings\accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df_ter.sort_values('visit', ascending = False).head()
# Out:
#      bizesId   place brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 5   20673833      아건                 Q         음식        Q06         양식
# 6   16603185      아건                 Q         음식        Q10    별식/퓨전요리
# 3   16325619    영미김밥                 Q         음식        Q04         분식
# 14  23434871  파파노다이닝                 Q         음식        Q06         양식
# 12  16294026    비아37                 Q         음식        Q06         양식
#
#    indsSclsCd indsSclsNm  ksicCd  ...                 rdnmAdr  oldZipcd  \
# 5      Q06A01   정통양식/경양식  I56114  ...    서울특별시 서대문구 이화여대3길 35    120809
# 6      Q10A08   동남아음식전문점  I56119  ...     서울특별시 서대문구 이화여대길 63    120808
# 3      Q04A01     라면김밥분식  I56194  ...      서울특별시 서대문구 신촌역로 21    120809
# 14     Q06A01   정통양식/경양식  I56114  ...  서울특별시 서대문구 이화여대길 88-14    120808
# 12     Q06A07  기타전문서양음식점  I56114  ...   서울특별시 서대문구 이화여대길 77-1    120808
#
#    newZipcd  dongNo flrNo  hoNo         lon        lat  rate  visit
# 5      3766             2        126.943669  37.557834  4.82   1351
# 6      3766                      126.944908  37.559052  4.82   1351
# 3      3777                      126.942469  37.558652  4.57   1063
# 14     3765             1        126.944111  37.559414  4.56    505
# 12     3766                      126.944117  37.558973  4.67    431
#
# [5 rows x 41 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df_best['place']
#
# TypeError: string indices must be integers
