# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "KEDIu8F1pkcIQcLZ6Iwm"
client_secret = "Gj0ZfKZaL6"

query = input("검색할 단어 (빈값: 빅데이터) >")
if query == "":
    query = "빅데이터"

encText = urllib.parse.quote(query)

#url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어 (빈값: 빅데이터) >
# ...

# %%
import warnings
warnings.filterwarnings(action='ignore')

from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
bs = BeautifulSoup(xml, 'lxml')
bs.get_text()
# Out:
# "Naver Open API - blog ::'빅데이터'https://search.naver.comNaver Search ResultThu, 28 Jul 2022 10:37:59 +09001144657110<b>빅데이터</b>전문가 준비를 위한 체계적인 방법https://blog.naver.com/nam8853nam?Redirect=Log&logNo=222802704648그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터</b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... 율맘 스토리https://blog.naver.com/nam8853nam20220707<b>빅데이터</b>분석기사 실기 준비를 위한 학습루틴https://blog.naver.com/parkrapp?Redirect=Log&logNo=222753783578안녕하세요, 오늘은 제가 도전한 <b>빅데이터</b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터</b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... 황금빛 쭈롱월드https://blog.naver.com/parkrapp20220531<b>빅데이터</b>전문가 공부했던 과정https://blog.naver.com/kmin4015?Redirect=Log&logNo=222802560555<b>빅데이터</b>전문가 커리큘럼에서 다루고 있는 내용들은 1) 데이터 분석과 해석, 2) R 프로그램, 3) 요인 및 행렬, 4) 배열 및 리스트, 5) 패키지 등으로 구분해 볼 수 있는데요. 필요한 내용은 알차게 모두 구성되어 있는... 나날https://blog.naver.com/kmin401520220707<b>빅데이터</b>전문가 꼼꼼한 학습 노하우https://blog.naver.com/dbsrptkdgod?Redirect=Log&logNo=222
# ...

# %% [markdown]
# #### Q. 네이버웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요. (api 가이드 참조)

# %%
    
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "KEDIu8F1pkcIQcLZ6Iwm"
client_secret = "Gj0ZfKZaL6"

query = input("검색할 단어 (빈값: 빅데이터) >")
if query == "":
    query = "빅데이터"

encText = urllib.parse.quote(query)

#url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

#url = "https://openapi.naver.com/v1/search/webkr.xml?display=100&query=" + encText # xml 결과
url = "https://openapi.naver.com/v1/search/webkr.json?display=100&query=" + encText # json 결과
    
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어 (빈값: 빅데이터) >
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 08:36:22 +0900",
# 	"total":38802625,
# 	"start":1,
# 	"display":75,
# 	"items":[
# 		{
# 			"title":"<b>빅 데이터<\/b> 프로세싱 - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1",
# 			"description":"Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터<\/b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>란? | 고급 <b>빅데이터<\/b> 분석 | SAP Insights",
# 			"link":"https:\/\/www.sap.com\/korea\/insights\/what-is-big-data.html",
# 			"description":"비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 <b>빅데이터<\/b> 솔루션을 만나보세요."
# 		},
# 		{
# 			"title":"<b>빅 데이터<\/b>란 무엇입니까? | Oracle 대한민국",
# 			"link":"https:\/\/www.oracle.com\/kr\/big-data\/what-is-big-data\/",
# 			"description":"<b>빅데이터<\/b>는 특히 새로운 <b>데이터<\/b> 소스에서 나온 더 크고 더 복잡한 <b>데이터<\/b> 세트입니다. <b>빅데이터<\/b>의 이점, 과제 및 모범 사례 외에도 정의 및 역사에 대해 알아보세요."
# 		},
# 		{
# ...

# %%
import pandas as pd
news_df = pd.DataFrame(columns=['title','link','description'])
news_df
# Out:
# Empty DataFrame
# Columns: [title, link, description]
# Index: []

# %%
import warnings
warnings.filterwarnings(action='ignore')

from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
#bs = BeautifulSoup(xml, 'lxml')
#bs.get_text()

import json
json_object = json.loads(xml)

ind = 0
for i in json_object['items']:
    title = i['title']
    link = i['link']
    description = i['description']
    news_df.loc[ind] = [title,link,description]   
    ind += 1

news_df
# Out:
#                                                 title  \
# 0                            <b>빅 데이터</b> 프로세싱 - 나무위키
# 1    <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 2                  <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 3    <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                     네이버 <b>데이터</b>랩
# ..                                                ...
# 70  <b>빅데이터</b>에 관한 인기 아이디어 270개 | <b>빅데이터</b>, 파이...
# 71  자바학원,<b>빅데이터</b>학원,파이썬학원,자바교육,<b>빅데이터</b>교육,파이...
# 72                       <b>빅데이터</b> 전문기업 빅스터 BIGSTER
# 73             #<b>빅데이터</b> 해시태그 • Instagram 사진 및 동영상
# 74                    아임클라우드 – 인공지능, <b>빅데이터</b> 전문기업
#
#                                                  link  \
# 0   https://namu.wiki/w/%EB%B9%85%20%EB%8D%B0%EC%9...
# 1   https://www.sap.com/korea/insights/what-is-big...
# 2   https://www.oracle.com/kr/big-data/what-is-big...
# 3           https://www.redhat.com/ko/topics/big-data
# ...

# %%
import warnings
warnings.filterwarnings(action='ignore')

from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
#bs = BeautifulSoup(xml, 'lxml')
#bs.get_text()

import pandas as pd
json_object = pd.read_json(xml)
#display(json_object)

ind = 0
for i in json_object['items']:
    title = i['title']
    link = i['link']
    description = i['description']
    news_df.loc[ind] = [title,link,description]   
    ind += 1

news_df
# Out:
#                                                 title  \
# 0                            <b>빅 데이터</b> 프로세싱 - 나무위키
# 1    <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 2                  <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 3    <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                     네이버 <b>데이터</b>랩
# ..                                                ...
# 70  <b>빅데이터</b>에 관한 인기 아이디어 270개 | <b>빅데이터</b>, 파이...
# 71  자바학원,<b>빅데이터</b>학원,파이썬학원,자바교육,<b>빅데이터</b>교육,파이...
# 72                       <b>빅데이터</b> 전문기업 빅스터 BIGSTER
# 73             #<b>빅데이터</b> 해시태그 • Instagram 사진 및 동영상
# 74                    아임클라우드 – 인공지능, <b>빅데이터</b> 전문기업
#
#                                                  link  \
# 0   https://namu.wiki/w/%EB%B9%85%20%EB%8D%B0%EC%9...
# 1   https://www.sap.com/korea/insights/what-is-big...
# 2   https://www.oracle.com/kr/big-data/what-is-big...
# 3           https://www.redhat.com/ko/topics/big-data
# ...

# %% [markdown]
# #### 과제 0728_1
# 웹문서에서 빅데이터에 대한 의미있는 정보로 구성된 데이터프레임을 출력하세요

# %% [markdown]
# #### 과제 0728_2
# 뉴스, 영화, 쇼핑, 지식in, 카페글에서 적합한 주제에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "KEDIu8F1pkcIQcLZ6Iwm"
client_secret = "Gj0ZfKZaL6"

query = input("검색할 단어 (빈값: 빅데이터) >")
if query == "":
    query = "빅데이터"

encText = urllib.parse.quote(query)

#url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

#url = "https://openapi.naver.com/v1/search/webkr.xml?display=100&query=" + encText # xml 결과
url = "https://openapi.naver.com/v1/search/webkr.json?display=100&query=" + encText # json 결과
    
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# DataFrame    
import pandas as pd
news_df = pd.DataFrame(columns=['title','link','description'])
news_df    

import warnings
warnings.filterwarnings(action='ignore')

from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
#bs = BeautifulSoup(xml, 'lxml')
#bs.get_text()

import pandas as pd
json_object = pd.read_json(xml)
#display(json_object)

ind = 0
for i in json_object['items']:
    title = i['title']
    link = i['link']
    description = i['description']
    news_df.loc[ind] = [title,link,description]   
    ind += 1

news_df
# Out:
# 검색할 단어 (빈값: 빅데이터) >영화
#                                                 title  \
# 0                                       네이버 <b>영화</b>
# 1                               <b>영화</b> :: 네이버 TV연예
# 2                                    <b>영화</b> - 나무위키
# 3                                        다음 <b>영화</b>
# 4                                            네이버 시리즈온
# ..                                                ...
# 75           <b>영화</b>의전당 &gt; <b>영화</b> &gt; 시네마테크소개
# 76                                      <b>영화</b>펜션타운
# 77  대한예수교 장로회 <b>영화</b>교회 – <b>영화</b>교회 홈페이지에 오신 것...
# 78             <b>영화</b>의전당 &gt; <b>영화</b> &gt; 상영시간표
# 79                                    한눈에 보는 오늘 : 네이트
#
#                                                  link  \
# 0                            https://movie.naver.com/
# 1                   https://entertain.naver.com/movie
# 2              https://namu.wiki/w/%EC%98%81%ED%99%94
# 3                             https://movie.daum.net/
# ...

# %% [markdown]
# #### 과제 0728_3
# 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5

# %%
'''
+ 도시 = Seoul
| 날씨 = broken clouds
| 최저 기온 = -1.0 2
| 최고 기온 = 2.0 2
| 습도 = 74
| 기압 = 1023
| 풍속 = 0.5
'''
url = 'https://openweathermap.org/api'
cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]

# %%
import requests
import json

city = "Seoul" #도시
#apiKey = "본인의 api key"
lang = 'kr' #언어
apiKey = 'd3dbf480e3e3caedceb8d5528c8eac03'
units = 'metric' #화씨 온도를 섭씨 온도로 변경

cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
for city in cities:
    api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apiKey}&lang={lang}&units={units}"

    result = requests.get(api)
    result = json.loads(result.text)

    name = result['name']
    lon = result['coord']['lon']
    lat = result['coord']['lat']
    weather = result['weather'][0]['main']
    description = result['weather'][0]['description']
    
    pressure = result['main']['pressure']
    temp_min = result['main']['temp_min']
    temp_max = result['main']['temp_min']
    humidity = result['main']['humidity']    
    speed = result['wind']['speed']    
    
    # 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
    print(f'''+ 도시 = {city}
    | 날씨 = {description}
    | 최저 기온 = {temp_min}
    | 최고 기온 = {temp_max}
    | 습도 = {humidity}
    | 기압 = {pressure}
    | 풍속 = {speed}''')
#     print(result)
# Out:
# + 도시 = Seoul,KR
#     | 날씨 = 약간의 구름이 낀 하늘
#     | 최저 기온 = 29.66
#     | 최고 기온 = 29.66
#     | 습도 = 66
#     | 기압 = 1013
#     | 풍속 = 4.12
# + 도시 = Tokyo,JP
#     | 날씨 = 구름조금
#     | 최저 기온 = 28.7
#     | 최고 기온 = 28.7
#     | 습도 = 68
#     | 기압 = 1016
#     | 풍속 = 5.14
# + 도시 = New York,US
#     | 날씨 = 온흐림
#     | 최저 기온 = 25.47
#     | 최고 기온 = 25.47
#     | 습도 = 64
#     | 기압 = 1008
#     | 풍속 = 5.66

# %% [markdown]
# ## 공공데이터 api

# %% [markdown]
# #### 상가 업소정보

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = '2WKhofO%2FP%2Fzyhb%2FYYUq6fVtO08ZFBBiJ%2B7abwe9sV7Y%2BP9sWIADFvAVKjMJc6qln2Kabc6cgEs4anTIddxB7Tg%3D%3D'
res_id = 'storeZoneOne'
stype = 'json'

#url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/storeZoneOne'
#params ={'serviceKey' : '서비스키', 'key' : '9174', 'type' : 'xml' }
#response = requests.get(url, params=params)

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + urlencode({quote_plus('key'):'9174'})
#params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&key=9174'
query = url + params
#print(query)

response = Request(query)
response.get_method = lambda: 'GET'
response_body = urlopen(response).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
#print(response_dict)
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

def baro_api(skey, res_id, encode):
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + encode   
    query = url + params
    
    response = Request(query)
    response.get_method = lambda: 'GET'
    response_body = urlopen(response).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']

    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ### 상권조회

# %% [markdown]
# #### 지정 상권조회

# %%
skey = '2WKhofO%2FP%2Fzyhb%2FYYUq6fVtO08ZFBBiJ%2B7abwe9sV7Y%2BP9sWIADFvAVKjMJc6qln2Kabc6cgEs4anTIddxB7Tg%3D%3D'
res_id = 'storeZoneOne'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# #### 반경내 상권조회

# %%
skey = '2WKhofO%2FP%2Fzyhb%2FYYUq6fVtO08ZFBBiJ%2B7abwe9sV7Y%2BP9sWIADFvAVKjMJc6qln2Kabc6cgEs4anTIddxB7Tg%3D%3D'
res_id = 'storeZoneOne'
encode = urlencode({quote_plus('catId'):'radius', quote_plus('radius'):'500'
                    , quote_plus('cx'):'127.004528', quote_plus('cy'):'37.567538'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# #### 과제 0728_4
# 사각형내 상권조회

# %%
res_id = 'store'

#http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=rectangle&minx=127.034113&miny=37.509715&maxx=127.035730&maxy=37.510824&ServiceKey=서비스인증키
#encode = urlencode({quote_plus('resId'):'store', quote_plus('catId'):'rectangle'
#                    , quote_plus('minx'):'127.034113', quote_plus('miny'):'37.509715', quote_plus('maxx'):'127.035730', quote_plus('maxy'):'37.510824'})

# 이대역 37.556761, 126.945857                    
# 37.553261, 126.942357
# 37.560261, 126.949357
                    
#http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=rectangle&minx=127.034113&miny=37.509715&maxx=127.035730&maxy=37.510824&ServiceKey=서비스인증키
# encode = urlencode({quote_plus('catId'):'rectangle'
#                     , quote_plus('minx'):'126.942357', quote_plus('miny'):'37.553261'
#                     , quote_plus('maxx'):'126.949357', quote_plus('maxy'):'37.560261'})

# 홍대역: 37.557527, 126.9244669
# 37.554027, 126.9209669
# 37.561027, 126.9279669
#http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=rectangle&minx=127.034113&miny=37.509715&maxx=127.035730&maxy=37.510824&ServiceKey=서비스인증키
encode = urlencode({quote_plus('catId'):'rectangle'
                    , quote_plus('minx'):'126.9209669', quote_plus('miny'):'37.554027'
                    , quote_plus('maxx'):'126.9279669', quote_plus('maxy'):'37.561027'})

# encode = urlencode({quote_plus('catId'):'rectangle'
#                     , quote_plus('minx'):'126.9209669', quote_plus('miny'):'37.554027'
#                     , quote_plus('maxx'):'126.949357', quote_plus('maxy'):'37.560261'})


# http:/ / apis.data.go.kr / B553077/ api/ open/ sdsc2/ bar oApi?resId=stor e&catId=rectangle&m
# inx=127.034113&miny=37.509715&maxx=127.035730&maxy=37.510824&Ser viceKey=서비스
# 인증키


baro_api(skey, res_id, encode)
# Out:
#      bizesId        bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10183701           테디클럽                 D         소매        D01
# 1   11075131         그동네떡볶이    홍대점          Q         음식        Q04
# 2   11204457           바다나라                 Q         음식        Q03
# 3   11225763      하지디자인스튜디오                 F      생활서비스        F06
# 4   11633265         우리바다수산                 Q         음식        Q03
# 5   11751375           레또르떼                 Q         음식        Q08
# 6   11752637         푸하하크림빵                 Q         음식        Q08
# 7   11754204             슬슬                 Q         음식        Q09
# 8   11754607           종합수리                 F      생활서비스        F15
# 9   11756444          메디힐요가                 N   관광/여가/오락        N05
# 10  11756468         홍대역부동산                 L        부동산        L01
# 11  11758008           술퍼마켓                 Q         음식        Q09
# 12  11758016             진가                 Q         음식        Q02
# ...

# %%
a = pd.DataFrame()
type(a)
if type(a) == type(pd.DataFrame()):
    print(1)
else:
    print(2)
# Out:
# 1

# %%
def xy(x,y):
    max_x = x + 0.00350
    max_y = y + 0.00350
    min_x = x - 0.00350    
    min_y = y - 0.00350        
    return (min_x, min_y, max_x, max_y)

min_x, min_y, max_x, max_y = xy(126.945857, 37.556761)

import numpy as np

print(min_x, min_y, max_x, max_y )
li_x = np.linspace(min_x,max_x,10)
li_y = np.linspace(min_y,max_y,10)

df_s = np.NaN
for i in range(len(li_x)-1):
    x0 = li_x[i]
    x1 = li_x[i+1]
   
    for j in range(len(li_y)-1):
        y0 = li_y[j]
        y1 = li_y[j+1]
        
        # #이대역 37.556761, 126.945857
        encode = urlencode({quote_plus('catId'):'rectangle'
                            , quote_plus('minx'):x0, quote_plus('miny'):y0
                            , quote_plus('maxx'):x1, quote_plus('maxy'):y1})

        df_t = baro_api(skey, res_id, encode)
        #print(i, j, type(df_t), len(df_t))

        if type(df_t) == type(pd.DataFrame()) and len(df_t) > 0:        
            if type(df_s) == type(pd.DataFrame()) and len(df_s) > 0:
                #df_s = pd.concat(df_s,df_t, ignore_index=True)
                df_s = pd.concat([df_s, df_t], axis = 0, ignore_index=True)
            else:
                df_s = df_t    

df_s
# Out:
# 126.942357 37.553261 126.949357 37.560261000000004
#       bizesId      bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0    22414172         브레드칸                 N   관광/여가/오락        N03
# 1    12098251         머리쟁이                 F      생활서비스        F01
# 2    12620998  에이치에비뉴호텔이대점    이대점          O         숙박        O01
# 3    16733161      국민간식333    대흥점          D         소매        D03
# 4    21883640        보드람치킨    이대점          Q         음식        Q05
# ..        ...          ...    ...        ...        ...        ...
# 662  23568249        예일디엔시                 F      생활서비스        F13
# 663  26159771         뮤즈웨딩                 F      생활서비스        F17
# 664  26288178          아네스                 D         소매        D05
# 665  28296757       한국생활건강                 D         소매        D10
# 666  24352813           삐삐                 D         소매        D05
#
#      indsMclsNm indsSclsCd    indsSclsNm  ksicCd  ...  \
# ...

# %%
df_s.drop_duplicates(inplace = True)

df_s[df_s.bizesId == '12568975']
# Out:
#      bizesId bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 43  12568975    라멘81                 Q         음식        Q03     일식/수산물
#
#    indsSclsCd indsSclsNm  ksicCd  ...                   bldMngNo  bldNm  \
# 43     Q03A02     음식점-일식  I56113  ...  1141011200100270020000001  신촌가이아
#
#                rdnmAdr oldZipcd newZipcd dongNo flrNo hoNo         lon  \
# 43  서울특별시 서대문구 신촌역로 16   120808    03766            1       126.943156
#
#           lat
# 43  37.558054
#
# [1 rows x 39 columns]

# %%
len(df_s)
# Out:
# 646

# %%
d = pd.DataFrame()
# Out:
# pandas.core.frame.DataFrame

# %%
df_s

#df_s = pd.merge(li[1])
#df_s
# Out:
# Empty DataFrame
# Columns: [bizesId, bizesNm, brchNm, indsLclsCd, indsLclsNm, indsMclsCd, indsMclsNm, indsSclsCd, indsSclsNm, ksicCd, ksicNm, ctprvnCd, ctprvnNm, signguCd, signguNm, adongCd, adongNm, ldongCd, ldongNm, lnoCd, plotSctCd, plotSctNm, lnoMnno, lnoSlno, lnoAdr, rdnmCd, rdnm, bldMnno, bldSlno, bldMngNo, bldNm, rdnmAdr, oldZipcd, newZipcd, dongNo, flrNo, hoNo, lon, lat]
# Index: []
#
# [0 rows x 39 columns]

# %%
#이대역 37.556761, 126.945857
encode = urlencode({quote_plus('catId'):'rectangle'
                    , quote_plus('minx'):'126.942357', quote_plus('miny'):'37.556761'
                    , quote_plus('maxx'):'126.949357', quote_plus('maxy'):'37.560261'})
baro_api(skey, res_id, encode)
# Out:
#      bizesId      bizesNm    brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10786318        오피스디포       신촌점          D         소매        D08
# 1   11118157          메이퀸                    F      생활서비스        F01
# 2   11640271        현대홈마트     신촌이대점          D         소매        D03
# 3   11752602         미미뷰티                    F      생활서비스        F01
# 4   11754909    파파노다이닝돈부리                    Q         음식        Q03
# 5   11755132       파파존스피자     이대아현점          Q         음식        Q06
# 6   11819053    삼성전자판매이대점     판매이대점          D         소매        D12
# 7   11821462         데몬헤어                    F      생활서비스        F01
# 8   11858246      나나웨딩드레스                    D         소매        D05
# 9   11862809         시간여행                    D         소매        D05
# 10  11882876      온누리음악학원                    R      학문/교육        R05
# 11  11909851           파오                    Q         음식        Q01
# 12  11911902         육쌈냉면                    Q         음식        Q01
# ...

# %% [markdown]
# #### 과제 0728_5
# 행정단위 상권조회

# %%
#http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?
#resId=storezone&catId=dong&divId=adongCd&key=1168069000&ServiceKey=서비스인증키

encode = urlencode({quote_plus('resId'):'storezone', quote_plus('catId'):'dong'
                    , quote_plus('divId'):'adongCd', quote_plus('key'):'1168069000'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId        bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10372656     한스공인중개사사무소                 L        부동산        L01
# 1   11752840           오페라빈                 Q         음식        Q01
# 2   11794107          러빙헛카페                 Q         음식        Q12
# 3   11796806       파스쿠찌국악고점   국악고점          Q         음식        Q12
# 4   11799567             그집                 Q         음식        Q01
# 5   11799618       김승우의뼈감자탕                 Q         음식        Q01
# 6   11799629    배스킨라빈스31포이점    포이점          Q         음식        Q07
# 7   11799634          바로본안경                 D         소매        D18
# 8   11799688     우리들의편의점개포점    개포점          D         소매        D03
# 9   11872043         닥터큐헤어샵                 F      생활서비스        F01
# 10  11928583  호식이두마리치킨개포1호점  개포1호점          Q         음식        Q05
# 11  11958998           GS25  개포사랑점          D         소매        D03
# 12  11968513         모아필라테스    개포점          N   관광/여가/오락        N05
# ...

# %% [markdown]
# ### 상가업소 조회

# %% [markdown]
# #### 행정동 단위 상가업조 조회

# %%
res_id = 'store'
encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'ctprvnCd', quote_plus('key'):'11'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
